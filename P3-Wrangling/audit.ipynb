# %% [markdown]
# # Auditing the OSM Data
#
# Before we can do the real auditing, let's get the preliminary chores over with:

# %%
# Modules
from __future__  import print_function
from collections import Counter, defaultdict
from lxml.etree  import iterparse  # lxml is much faster
import re

# %run 'vendor/pprint_utf.py'        # Fix the problem of displaying Chinese

# Config constants
SAMPLE_FILE  = 'osm/sample.osm'
OSM_FILE     = 'osm/Xian-Xianyang.osm'
OSM_ELEMENTS = ('node', 'way', 'relation')

# Regex patterns (retroactively collected here from the auditing process below)
ALL_EN = re.compile(u'^[a-zA-Z0-9\s]+$')
ALL_CN = re.compile(u'^[\u4e00-\u9fa5]+$')
CN_EN  = re.compile(u'^[\u4e00-\u9fa5]+[^\u4e00-\u9fa5]+')
CN_SPACE_EN = re.compile(u'^[\u4e00-\u9fa5]+\s[^\u4e00-\u9fa5]+')

# Helper functions (retroactively collected here from the auditing process below)
#
# Generate every tag key and value with its paren
                
# print the element id and all its tags in the form of a dict
def print_element(elem):
    print(elem.tag, 'id:', elem.attrib['id'])
    pprint({ tag.attrib['k']: tag.attrib['v'] 
             for tag in elem.iter('tag') })
    print()
            
# Find an OSM element by id and
# print all its tags in the form of a dict
def find_and_print(id):
    for _, elem in iterparse(OSM_FILE, tag=OSM_ELEMENTS):
        if elem.attrib['id'] == id:
            print_element(elem)
            elem.clear()
            return
        else:
            elem.clear()

# %% [markdown]
# ## The Shape of the OSM File
#
# It seems a good idea to first familiarize ourselves with all the XML elements in the file and their respective number of occurrences in the descending order.

# %%
xml_element_count = Counter(elem.tag for _, elem in iterparse(SAMPLE_FILE))
xml_element_count.most_common()
# Out:
# [('nd', 30411),
#  ('node', 25623),
#  ('tag', 8036),
#  ('way', 3415),
#  ('member', 602),
#  ('relation', 21),
#  ('osm', 1)]

# %% [markdown]
# Now that we know what kind of and how many XML elements are there, let's get to the shape of the file. Using any text editor we can find out the outline as below, and it accounts for all the XML elements counted above:
# ```
# <osm>
#     <node>          # a point on the map
#         <tag></tag> # contains key/value pair
#     </node>
#
#     <way>           # a list of node element
#         <nd></nd>   # refers to a node element
#         <tag></tag> # contains key/value pair
#     </way>
#
#     <relation>            # a list of node/way/relation element
#         <member></member> # refers to a node/way/relation element
#         <tag></tag>       # contains key/value pair
#     </relation>
# </osm>
# ```

# %% [markdown]
# It can be reasonably deduced that the official OSM elements (node, way and relation) provides the structures of the map data, while the real meat resides in the tag elements. So tags will be the focal point of our auditing.

# %% [markdown]
# ## Surveying Tags
#
# Since we will probably spend a lot of time with tags, I have defined (and put at the very beginning) an **all_tags()** helper function, which allows us easy access to every tag element along with its parent OSM element.
#
# The code below shows how **all_tags()** works, and actually prints all the tags in the sample file.

# %%
for elem, key, val in all_tags(SAMPLE_FILE):
    pprint([elem.attrib['id'], key, val])
# Out:
# ['244080278', 'name', 'Gaoling Xian']
# ['244080278', 'place', 'county']
# ['244080278', 'gns:DSG', 'ADM3']
# ['244080278', 'gns:UFI', '-1906363']
# ['244080278', 'gns:UNI', '6816820']
# ['244080278', 'name:vi', u'Cao Lăng']
# ['244080278', 'name:zh', u'高陵县']
# ['244080278', 'gns:ADM1', '26']
# ['244080278', 'created_by', 'dkt_GNS-import-1']
# ['244080278', 'name:zh_pinyin', 'Gaoling Xian']
# ['244081932', 'name', u'渭南市']
# ['244081932', 'place', 'city']
# ['244081932', 'gns:DSG', 'ADM2']
# ['244081932', 'gns:UFI', '-1930304']
# ['244081932', 'gns:UNI', '6816771']
# ['244081932', 'name:de', 'Weinan']
# ['244081932', 'name:en', 'Weinan']
# ['244081932', 'name:fr', 'Weinan']
# ['244081932', 'name:ja', u'渭南市']
# ['244081932', 'name:vi', u'Vị Nam']
# ['244081932', 'name:zh', u'渭南市']
# ['244081932', 'gns:ADM1', '26']
# ['244081932', 'wikipedia', u'zh:渭南市']
# ['244081932', 'is_in:country', 'China']
# ['244081932', 'name:zh_pinyin', u'Wèinán Shì']
# ['244081932', 'is_in:continent', 'Asia']
# ['244081932', 'is_in:country_code', 'CN']
# ['244084832', 'name', u'灞桥区']
# ['244084832', 'place', 'town']
# ['244084832', 'gns:DSG', 'ADM3']
# ['244084832', 'gns:UFI', '9213841']
# ['244084832', 'gns:UNI', '9282012']
# ['244084832', 'name:vi', u'Bá Kiều']
# ['244084832', 'name:zh', u'灞桥区']
# ['244084832', 'gns:ADM1', '26']
# ['244084832', 'name:zh_pinyin', 'Baqiao Qu']
# ['310338331', 'name', u'青龙寺']
# ['310338331', 'amenity', 'place_of_worship']
# ['310338331', 'name:en', 'QingLong Temple']
# ['310338331', 'historic', 'wayside_shrine']
# ['310338331', 'religion', 'buddhist']
# ['310338331', 'denomination', 'Tang vajrayana']
# ['310347353', 'highway', 'traffic_signals']
# ['310502141', 'highway', 'bus_stop']
# ['310515765', 'historic', 'archaeological_site']
# ['310515765', 'name', u'兵马俑 terracotta army']
# ['310515765', 'name:de', 'Terrakotta-Armee']
# ['310515765', 'name:en', 'Terracotta Warriors']
# ['310515765', 'name:fr', u'Armée de terre cuite']
# ['310515765', 'name:ro', 'soldatii de teracota']
# ['310515765', 'name:sk', u'Terakotová armáda']
# ['310515765', 'name:zh', u'Exército de Terracota']
# ['310515765', 'tourism', 'museum']
# ['310515765', 'wheelchair', 'no']
# ['310725108', 'highway', 'bus_stop']
# ['310740835', 'name', u'家世界']
# ['310740835', 'highway', 'bus_stop']
# ['310741040', 'amenity', 'fuel']
# ['311042699', 'name', '107,34']
# ['311042699', 'highway', 'bus_stop']
# ['311042791', 'highway', 'bus_stop']
# ['312483360', 'name', 'Xianyang']
# ['312483360', 'highway', 'motorway_junction']
# ['312485833', 'name', u'天台路']
# ['312485833', 'highway', 'motorway_junction']
# ['312727858', 'name', u'西工大']
# ['312727858', 'highway', 'bus_stop']
# ['312978697', 'name', '411']
# ['312978697', 'highway', 'bus_stop']
# ['314079125', 'name', '721,...']
# ['314079125', 'highway', 'bus_stop']
# ['314928381', 'highway', 'bus_stop']
# ['314930196', 'name', '209, ...']
# ['314930196', 'highway', 'bus_stop']
# ['315268534', 'name', '29,411']
# ['315268534', 'highway', 'bus_stop']
# ['315470185', 'name', 'DHL']
# ['315470185', 'amenity', 'post_office']
# ['315744824', 'name', '411']
# ['315744824', 'highway', 'bus_stop']
# ['330371803', 'barrier', 'gate']
# ['477354210', 'highway', 'motorway_junction']
# ['526678458', 'highway', 'motorway_junction']
# ['699695383', 'highway', 'traffic_signals']
# ['732825569', 'highway', 'traffic_signals']
# ['733110512', 'crossing', 'traffic_signals']
# ['733110512', 'highway', 'crossing']
# ['787700234', 'amenity', 'bus_station']
# ['850352828', 'name', u'索菲特国际会展中心 Sofitel on Renmin Square']
# ['850352828', 'name:en', 'Sofitel on Renmin Square']
# ['850352828', 'name:zh', u'索菲特国际会展中心']
# ['850352828', 'tourism', 'hotel']
# ['850352828', 'addr:street', 'Dongxin']
# ['850352828', 'addr:housenumber', '319']
# ['989111726', 'name', 'Hairy Woman Cave']
# ['1042028041', 'name', u'西安阎良机场']
# ['1042028041', 'source', 'ourairports.com']
# ['1042028041', 'aeroway', 'aerodrome']
# ['1042028041', 'name:en', 'Yanliang Air Base']
# ['1511453988', 'name', 'Baskin & Robins']
# ['1511453988', 'amenity', 'cafe']
# ['1511453988', 'cuisine', 'ice_cream']
# ['1512532109', 'seats', '2']
# ['1512532109', 'colour', 'brown']
# ['1512532109', 'amenity', 'bench']
# ['1512532109', 'backrest', 'yes']
# ['1512532109', 'material', 'wood']
# ['1512532428', 'barrier', 'lift_gate']
# ['1532512688', 'source', 'bing']
# ['1532512688', 'railway', 'level_crossing']
# ['1557695569', 'name', u'西铁分局']
# ['1557695569', 'bench', 'no']
# ['1557695569', 'highway', 'bus_stop']
# ['1557695569', 'shelter', 'yes']
# ['1557740858', 'highway', 'traffic_signals']
# ['1557765359', 'highway', 'traffic_signals']
# ['1615501564', 'highway', 'traffic_signals']
# ['1615521419', 'name', u'大明宫桥']
# ['1615521419', 'highway', 'motorway_junction']
# ['1616450965', 'highway', 'crossing']
# ['1616452682', 'name', u'雾庄桥']
# ['1616452682', 'highway', 'motorway_junction']
# ['1654606400', 'amenity', 'bench']
# ['1694284806', 'name', 'Hanting Hotels']
# ['1694284806', 'tourism', 'hotel']
# ['1703812749', 'name', u'西安理工大学']
# ['1703812749', 'amenity', 'school']
# ['1703841483', 'name', u'西安工业学院']
# ['1703841483', 'amenity', 'school']
# ['1704119681', 'name', 'Starbucks Coffee']
# ['1704119681', 'wifi', 'free']
# ['1704119681', 'amenity', 'cafe']
# ['1726785187', 'name', 'Gaoxin erlu']
# ['1726785187', 'highway', 'bus_stop']
# ['1808516969', 'name', u'怡丰城']
# ['1808516969', 'shop', 'mall']
# ['1808516969', 'addr:street', '2nd Ring Road']
# ['1815078858', 'power', 'pole']
# ['1815078858', 'source', 'Bing']
# ['1815078885', 'power', 'pole']
# ['1815078885', 'source', 'Bing']
# ['1815078915', 'power', 'pole']
# ['1815078915', 'source', 'Bing']
# ['1815078944', 'power', 'pole']
# ['1815078944', 'source', 'Bing']
# ['1815078981', 'power', 'pole']
# ['1815078981', 'source', 'Bing']
# ['1815079009', 'power', 'pole']
# ['1815079009', 'source', 'Bing']
# ['1815299585', 'power', 'tower']
# ['1815299585', 'source', 'Bing']
# ['1815299606', 'power', 'tower']
# ['1815299606', 'source', 'Bing']
# ['1815330735', 'power', 'tower']
# ['1815330735', 'source', 'Bing']
# ['1815330745', 'power', 'tower']
# ['1815330745', 'source', 'Bing']
# ['1815330755', 'power', 'tower']
# ['1815330755', 'source', 'Bing']
# ['1815330765', 'railway', 'crossing']
# ['1815330775', 'power', 'tower']
# ['1815330775', 'source', 'Bing']
# ['1815330786', 'power', 'tower']
# ['1815330786', 'source', 'Bing']
# ['1815330796', 'power', 'tower']
# ['1815330796', 'source', 'Bing']
# ['1815330806', 'power', 'tower']
# ['1815330806', 'source', 'Bing']
# ['1815330816', 'power', 'tower']
# ['1815330816', 'source', 'Bing']
# ['1815330826', 'power', 'tower']
# ['1815330826', 'source', 'Bing']
# ['1815330846', 'power', 'tower']
# ['1815330846', 'source', 'Bing']
# ['1815330856', 'power', 'tower']
# ['1815330856', 'source', 'Bing']
# ['1815330870', 'power', 'tower']
# ['1815330870', 'source', 'Bing']
# ['1815330880', 'power', 'tower']
# ['1815330880', 'source', 'Bing']
# ['1815330890', 'power', 'tower']
# ['1815330890', 'source', 'Bing']
# ['1815330900', 'power', 'tower']
# ['1815330900', 'source', 'Bing']
# ['1815368328', 'power', 'tower']
# ['1815368328', 'source', 'Bing']
# ['1815368348', 'power', 'tower']
# ['1815368348', 'source', 'Bing']
# ['1815368358', 'power', 'tower']
# ['1815368358', 'source', 'Bing']
# ['1815368380', 'power', 'tower']
# ['1815368380', 'source', 'Bing']
# ['1815368405', 'power', 'tower']
# ['1815368405', 'source', 'Bing']
# ['1815368415', 'power', 'tower']
# ['1815368415', 'source', 'Bing']
# ['1815368435', 'power', 'tower']
# ['1815368435', 'source', 'Bing']
# ['1815368445', 'power', 'tower']
# ['1815368445', 'source', 'Bing']
# ['1815368455', 'power', 'tower']
# ['1815368455', 'source', 'Bing']
# ['1815368465', 'power', 'tower']
# ['1815368465', 'source', 'Bing']
# ['1815368475', 'power', 'tower']
# ['1815368475', 'source', 'Bing']
# ['1815368485', 'power', 'tower']
# ['1815368485', 'source', 'Bing']
# ['1815368509', 'power', 'tower']
# ['1815368509', 'source', 'Bing']
# ['1815368529', 'power', 'tower']
# ['1815368529', 'source', 'Bing']
# ['1815368559', 'power', 'tower']
# ['1815368559', 'source', 'Bing']
# ['1815368569', 'power', 'tower']
# ['1815368569', 'source', 'Bing']
# ['1815368579', 'power', 'tower']
# ['1815368579', 'source', 'Bing']
# ['1815368589', 'power', 'tower']
# ['1815368589', 'source', 'Bing']
# ['1815368599', 'power', 'tower']
# ['1815368599', 'source', 'Bing']
# ['1815378314', 'power', 'tower']
# ['1815378314', 'source', 'Bing']
# ['1815378324', 'power', 'tower']
# ['1815378324', 'source', 'Bing']
# ['1815378334', 'power', 'tower']
# ['1815378334', 'source', 'Bing']
# ['1815378344', 'power', 'tower']
# ['1815378344', 'source', 'Bing']
# ['1815378354', 'power', 'tower']
# ['1815378354', 'source', 'Bing']
# ['1815378364', 'power', 'tower']
# ['1815378364', 'source', 'Bing']
# ['1815378374', 'power', 'tower']
# ['1815378374', 'source', 'Bing']
# ['1815378394', 'power', 'tower']
# ['1815378394', 'source', 'Bing']
# ['1815397763', 'power', 'tower']
# ['1815397763', 'source', 'Bing']
# ['1815397811', 'power', 'tower']
# ['1815397811', 'source', 'Bing']
# ['1815397860', 'power', 'tower']
# ['1815397860', 'source', 'Bing']
# ['1815397902', 'power', 'tower']
# ['1815397902', 'source', 'Bing']
# ['1815397940', 'power', 'tower']
# ['1815397940', 'source', 'Bing']
# ['1815397978', 'power', 'tower']
# ['1815397978', 'source', 'Bing']
# ['1815398018', 'power', 'tower']
# ['1815398018', 'source', 'Bing']
# ['1819638409', 'name', u'学校食堂']
# ['1819638409', 'amenity', 'restaurant']
# ['1828966323', 'power', 'tower']
# ['1828966323', 'source', 'Bing']
# ['1828966383', 'power', 'tower']
# ['1828966383', 'source', 'Bing']
# ['1828966471', 'power', 'tower']
# ['1828966471', 'source', 'Bing']
# ['1828966501', 'power', 'tower']
# ['1828966501', 'source', 'Bing']
# ['1828966518', 'power', 'tower']
# ['1828966518', 'source', 'Bing']
# ['1828966639', 'power', 'tower']
# ['1828966639', 'source', 'Bing']
# ['1828966673', 'power', 'tower']
# ['1828966673', 'source', 'Bing']
# ['1828966697', 'power', 'tower']
# ['1828966697', 'source', 'Bing']
# ['1828966711', 'power', 'tower']
# ['1828966711', 'source', 'Bing']
# ['1828966723', 'power', 'tower']
# ['1828966723', 'source', 'Bing']
# ['1828966738', 'power', 'tower']
# ['1828966738', 'source', 'Bing']
# ['1828966804', 'power', 'tower']
# ['1828966804', 'source', 'Bing']
# ['1828966891', 'power', 'tower']
# ['1828966891', 'source', 'Bing']
# ['1828966922', 'power', 'tower']
# ['1828966922', 'source', 'Bing']
# ['1828967063', 'power', 'tower']
# ['1828967063', 'source', 'Bing']
# ['1828977237', 'power', 'tower']
# ['1828977237', 'source', 'Bing']
# ['1828977282', 'power', 'tower']
# ['1828977282', 'source', 'Bing']
# ['1828977339', 'power', 'tower']
# ['1828977339', 'source', 'Bing']
# ['1828989763', 'power', 'tower']
# ['1828989763', 'source', 'Bing']
# ['1828989797', 'power', 'tower']
# ['1828989797', 'source', 'Bing']
# ['1828989830', 'power', 'tower']
# ['1828989830', 'source', 'Bing']
# ['1828989876', 'power', 'tower']
# ['1828989876', 'source', 'Bing']
# ['1876844147', 'foot', 'yes']
# ['1876844147', 'name', u'西北工业大学友谊校区南门']
# ['1876844147', 'horse', 'no']
# ['1876844147', 'barrier', 'gate']
# ['1876844147', 'bicycle', 'yes']
# ['1876844147', 'motor_vehicle', 'designated']
# ['1905583315', 'highway', 'motorway_junction']
# ['1918384840', 'name', u'谢王桥']
# ['1918384840', 'highway', 'motorway_junction']
# ['1918760562', 'highway', 'traffic_signals']
# ['1927956207', 'highway', 'motorway_junction']
# ['2152344863', 'power', 'tower']
# ['2152344896', 'power', 'tower']
# ['2152344953', 'power', 'tower']
# ['2152344965', 'power', 'tower']
# ['2152345039', 'power', 'tower']
# ['2152345071', 'power', 'tower']
# ['2152345136', 'power', 'tower']
# ['2153564006', 'power', 'tower']
# ['2153564020', 'power', 'tower']
# ['2153564050', 'power', 'tower']
# ['2153564060', 'power', 'tower']
# ['2153564070', 'power', 'tower']
# ['2153564080', 'power', 'tower']
# ['2153564090', 'power', 'tower']
# ['2153564100', 'power', 'tower']
# ['2153570910', 'power', 'tower']
# ['2153570920', 'power', 'tower']
# ['2157405229', 'source', 'bing']
# ['2157405229', 'barrier', 'toll_booth']
# ['2157496404', 'name', u'灞源']
# ['2157496404', 'highway', 'motorway_junction']
# ['2254514432', 'amenity', 'fast_food']
# ['2254514432', 'cuisine', 'american']
# ['2254514432', 'name', 'KFC']
# ['2254514432', 'name:zh', u'肯德基']
# ['2260068458', 'amenity', 'toilets']
# ['2278121070', 'source', 'bing']
# ['2278121070', 'barrier', 'toll_booth']
# ['2282557110', 'amenity', 'place_of_worship']
# ['2282557110', 'religion', 'taoist']
# ['2282557128', 'name', 'South Heavenly Gate']
# ['2282557128', 'building', 'yes']
# ['2298244476', 'barrier', 'toll_booth']
# ['2298244578', 'highway', 'crossing']
# ['2298244649', 'highway', 'crossing']
# ['2298244669', 'highway', 'crossing']
# ['2298244689', 'highway', 'crossing']
# ['2298245087', 'barrier', 'toll_booth']
# ['2298523109', 'highway', 'motorway_junction']
# ['2299187326', 'highway', 'crossing']
# ['2299187326', 'crossing', 'uncontrolled']
# ['2300217322', 'historic', 'monument']
# ['2301249336', 'barrier', 'gate']
# ['2336828589', 'name', u'盛景园']
# ['2336828589', 'building', 'residential']
# ['2379990923', 'name', u'世纪金花']
# ['2379990923', 'shop', 'mall']
# ['2379990923', 'name:en', 'Century Ginwa']
# ['2379990923', 'name:zh', u'世纪金花']
# ['2379990923', 'website', 'centuryginwa.com.cn']
# ['2410636443', 'barrier', 'toll_booth']
# ['2411196689', 'barrier', 'toll_booth']
# ['2422930094', 'name', u'穆将王立交']
# ['2422930094', 'highway', 'motorway_junction']
# ['2453135600', 'highway', 'motorway_junction']
# ['2470112464', 'name', u'耿镇']
# ['2470112464', 'place', 'town']
# ['2470112464', 'source', 'GNS']
# ['2470112464', 'name:en', 'Gengzhen']
# ['2470112464', 'china_class', 'zhen']
# ['2470112477', 'name', u'滦镇街办']
# ['2470112477', 'place', 'town']
# ['2470112477', 'source', 'GNS']
# ['2470112477', 'name:en', 'Luanzhen']
# ['2470112477', 'china_class', 'zhen']
# ['2470112492', 'name', u'通远镇']
# ['2470112492', 'place', 'town']
# ['2470112492', 'source', 'GNS']
# ['2470112492', 'name:en', 'Tongyuan']
# ['2470112492', 'china_class', 'zhen']
# ['2470112505', 'name', u'终南镇']
# ['2470112505', 'place', 'town']
# ['2470112505', 'source', 'GNS']
# ['2470112505', 'name:en', 'Zhongnan']
# ['2470112505', 'wikipedia', u'zh:终南镇']
# ['2470112505', 'china_class', 'zhen']
# ['2470141395', 'name', u'斗门街办']
# ['2470141395', 'place', 'town']
# ['2470141395', 'source', 'GNS']
# ['2470141395', 'name:en', 'Doumen']
# ['2470141395', 'china_class', 'zhen']
# ['2470141470', 'power', 'tower']
# ['2470141470', 'source', 'bing']
# ['2513441855', 'name', 'Mercure on Renmin Square Xian']
# ['2513441855', 'tourism', 'hotel']
# ['2531704894', 'name', u'格力电器维修站']
# ['2548263339', 'name', u'半坡']
# ['2548263339', 'place', 'locality']
# ['2557088965', 'natural', 'tree']
# ['2557088975', 'natural', 'tree']
# ['2559415716', 'natural', 'tree']
# ['2569490889', 'name', u'小寨']
# ['2569490889', 'place', 'neighbourhood']
# ['2579259276', 'amenity', 'fountain']
# ['2589970850', 'shop', 'beverages']
# ['2598186083', 'barrier', 'bollard']
# ['2603038454', 'name', u'南稍门']
# ['2603038454', 'place', 'locality']
# ['2611724248', 'power', 'tower']
# ['2611724258', 'power', 'tower']
# ['2611724268', 'power', 'tower']
# ['2611724278', 'power', 'tower']
# ['2611724278', 'source', 'Bing']
# ['2611724288', 'power', 'tower']
# ['2611724308', 'power', 'pole']
# ['2611724318', 'power', 'pole']
# ['2611724328', 'power', 'tower']
# ['2611724328', 'source', 'Bing']
# ['2611724338', 'power', 'pole']
# ['2611724348', 'power', 'pole']
# ['2611724358', 'power', 'pole']
# ['2611724368', 'power', 'pole']
# ['2611724378', 'power', 'tower']
# ['2611724388', 'power', 'tower']
# ['2611724398', 'power', 'tower']
# ['2611724398', 'source', 'Bing']
# ['2611724408', 'power', 'tower']
# ['2611724408', 'source', 'Bing']
# ['2611724421', 'power', 'tower']
# ['2611724421', 'source', 'Bing']
# ['2615873518', 'name', u'交通银行']
# ['2615873518', 'amenity', 'bank']
# ['2616189316', 'name', u'陈天人校长纪念碑']
# ['2616189316', 'historic', 'monument']
# ['2616189316', 'attribution', u'创始人即首任校长纪念碑']
# ['2616189336', 'name', u'天文台']
# ['2616229417', 'atm', 'yes']
# ['2616229417', 'name', u'陕西信合']
# ['2616229417', 'amenity', 'bank']
# ['2616238127', 'name', u'青年南街：215，229，324，918']
# ['2616238127', 'highway', 'bus_stop']
# ['2616247127', 'atm', 'yes']
# ['2616247127', 'name', u'邮政储蓄银行']
# ['2616247127', 'amenity', 'bank']
# ['2616247137', 'name', u'西安银行']
# ['2616247137', 'amenity', 'bank']
# ['2616278812', 'name', u'苏宁']
# ['2616278812', 'shop', 'mall']
# ['2616278869', 'name', u'司马村']
# ['2616278869', 'place', 'village']
# ['2616278879', 'name', u'西杨万村']
# ['2616278879', 'place', 'village']
# ['2616904373', 'name', u'涝店初中']
# ['2616904373', 'amenity', 'school']
# ['2616904373', 'website', 'http://zjq.in']
# ['2616904383', 'name', u'元王村']
# ['2616904383', 'place', 'village']
# ['2616904393', 'place', 'village']
# ['2616922178', 'name', u'东曹村']
# ['2616922178', 'place', 'village']
# ['2616922178', 'website', 'http://zjq.in']
# ['2616922211', 'name', u'宋滩村']
# ['2616922211', 'place', 'village']
# ['2616922211', 'website', 'http://zjq.in']
# ['2616922248', 'name', u'东堡村']
# ['2616922248', 'place', 'village']
# ['2616922248', 'website', 'http://zjq.in']
# ['2616922285', 'name', u'双北村']
# ['2616922285', 'place', 'village']
# ['2616922285', 'website', 'http://zjq.in']
# ['2616937081', 'name', u'平东村']
# ['2616937081', 'place', 'village']
# ['2616937081', 'website', 'http://zjq.in']
# ['2616995850', 'amenity', 'university']
# ['2616995850', 'name', u'西安翻译学院']
# ['2616995850', 'website', 'http://zjq.in']
# ['2634971738', 'tourism', 'hotel']
# ['2634980423', 'shop', 'mall']
# ['2634988855', 'shop', 'beverages']
# ['2634988900', 'amenity', 'restaurant']
# ['2647202544', 'name', u'辛家庙立交']
# ['2647202544', 'highway', 'motorway_junction']
# ['2651274995', 'name', u'西安雁塔神龙中医医院']
# ['2651274995', 'amenity', 'hospital']
# ['2651289882', 'highway', 'traffic_signals']
# ['2655761920', 'amenity', 'bar']
# ['2684608864', 'name', u'眼光菩萨']
# ['2684608864', 'amenity', 'place_of_worship']
# ['2684608864', 'religion', 'buddhist']
# ['2687897293', 'name', u'嘉天國際']
# ['2687897293', 'name:zh', u'嘉天国际']
# ['2694576971', 'name', u'浐河站']
# ['2694576971', 'railway', 'station']
# ['2694576993', 'name', u'开远门站']
# ['2694576993', 'railway', 'station']
# ['2694577028', 'name', u'纺织城站']
# ['2694577028', 'railway', 'station']
# ['2726544602', 'name', u'郭杜街办']
# ['2726544602', 'place', 'town']
# ['2726644062', 'name', u'西安西站']
# ['2726644062', 'railway', 'station']
# ['2746847416', 'name', u'长安大学校本部办公楼']
# ['2841186409', 'name', u'大荆镇']
# ['2841186409', 'place', 'town']
# ['2841186409', 'source', 'GNS']
# ['2841186409', 'name:en', 'Dajing']
# ['2841186409', 'china_class', 'zhen']
# ['2841186419', 'name', u'桥南镇']
# ['2841186419', 'place', 'town']
# ['2841186419', 'source', 'GNS']
# ['2841186419', 'name:en', 'Qiaonan']
# ['2841186419', 'china_class', 'zhen']
# ['2844061719', 'name', u'国展中心']
# ['2844061719', 'highway', 'bus_stop']
# ['2844061729', 'amenity', 'parking']
# ['2844061740', 'highway', 'bus_stop']
# ['2876178097', 'name', u'窑村']
# ['2876178097', 'railway', 'station']
# ['2918439838', 'barrier', 'toll_booth']
# ['2921585615', 'name', u'金堆城：162']
# ['2921585615', 'highway', 'bus_stop']
# ['2941777327', 'name', u'三爻站']
# ['2941777327', 'name:en', 'Sanyao']
# ['2941777327', 'railway', 'station']
# ['2943643680', 'name', u'西安电子科技大学新校区']
# ['2943643680', 'note', u'4-08路 4-16路 916路 921路 922路']
# ['2943643680', 'highway', 'bus_stop']
# ['2943828234', 'atm', 'yes']
# ['2943828234', 'name', u'交通银行']
# ['2943828234', 'amenity', 'bank']
# ['2958054523', 'name', u'凤栖原站']
# ['2958054523', 'name:en', 'Fengqiyuan']
# ['2958054523', 'railway', 'station']
# ['2958170402', 'addr:city', u'西安']
# ['2958170402', 'addr:street', u'北院门']
# ['2958170402', 'addr:housenumber', '1']
# ['2958176834', 'name', u'西安烤鸭店总店']
# ['2958176834', 'amenity', 'restaurant']
# ['2968410795', 'name', u'斗门']
# ['2968410795', 'railway', 'station']
# ['2972370360', 'name', u'安远门站']
# ['2972370360', 'railway', 'station']
# ['2977155119', 'name', u'保税区站']
# ['2977155119', 'railway', 'station']
# ['2977172947', 'name', u'石家街站']
# ['2977172947', 'railway', 'station']
# ['2984012340', 'name', u'秦始皇陵']
# ['2997258126', 'highway', 'traffic_signals']
# ['2999960009', 'name', u'两岔河站']
# ['2999960009', 'railway', 'station']
# ['3003935030', 'name', u'漠西站']
# ['3003935030', 'railway', 'station']
# ['3011811575', 'name', u'黄良街办']
# ['3011811575', 'place', 'town']
# ['3011812876', 'name', u'王寺街办']
# ['3011812876', 'place', 'town']
# ['3013880327', 'name', u'代王街办']
# ['3013880327', 'place', 'town']
# ['3015663398', 'name', u'洪庆街办']
# ['3015663398', 'place', 'town']
# ['3060726439', 'name', u'西关']
# ['3060726439', 'place', 'town']
# ['3074748427', 'name', u'普集街镇']
# ['3074748427', 'place', 'town']
# ['3079707878', 'name', u'东关南街']
# ['3079707878', 'place', 'town']
# ['3079707888', 'name', u'谭家']
# ['3079707888', 'place', 'town']
# ['3079723028', 'name', u'长延堡']
# ['3079723028', 'place', 'town']
# ['3079728730', 'name', u'韩森寨']
# ['3079728730', 'place', 'town']
# ['3105099585', 'amenity', 'parking']
# ['3105099585', 'parking', 'underground']
# ['3132559115', 'name', u'富仁乡']
# ['3132559115', 'place', 'town']
# ['3218811457', 'name', u'西门']
# ['3218811457', 'amenity', 'bus_station']
# ['3283285289', 'name', u'绿地世纪城 Igress Park']
# ['3283285289', 'note', u'绿地世纪城 Igress Park。']
# ['3283285289', 'leisure', 'park']
# ['3283285289', 'addr:city', u'西安市']
# ['3283285289', 'addr:street', u'丈八三路']
# ['3283285289', 'addr:postcode', '710075']
# ['3283285289', 'addr:housenumber', u'1号']
# ['3405324194', 'name', u'西南城角']
# ['3421039871', 'name', u'交大电脑城']
# ['3421039871', 'amenity', 'bus_station']
# ['3421039881', 'name', u'东南城角']
# ['3421039881', 'amenity', 'bus_station']
# ['3421043997', 'name', u'李家村']
# ['3421043997', 'amenity', 'bus_station']
# ['3424725076', 'name', u'东等驾坡']
# ['3424725076', 'amenity', 'bus_station']
# ['3424726260', 'name', u'青龙寺']
# ['3424726260', 'amenity', 'bus_station']
# ['3424740598', 'name', u'五路口']
# ['3424740598', 'amenity', 'bus_station']
# ['3424858815', 'name', 'Terrakotta Armee Xian']
# ['3424858815', 'seamark:type', 'mooring']
# ['3424858815', 'seamark:mooring:category', 'dolphin']
# ['3426311983', 'name', u'西部大道']
# ['3426311983', 'amenity', 'bus_station']
# ['3426565057', 'name', u'锦园小区']
# ['3426565057', 'amenity', 'bus_station']
# ['3426583781', 'name', u'科技路小区']
# ['3426583781', 'amenity', 'bus_station']
# ['3426583791', 'name', u'电子二路西口']
# ['3426583791', 'amenity', 'bus_station']
# ['3426604308', 'name', u'北沈家桥']
# ['3426604308', 'amenity', 'bus_station']
# ['3426604318', 'name', u'博士路']
# ['3426604318', 'amenity', 'bus_station']
# ['3426604328', 'name', u'发展大道']
# ['3426604328', 'amenity', 'bus_station']
# ['3426604338', 'name', u'硕士路']
# ['3426604338', 'amenity', 'bus_station']
# ['3426612982', 'name', u'悦园路']
# ['3426612982', 'amenity', 'bus_station']
# ['3426804931', 'name', u'西五桥新村']
# ['3426804931', 'amenity', 'bus_station']
# ['3426804941', 'name', u'大居安村']
# ['3426804941', 'amenity', 'bus_station']
# ['3429782376', 'name', u'玉祥门']
# ['3429782376', 'amenity', 'bus_station']
# ['3444336188', 'name', u'太乙路']
# ['3444336188', 'highway', 'bus_stop']
# ['3458685174', 'door', 'yes']
# ['3458685174', 'entrance', 'emergency']
# ['3481671580', 'name', 'Hooters']
# ['3481671580', 'phone', '+86 29 88315552']
# ['3481671580', 'amenity', 'restaurant']
# ['3481671580', 'cuisine', 'burger']
# ['3481671580', 'smoking', 'separated']
# ['3481671580', 'addr:city', "Xi'an"]
# ['3481671580', 'addr:street', u'科技路 / Keji Lu']
# ['3481671580', 'addr:postcode', '710068']
# ['3481671580', 'opening_hours', '11:00am-02:00am Sun - Sat']
# ['3481671580', 'addr:housenumber', '39']
# ['3521045254', 'level', '0']
# ['3521045254', 'entrance', 'main']
# ['3547180842', 'barrier', 'toll_booth']
# ['3598573422', 'name', u'户县']
# ['3598573422', 'highway', 'motorway_junction']
# ['3598579895', 'name', u'三桥收费站']
# ['3598579895', 'barrier', 'toll_booth']
# ['3599757760', 'name', u'咸阳东']
# ['3599757760', 'highway', 'motorway_junction']
# ['3599851651', 'name', u'蓝田']
# ['3599851651', 'highway', 'motorway_junction']
# ['3599862097', 'name', u'梁村塬']
# ['3599862097', 'highway', 'motorway_junction']
# ['3599862117', 'name', u'聂冯东']
# ['3599862117', 'highway', 'motorway_junction']
# ['3600090449', 'name', u'礼泉']
# ['3600090449', 'highway', 'motorway_junction']
# ['3643535043', 'amenity', 'car_wash']
# ['3643535204', 'amenity', 'fountain']
# ['3657416925', 'barrier', 'gate']
# ['3670482118', 'name', u'教学区北一门']
# ['3670482118', 'access', 'permissive']
# ['3670482118', 'barrier', 'gate']
# ['3672876859', 'name', u'中通快递']
# ['3672876859', 'building', 'university']
# ['3683385253', 'name', u'万家福便利店']
# ['3683385253', 'shop', 'convenience']
# ['3684897982', 'name', u'南方修鞋']
# ['3684897982', 'craft', 'shoemaker']
# ['3692652488', 'name', u'北田街道']
# ['3692652488', 'place', 'town']
# ['3692652498', 'name', u'渠岸镇']
# ['3692652498', 'place', 'town']
# ['3692656080', 'name', u'韩家湾街道']
# ['3692656080', 'place', 'town']
# ['3692759977', 'name', u'康桥镇']
# ['3692759977', 'place', 'town']
# ['3708900764', 'name', "Xi'An Hometown Hostel"]
# ['3708900764', 'note', '1st floor, left door']
# ['3708900764', 'phone', '+8613384912615']
# ['3708900764', 'tourism', 'hostel']
# ['3708900764', 'addr:city', "Xi'an"]
# ['3708900764', 'wheelchair', 'no']
# ['3708900764', 'addr:street', '237 ZiQiang West Road']
# ['3708900764', 'addr:housenumber', '15']
# ['3779399917', 'name', 'SkyBar']
# ['3779399917', 'wifi', 'free']
# ['3779399917', 'amenity', 'bar']
# ['3779399917', 'addr:city', "Xi'an"]
# ['3779399917', 'addr:street', 'SouthRingRoad']
# ['3792222342', 'name', u'阡东镇']
# ['3792222342', 'place', 'town']
# ['3792240815', 'name', u'骏马乡']
# ['3792240815', 'place', 'town']
# ['3792505120', 'name', u'周城镇']
# ['3792505120', 'place', 'town']
# ['3794181906', 'name', u'华西镇']
# ['3794181906', 'place', 'town']
# ['3796967412', 'name', u'张家坪乡']
# ['3796967412', 'place', 'town']
# ['3814807948', 'name', u'上王村']
# ['3814807948', 'place', 'village']
# ['3814836167', 'name', u'温国堡']
# ['3814836167', 'place', 'village']
# ['3861900119', 'name', u'铁一中4公寓']
# ['3861900119', 'amenity', 'school']
# ['3871021780', 'name', 'China Construction Bank 24-hour Self-service Bank']
# ['3871021780', 'amenity', 'atm']
# ['3871021780', 'operator', 'China Construction Bank']
# ['4010621036', 'amenity', 'fuel']
# ['4015858552', 'amenity', 'fuel']
# ['4031489524', 'name', u'大杨乡']
# ['4031489524', 'place', 'town']
# ['4031489524', 'name:en', 'Dayang']
# ['4031489524', 'name:zh', u'大杨乡']
# ['4031489524', 'alt_name', u'大杨;Dayangcun']
# ['4031489524', 'china_class', 'xiang']
# ['4031489524', 'source:name', 'GNS']
# ['4031489534', 'power', 'tower']
# ['4031489534', 'source', 'mapbox']
# ['4031489544', 'power', 'tower']
# ['4031489544', 'source', 'mapbox']
# ['4031489554', 'power', 'tower']
# ['4031489554', 'source', 'mapbox']
# ['4031489574', 'power', 'tower']
# ['4031489574', 'source', 'mapbox']
# ['4031489584', 'power', 'tower']
# ['4031489584', 'source', 'mapbox']
# ['4087687860', 'name', u'康家湾']
# ['4087687860', 'place', 'village']
# ['4087696785', 'name', u'马腾空']
# ['4087696785', 'place', 'village']
# ['4119774589', 'amenity', 'fast_food']
# ['4119774589', 'name', 'KFC']
# ['4119774589', 'name:zh', u'肯德基']
# ['4122416685', 'name', u'南雷村']
# ['4122416685', 'place', 'village']
# ['4178393691', 'name', 'Shuttle Service To The Airport ']
# ['4178393691', 'amenity', 'bus_station']
# ['4185074661', 'railway', 'subway_entrance']
# ['4198253594', 'name', 'Pizza Hut']
# ['4198253594', 'amenity', 'fast_food']
# ['4210094661', 'name', '8']
# ['4210094661', 'amenity', 'hospital']
# ['4234001747', 'tourism', 'artwork']
# ['4234001747', 'artwork_type', 'statue']
# ['4238854710', 'amenity', 'cafe']
# ['4238854710', 'name', 'Coffee House']
# ['4254175489', 'name', 'Ren Ren Ju']
# ['4254175489', 'amenity', 'restaurant']
# ['4254175489', 'cuisine', 'chinese;asian']
# ['4254175489', 'addr:street', u'建国路']
# ['4254175489', 'addr:housenumber', '138']
# ['4264095890', 'name', 'Lao Sun Jia']
# ['4264095890', 'amenity', 'restaurant']
# ['4264095890', 'addr:street', u'东大街']
# ['4264095890', 'addr:housenumber', '364']
# ['4266486298', 'amenity', 'place_of_worship']
# ['4266515989', 'amenity', 'place_of_worship']
# ['4277997592', 'name', 'Merida']
# ['4277997592', 'shop', 'bicycle']
# ['4283763373', 'name', u'侯家村镇']
# ['4283763373', 'place', 'town']
# ['4283763373', 'name:en', 'Houjiacun']
# ['4283763373', 'name:zh', u'侯家村']
# ['4283763373', 'alt_name', u'侯家村;Houjia']
# ['4283763373', 'old_name', u'侯家村乡']
# ['4283763373', 'wikipedia', u'zh:侯家村镇']
# ['4283763373', 'china_class', 'zhen']
# ['4283763373', 'source:name', 'GNS']
# ['4308319500', 'name', u'한성호공원']
# ['4308319500', 'tourism', 'attraction']
# ['4312830824', 'natural', 'tree']
# ['4318359646', 'source', 'bing']
# ['4318359646', 'highway', 'bus_stop']
# ['4325946318', 'amenity', 'fast_food']
# ['4325946318', 'cuisine', 'regional']
# ['4325946328', 'amenity', 'fast_food']
# ['4325946328', 'cuisine', 'regional']
# ['4343728090', 'name', 'grand noble hotel']
# ['4343728090', 'tourism', 'hotel']
# ['4348482493', 'name', 'Shuyuan International Party Hostel']
# ['4348482493', 'email', 'shuyuanhostel@hotmail.com']
# ['4348482493', 'tourism', 'hostel']
# ['4348482493', 'opening_hours', 'Mo-Su 08:00-20:00']
# ['4348482493', 'internet_access', 'wlan']
# ['4350394364', 'highway', 'crossing']
# ['4350394364', 'crossing', 'zebra']
# ['4358256490', 'name', 'Temple of the Eight Immortals']
# ['4358256490', 'amenity', 'place_of_worship']
# ['4374147391', 'highway', 'bus_stop']
# ['4379249095', 'name:en', 'Pit 0006']
# ['4379249095', 'tourism', 'attraction']
# ['4409659533', 'amenity', 'restaurant']
# ['4409659533', 'name', 'First Noodle under the sun']
# ['4409659533', 'name:zh', u'天下第一面 First Noodle under the sun']
# ['4422307289', 'addr:housenumber', '2']
# ['4422307289', 'addr:street', u'科技路']
# ['4422307289', 'name', u'西安市公安局出入境管理中心']
# ['4422307289', 'name:zh', u'西安市公安局出入境管理中心']
# ['4422307289', 'office', 'government']
# ['4428764298', 'natural', 'tree']
# ['4440952302', 'highway', 'crossing']
# ['4449239515', 'name', u'定一村']
# ['4449239515', 'place', 'village']
# ['4456172990', 'leisure', 'sauna']
# ['4456172990', 'name', 'mia house']
# ['4457578420', 'name', u'元三村']
# ['4457578420', 'place', 'village']
# ['4457578430', 'name', u'元南村']
# ['4457578430', 'place', 'village']
# ['4458870865', 'name', u'小王店']
# ['4458870865', 'place', 'village']
# ['4458885898', 'name', u'龙西村']
# ['4458885898', 'place', 'village']
# ['4476322586', 'name', u'定舟村北堡']
# ['4476322586', 'place', 'village']
# ['4484077813', 'name', u'沈家营村']
# ['4484077813', 'place', 'village']
# ['4493590392', 'amenity', 'cafe']
# ['4493590392', 'name:en', 'Shaanxi Thirteen']
# ['4494642682', 'name', u'渭丰镇']
# ['4494642682', 'place', 'town']
# ['4496309890', 'amenity', 'cafe']
# ['4496309890', 'name:en', 'miko cafe']
# ['4504569449', 'name', u'樊家']
# ['4504569449', 'name:en', 'Fanjia']
# ['4504569449', 'name:zh', u'樊家']
# ['4504569449', 'place', 'village']
# ['4504569449', 'source:name', 'GNS']
# ['4516285094', 'amenity', 'restaurant']
# ['4516285094', 'name', u'天下第一面 @ 吉祥村店']
# ['4516285094', 'name:zh', u'天下第一面 @ 吉祥村店']
# ['4516332392', 'name:en', 'Columbia']
# ['4516332392', 'shop', 'clothes']
# ['4516338797', 'amenity', 'restaurant']
# ['4516338797', 'name', u'老白家泡馍']
# ['4516338797', 'name:zh', u'老白家泡馍']
# ['4516349190', 'amenity', 'restaurant']
# ['4516349190', 'name', u'Bang Bang 面']
# ['4516349190', 'name:zh', u'Bang Bang 面']
# ['4524336303', 'amenity', 'police']
# ['4533656711', 'amenity', 'restaurant']
# ['4533656711', 'name', u'莉莉大盘鸡']
# ['4533656711', 'name:zh', u'莉莉大盘鸡']
# ['26173997', 'oneway', 'yes']
# ['26173997', 'highway', 'motorway_link']
# ['28257576', 'highway', 'tertiary']
# ['28258008', 'name', 'Tangyan Lu']
# ['28258008', 'lanes', '4']
# ['28258008', 'oneway', '-1']
# ['28258008', 'highway', 'primary']
# ['28258008', 'name:zh', u'唐延路']
# ['28258008', 'maxspeed', '60']
# ['28258924', 'name', u'长安北路']
# ['28258924', 'lanes', '2']
# ['28258924', 'oneway', 'yes']
# ['28258924', 'highway', 'primary']
# ['28258939', 'name', u'小寨西路']
# ['28258939', 'highway', 'primary']
# ['28258939', 'name:en', 'W. Xiaozhai Rd']
# ['28258958', 'highway', 'tertiary']
# ['28258958', 'lanes', '4']
# ['28258958', 'name', u'高薪四路 / Gaoxin Si Lu']
# ['28258958', 'name:en', 'Gaoxin 4 Road']
# ['28258958', 'oneway', 'no']
# ['28258971', 'source', 'osm-gpx']
# ['28258971', 'highway', 'path']
# ['28275322', 'highway', 'tertiary']
# ['28275322', 'name', u'光大路']
# ['28275322', 'name:en', 'Guangda Road']
# ['28294894', 'name', u'锦业路 JinYe road']
# ['28294894', 'lanes', '3']
# ['28294894', 'oneway', 'yes']
# ['28294894', 'highway', 'primary']
# ['28320649', 'name', u'二环南路西段']
# ['28320649', 'lanes', '2']
# ['28320649', 'oneway', 'yes']
# ['28320649', 'highway', 'trunk']
# ['28340417', 'name', u'二环南路']
# ['28340417', 'lanes', '2']
# ['28340417', 'oneway', 'yes']
# ['28340417', 'highway', 'trunk']
# ['28343383', 'ref', 'G3011']
# ['28343383', 'lanes', '3']
# ['28343383', 'layer', '1']
# ['28343383', 'bridge', 'yes']
# ['28343383', 'oneway', 'yes']
# ['28343383', 'highway', 'motorway']
# ['28356512', 'ref', 'S105']
# ['28356512', 'name', 'S105']
# ['28356512', 'oneway', 'no']
# ['28356512', 'highway', 'primary']
# ['28356512', 'surface', 'asphalt']
# ['28358449', 'lanes', '4']
# ['28358449', 'layer', '2']
# ['28358449', 'bridge', 'yes']
# ['28358449', 'highway', 'trunk']
# ['28358567', 'name', 'Car Repair Parking']
# ['28358567', 'amenity', 'parking']
# ['28460937', 'lanes', '2']
# ['28460937', 'layer', '2']
# ['28460937', 'bridge', 'yes']
# ['28460937', 'oneway', 'yes']
# ['28460937', 'highway', 'trunk_link']
# ['28461936', 'highway', 'secondary']
# ['28461936', 'name', u'友谊西路']
# ['28461936', 'name:en', 'You Yi West Road']
# ['28461936', 'name:zh', u'友谊西路']
# ['28461936', 'name:zh_pinyin', u'Yǒuyì Xī Lù']
# ['28461936', 'oneway', 'yes']
# ['28465736', 'name', u'新纪元公园 / Xinji Yuan Huayuan']
# ['28465736', 'leisure', 'park']
# ['28465736', 'name:en', 'New Century Park']
# ['28484384', 'highway', 'secondary']
# ['28484384', 'lanes', '4']
# ['28484384', 'name', u'东大街']
# ['28484384', 'name:en', 'East Avenue']
# ['28484384', 'name:fr', 'Avenue Est']
# ['28484384', 'name:zh', u'东大街']
# ['28484384', 'name:zh_pinyin', u'Dōng dàjiē']
# ['28484384', 'oneway', 'no']
# ['28521497', 'highway', 'service']
# ['28521497', 'service', 'parking_aisle']
# ['28521497', 'surface', 'paved']
# ['28521508', 'building', 'yes']
# ['28601776', 'highway', 'service']
# ['28601776', 'surface', 'paved']
# ['28655867', 'name', u'丈八东路']
# ['28655867', 'lanes', '2']
# ['28655867', 'oneway', 'yes']
# ['28655867', 'highway', 'primary']
# ['28655867', 'maxspeed', '60']
# ['28696875', 'highway', 'residential']
# ['28718650', 'leisure', 'park']
# ['28718660', 'highway', 'residential']
# ['28718660', 'surface', 'paved']
# ['28718672', 'highway', 'residential']
# ['28718672', 'surface', 'paved']
# ['31011873', 'source', 'bing']
# ['31011873', 'aeroway', 'taxiway']
# ['36974278', 'name', u'秦皇北路']
# ['36974278', 'oneway', 'yes']
# ['36974278', 'highway', 'primary']
# ['36974278', 'surface', 'asphalt']
# ['36990272', 'highway', 'primary_link']
# ['36990272', 'oneway', 'yes']
# ['37136025', 'highway', 'primary']
# ['39382394', 'ref', '06R/24L']
# ['39382394', 'source', 'bing']
# ['39382394', 'aeroway', 'runway']
# ['39382394', 'surface', 'paved']
# ['39820402', 'ref', 'S107']
# ['39820402', 'lanes', '2']
# ['39820402', 'oneway', 'yes']
# ['39820402', 'highway', 'primary']
# ['39820414', 'highway', 'tertiary']
# ['39820414', 'name', u'西一路']
# ['39820414', 'name:en', 'West 1st Road']
# ['39820429', 'highway', 'tertiary']
# ['39825429', 'name', u'华兴二路']
# ['39825429', 'highway', 'residential']
# ['39825444', 'name', u'玉泉东路']
# ['39825444', 'highway', 'secondary']
# ['39825471', 'highway', 'pedestrian']
# ['39825471', 'name', u'书院门 步行街']
# ['39825471', 'name:zh', u'书院门 步行街']
# ['40541062', 'highway', 'tertiary']
# ['40541062', 'name', u'南马道巷']
# ['42245047', 'layer', '1']
# ['42245047', 'bridge', 'yes']
# ['42245047', 'oneway', 'yes']
# ['42245047', 'highway', 'primary_link']
# ['42245079', 'name', u'陇海线']
# ['42245079', 'gauge', '1435']
# ['42245079', 'layer', '1']
# ['42245079', 'usage', 'main']
# ['42245079', 'bridge', 'yes']
# ['42245079', 'name:en', 'Longhai Line']
# ['42245079', 'name:zh', u'陇海线']
# ['42245079', 'railway', 'rail']
# ['42245079', 'voltage', '25000']
# ['42245079', 'frequency', '50']
# ['42245079', 'electrified', 'contact_line']
# ['47848026', 'name', u'翠华路']
# ['47848026', 'oneway', 'yes']
# ['47848026', 'highway', 'secondary']
# ['48795850', 'highway', 'secondary']
# ['48795850', 'name', u'南广济街']
# ['48795850', 'name:en', 'South Guangji Street']
# ['48795850', 'name:zh', u'南广济街']
# ['48795850', 'name:zh_pinyin', u'nán guǎng jì jiē']
# ['48795850', 'oneway', 'yes']
# ['52014726', 'oneway', 'yes']
# ['52014726', 'source', 'GPS']
# ['52014726', 'highway', 'secondary']
# ['52243966', 'source', 'GPS']
# ['52243966', 'highway', 'unclassified']
# ['52244433', 'lanes', '3']
# ['52244433', 'oneway', 'yes']
# ['52244433', 'highway', 'motorway']
# ['52244433', 'surface', 'asphalt']
# ['52244445', 'name', u'北三环辅道']
# ['52244445', 'oneway', 'yes']
# ['52244445', 'source', 'GPS']
# ['52244445', 'highway', 'trunk']
# ['53799941', 'mtb', 'yes']
# ['53799941', 'ref', 'G108;G310']
# ['53799941', 'note', 'conventional trunk road superceded by expressway']
# ['53799941', 'source', 'osm-gpx']
# ['53799941', 'highway', 'trunk']
# ['55682774', 'name', u'建国路']
# ['55682774', 'highway', 'residential']
# ['55691493', 'oneway', 'yes']
# ['55691493', 'highway', 'secondary']
# ['55696761', 'highway', 'unclassified']
# ['55696761', 'name', u'白沙路 / Baisha Lu']
# ['55696761', 'name:en', 'Baisha Road']
# ['59128845', 'highway', 'secondary']
# ['59128845', 'name', u'东七路']
# ['59128845', 'name:en', 'East 7th Road']
# ['59128845', 'oneway', 'yes']
# ['59140292', 'name', u'北曹家巷']
# ['59140292', 'highway', 'residential']
# ['59140292', 'name:en', 'Beicaojia']
# ['59140302', 'highway', 'unclassified']
# ['59140313', 'highway', 'residential']
# ['59140338', 'highway', 'tertiary']
# ['59140338', 'oneway', 'yes']
# ['59140350', 'highway', 'tertiary']
# ['59140350', 'name', u'西北一路']
# ['59140350', 'name:en', 'Northwest 1st Road']
# ['59140350', 'oneway', 'yes']
# ['59868404', 'highway', 'tertiary']
# ['59868404', 'name', u'大麦市街']
# ['59868404', 'name:en', 'Damaishi Street']
# ['59868422', 'highway', 'residential']
# ['59868422', 'name', u'东十道巷']
# ['59868422', 'name:en', 'East 10th Alley']
# ['59868440', 'highway', 'residential']
# ['59868440', 'name', u'教场门']
# ['59868440', 'name:en', 'Jiaochangmen']
# ['59868464', 'highway', 'residential']
# ['59870439', 'gauge', '1435']
# ['59870439', 'layer', '1']
# ['59870439', 'usage', 'main']
# ['59870439', 'bridge', 'yes']
# ['59870439', 'railway', 'rail']
# ['59870439', 'maxspeed', '350']
# ['59870439', 'highspeed', 'yes']
# ['63681715', 'source', 'GPS']
# ['63681715', 'highway', 'secondary']
# ['64931686', 'name', 'Jianguo Hotel']
# ['64931686', 'tourism', 'hotel']
# ['64931686', 'building', 'yes']
# ['71235646', 'building', 'yes']
# ['71235662', 'building', 'yes']
# ['71235674', 'building', 'yes']
# ['71235684', 'name', u'兵马俑二号坑']
# ['71235684', 'name:de', u'Terracotta Krieger Ausgrabungsstätte 2']
# ['71235684', 'name:en', 'Terracotta Warrior Pit 2']
# ['71235684', 'building', 'yes']
# ['71235694', 'building', 'yes']
# ['71394420', 'ref', 'G210']
# ['71394420', 'name', 'Xiwan Gong Lu']
# ['71394420', 'lanes', '4']
# ['71394420', 'oneway', 'yes']
# ['71394420', 'source', 'GPS']
# ['71394420', 'highway', 'primary']
# ['71394491', 'source', 'GPS']
# ['71394491', 'highway', 'tertiary']
# ['80237910', 'ref', 'G3001']
# ['80237910', 'lanes', '3']
# ['80237910', 'layer', '1']
# ['80237910', 'bridge', 'yes']
# ['80237910', 'oneway', 'yes']
# ['80237910', 'highway', 'motorway']
# ['80238866', 'bridge', 'yes']
# ['80238866', 'highway', 'motorway_link']
# ['80238866', 'layer', '1']
# ['80238866', 'oneway', 'yes']
# ['80239373', 'ref', 'G3001']
# ['80239373', 'name', 'G3001']
# ['80239373', 'lanes', '3']
# ['80239373', 'oneway', 'yes']
# ['80239373', 'highway', 'motorway']
# ['80239373', 'surface', 'asphalt']
# ['80240744', 'ref', 'G3001']
# ['80240744', 'name', 'G3011']
# ['80240744', 'lanes', '3']
# ['80240744', 'layer', '1']
# ['80240744', 'bridge', 'yes']
# ['80240744', 'oneway', 'yes']
# ['80240744', 'highway', 'motorway']
# ['80443131', 'source', 'GPS']
# ['80443131', 'highway', 'tertiary']
# ['80500050', 'highway', 'unclassified']
# ['80502765', 'source', 'Lakewalker / Landsat']
# ['80502786', 'name', u'迎宾大道']
# ['80502786', 'lanes', '3']
# ['80502786', 'oneway', 'yes']
# ['80502786', 'highway', 'primary']
# ['80502786', 'surface', 'asphalt']
# ['83497356', 'oneway', 'yes']
# ['83497356', 'highway', 'trunk_link']
# ['83557214', 'name', u'二环东路']
# ['83557214', 'lanes', '2']
# ['83557214', 'layer', '1']
# ['83557214', 'bridge', 'yes']
# ['83557214', 'oneway', 'yes']
# ['83557214', 'highway', 'trunk']
# ['84014108', 'name', u'二环东路']
# ['84014108', 'layer', '1']
# ['84014108', 'bridge', 'yes']
# ['84014108', 'oneway', 'yes']
# ['84014108', 'source', 'osm-gpx']
# ['84014108', 'highway', 'trunk']
# ['84014119', 'oneway', 'yes']
# ['84014119', 'source', 'osm-gpx']
# ['84014119', 'highway', 'trunk']
# ['84170167', 'ref', 'G5']
# ['84170167', 'name', u'西汉高速']
# ['84170167', 'lanes', '2']
# ['84170167', 'layer', '1']
# ['84170167', 'bridge', 'yes']
# ['84170167', 'oneway', 'yes']
# ['84170167', 'source', 'Bing']
# ['84170167', 'highway', 'motorway']
# ['84170167', 'name:en', 'Xihan Expressway']
# ['85318488', 'aerialway', 'cable_car']
# ['88216827', 'name', 'Huaqing Hot Springs']
# ['88216827', 'leisure', 'park']
# ['93087711', 'layer', '1']
# ['93087711', 'bridge', 'yes']
# ['93087711', 'oneway', 'yes']
# ['93087711', 'highway', 'motorway_link']
# ['93087726', 'lanes', '2']
# ['93087726', 'oneway', 'yes']
# ['93087726', 'highway', 'motorway_link']
# ['93483183', 'ref', 'G5']
# ['93483183', 'name', u'西汉高速']
# ['93483183', 'oneway', 'yes']
# ['93483183', 'source', 'GPS']
# ['93483183', 'highway', 'motorway_link']
# ['93483183', 'name:en', 'Xihan Expressway']
# ['93483883', 'highway', 'tertiary']
# ['93483883', 'name', u'渭滨路']
# ['93484769', 'highway', 'residential']
# ['93484782', 'highway', 'unclassified']
# ['93484782', 'name', u'瞪羚路']
# ['93484782', 'oneway', 'no']
# ['120859725', 'ref', 'G5']
# ['120859725', 'name', u'西禹高速']
# ['120859725', 'oneway', 'yes']
# ['120859725', 'highway', 'motorway']
# ['120859725', 'name:en', 'Xiyu Expressway']
# ['120859749', 'ref', 'G3001']
# ['120859749', 'name', 'G3001']
# ['120859749', 'lanes', '3']
# ['120859749', 'oneway', 'yes']
# ['120859749', 'highway', 'motorway']
# ['120859762', 'ref', 'G5']
# ['120859762', 'note', 'fixme']
# ['120859762', 'lanes', '2']
# ['120859762', 'layer', '1']
# ['120859762', 'oneway', 'yes']
# ['120859762', 'highway', 'motorway_link']
# ['120859775', 'ref', 'G3001']
# ['120859775', 'name', 'G3011']
# ['120859775', 'lanes', '3']
# ['120859775', 'oneway', 'yes']
# ['120859775', 'highway', 'motorway']
# ['120859792', 'ref', 'G3001']
# ['120859792', 'name', 'G3001']
# ['120859792', 'lanes', '3']
# ['120859792', 'layer', '1']
# ['120859792', 'bridge', 'yes']
# ['120859792', 'oneway', 'yes']
# ['120859792', 'highway', 'motorway']
# ['120859808', 'oneway', 'yes']
# ['120859808', 'highway', 'motorway_link']
# ['120860302', 'ref', 'G30']
# ['120860302', 'name', u'西潼高速']
# ['120860302', 'lanes', '4']
# ['120860302', 'layer', '2']
# ['120860302', 'bridge', 'yes']
# ['120860302', 'oneway', 'yes']
# ['120860302', 'source', 'GPS']
# ['120860302', 'highway', 'motorway']
# ['120860302', 'int_ref', 'AH34']
# ['120860302', 'name:en', 'Xitong Expressway']
# ['123173003', 'highway', 'unclassified']
# ['123173003', 'name', u'纺建路']
# ['123178266', 'highway', 'tertiary']
# ['123178276', 'highway', 'tertiary_link']
# ['123178286', 'bridge', 'yes']
# ['123178286', 'highway', 'footway']
# ['123288575', 'highway', 'path']
# ['123288585', 'highway', 'unclassified']
# ['123288595', 'highway', 'path']
# ['123288605', 'highway', 'primary_link']
# ['123288605', 'name', u'渭阳西路']
# ['123288605', 'name:en', 'Weiyang West Rd']
# ['123288605', 'surface', 'asphalt']
# ['123290416', 'name', u'段家路']
# ['123290416', 'highway', 'tertiary']
# ['126867251', 'source', 'bing']
# ['126867251', 'aeroway', 'taxiway']
# ['126868787', 'name', u'陇海线']
# ['126868787', 'gauge', '1435']
# ['126868787', 'layer', '-1']
# ['126868787', 'usage', 'main']
# ['126868787', 'tunnel', 'yes']
# ['126868787', 'name:en', 'Longhai Line']
# ['126868787', 'name:zh', u'陇海线']
# ['126868787', 'railway', 'rail']
# ['126868787', 'voltage', '25000']
# ['126868787', 'frequency', '50']
# ['126868787', 'electrified', 'contact_line']
# ['126868805', 'source', 'bing']
# ['126868805', 'highway', 'road']
# ['126868824', 'source', 'bing']
# ['126868824', 'aeroway', 'taxiway']
# ['136069070', 'name', u'纺一路']
# ['136069070', 'highway', 'tertiary']
# ['136069080', 'name', u'二环北路']
# ['136069080', 'layer', '1']
# ['136069080', 'bridge', 'yes']
# ['136069080', 'oneway', '-1']
# ['136069080', 'highway', 'trunk']
# ['136069092', 'oneway', 'yes']
# ['136069092', 'highway', 'trunk_link']
# ['136069102', 'oneway', 'yes']
# ['136069102', 'highway', 'motorway_link']
# ['136069118', 'name', u'灞柳西路']
# ['136069118', 'source', 'osm-gpx']
# ['136069118', 'highway', 'secondary']
# ['136069118', 'embankment', 'yes']
# ['137189546', 'highway', 'residential']
# ['137828491', 'highway', 'pedestrian']
# ['137828491', 'surface', 'asphalt']
# ['137931772', 'highway', 'footway']
# ['137931787', 'highway', 'footway']
# ['137931930', 'highway', 'pedestrian']
# ['139639996', 'source', 'GPS']
# ['139639996', 'highway', 'residential']
# ['139653072', 'flagfp', '1']
# ['139653072', 'oneway', 'yes']
# ['139653072', 'source', 'GPS']
# ['139653072', 'highway', 'primary']
# ['139653072', 'lanes:end', '2']
# ['139653072', 'lanes:start', '2']
# ['139653602', 'layer', '1']
# ['139653602', 'bridge', 'yes']
# ['139653602', 'source', 'GPS']
# ['139653602', 'highway', 'tertiary']
# ['139653616', 'source', 'GPS']
# ['139653616', 'highway', 'residential']
# ['139663858', 'name', u'陇海线']
# ['139663858', 'gauge', '1435']
# ['139663858', 'name:en', 'Longhai Line']
# ['139663858', 'name:zh', u'陇海线']
# ['139663858', 'railway', 'rail']
# ['139663858', 'voltage', '25000']
# ['139663858', 'frequency', '50']
# ['139663858', 'electrified', 'contact_line']
# ['139663891', 'ref', 'G30']
# ['139663891', 'name', u'西潼高速']
# ['139663891', 'lanes', '4']
# ['139663891', 'oneway', 'yes']
# ['139663891', 'source', 'GPS']
# ['139663891', 'highway', 'motorway']
# ['139663891', 'int_ref', 'AH34']
# ['139663891', 'name:en', 'Xitong Expressway']
# ['139663930', 'ref', 'G5']
# ['139663930', 'name', u'西禹高速']
# ['139663930', 'layer', '1']
# ['139663930', 'bridge', 'yes']
# ['139663930', 'oneway', 'yes']
# ['139663930', 'highway', 'motorway']
# ['139663930', 'name:en', 'Xiyu Expressway']
# ['139663960', 'source', 'bing']
# ['139663960', 'highway', 'tertiary']
# ['139663986', 'railway', 'rail']
# ['139663986', 'service', 'yard']
# ['139663986', 'source', 'bing']
# ['139664010', 'layer', '1']
# ['139664010', 'bridge', 'yes']
# ['139664010', 'railway', 'rail']
# ['139664037', 'layer', '1']
# ['139664037', 'bridge', 'yes']
# ['139664037', 'source', 'bing']
# ['139664037', 'railway', 'rail']
# ['139664094', 'source', 'bing']
# ['139664094', 'railway', 'rail']
# ['139749138', 'ref', 'G30']
# ['139749138', 'name', u'西潼高速']
# ['139749138', 'lanes', '4']
# ['139749138', 'oneway', 'yes']
# ['139749138', 'source', 'GPS']
# ['139749138', 'highway', 'motorway']
# ['139749138', 'int_ref', 'AH34']
# ['139749138', 'name:en', 'Xitong Expressway']
# ['139828166', 'source', 'bing']
# ['139828166', 'highway', 'tertiary']
# ['139828180', 'source', 'bing']
# ['139828180', 'highway', 'residential']
# ['139828207', 'oneway', 'yes']
# ['139828207', 'source', 'bing']
# ['139828207', 'highway', 'motorway_link']
# ['139828217', 'layer', '1']
# ['139828217', 'bridge', 'yes']
# ['139828217', 'source', 'bing']
# ['139828217', 'railway', 'rail']
# ['139828229', 'layer', '1']
# ['139828229', 'bridge', 'yes']
# ['139828229', 'source', 'bing']
# ['139828229', 'railway', 'rail']
# ['139828241', 'source', 'bing']
# ['139828241', 'railway', 'rail']
# ['139828251', 'source', 'bing']
# ['139828251', 'building', 'yes']
# ['141301306', 'ref', 'G108']
# ['141301306', 'name', u'仓程路']
# ['141301306', 'highway', 'trunk']
# ['141664626', 'ref', 'G30']
# ['141664626', 'name', u'西宝高速']
# ['141664626', 'lanes', '2; 4']
# ['141664626', 'oneway', 'yes']
# ['141664626', 'highway', 'motorway']
# ['141664626', 'int_ref', 'AH5']
# ['141664626', 'name:en', 'Xibao Expressway']
# ['142320595', 'highway', 'residential']
# ['142320595', 'name:en', 'West Kaitong Alley']
# ['142321460', 'highway', 'primary']
# ['142321460', 'name', u'西五路']
# ['142321460', 'name:en', 'West 5th Road']
# ['142321460', 'name:zh', u'西五路']
# ['142321460', 'oneway', 'yes']
# ['142323468', 'lanes', '4']
# ['142323468', 'highway', 'primary']
# ['142323478', 'highway', 'unclassified']
# ['142323478', 'lanes', '2']
# ['142323478', 'name', u'新开门南路 New Open Door South Rd']
# ['142323478', 'name:en', 'New Open Door South Rd']
# ['142323478', 'name:zh', u'新开门南路']
# ['142323478', 'name:zh_pinyin', u'Xīn kāi mén nán lù']
# ['142323478', 'oneway', 'no']
# ['142323478', 'width', '15']
# ['142323700', 'highway', 'service']
# ['142429400', 'name', u'大雁塔南广场']
# ['142429400', 'landuse', 'grass']
# ['142430845', 'highway', 'secondary']
# ['142432188', 'highway', 'unclassified']
# ['142432188', 'name', u'草场坡']
# ['142432188', 'name:en', 'Caochangpo']
# ['144435136', 'source', 'GPS']
# ['144435136', 'highway', 'tertiary']
# ['145112458', 'ref', 'G65']
# ['145112458', 'lanes', '2']
# ['145112458', 'oneway', 'yes']
# ['145112458', 'source', 'bing']
# ['145112458', 'highway', 'motorway']
# ['145112469', 'ref', 'G65']
# ['145112469', 'lanes', '2']
# ['145112469', 'layer', '-1']
# ['145112469', 'oneway', 'yes']
# ['145112469', 'source', 'bing']
# ['145112469', 'tunnel', 'yes']
# ['145112469', 'highway', 'motorway']
# ...
# ['446811764', 'building', 'yes']
# ['446811774', 'highway', 'tertiary']
# ['446811774', 'name', u'西甜水井巷']
# ['446812604', 'building', 'yes']
# ['446812614', 'building', 'yes']
# ['446815757', 'barrier', 'wall']
# ['446815767', 'building', 'yes']
# ['446815777', 'building', 'yes']
# ['446815788', 'building', 'yes']
# ['446815799', 'building', 'yes']
# ['446815809', 'access', 'private']
# ['446815809', 'highway', 'service']
# ['446815809', 'service', 'alley']
# ['446874243', 'bicycle', 'yes']
# ['446874243', 'cycleway', 'lane']
# ['446874243', 'foot', 'yes']
# ['446874243', 'highway', 'tertiary']
# ['446874243', 'lanes', '2']
# ['446874243', 'maxspeed', '60']
# ['446874243', 'name', u'高新六路 / Gaoxin Liu Lu']
# ['446874243', 'name:en', 'Gaoxin 6 Road']
# ['446874243', 'name:zh', u'高新六路']
# ['446874243', 'name:zh_pinyin', 'Gaoxin Liu Lu']
# ['446874243', 'oneway', 'yes']
# ['446874243', 'sidewalk', 'both']
# ['446874243', 'surface', 'cobblestone']
# ['446874254', 'highway', 'residential']
# ['446874264', 'bicycle', 'yes']
# ['446874264', 'cycleway', 'lane']
# ['446874264', 'foot', 'yes']
# ['446874264', 'highway', 'tertiary']
# ['446874264', 'lanes', '2']
# ['446874264', 'maxspeed', '60']
# ['446874264', 'name', u'高新六路 / Gaoxin Liu Lu']
# ['446874264', 'name:en', 'Gaoxin 6 Road']
# ['446874264', 'name:zh', u'高新六路']
# ['446874264', 'name:zh_pinyin', 'Gaoxin Liu Lu']
# ['446874264', 'oneway', 'yes']
# ['446874264', 'sidewalk', 'both']
# ['446874264', 'surface', 'cobblestone']
# ['446874276', 'highway', 'primary']
# ['446874276', 'lanes', '2']
# ['446874276', 'oneway', 'no']
# ['446874276', 'ref', 'G312']
# ['446878869', 'highway', 'residential']
# ['446878879', 'highway', 'secondary']
# ['446878879', 'lanes', '2']
# ['446878879', 'oneway', 'yes']
# ['446878889', 'highway', 'residential']
# ['446878899', 'highway', 'residential']
# ['446878899', 'oneway', 'yes']
# ['446878909', 'highway', 'residential']
# ['446946765', 'building:part', 'yes']
# ['446946765', 'height', '7.7']
# ['446946765', 'min_height', '6.2']
# ['447230394', 'highway', 'residential']
# ['447231624', 'highway', 'residential']
# ['447232335', 'highway', 'residential']
# ['447288635', 'building', 'yes']
# ['447288645', 'building', 'yes']
# ['447288655', 'building', 'yes']
# ['447288667', 'building', 'yes']
# ['447288677', 'building', 'yes']
# ['447288687', 'building', 'yes']
# ['447288698', 'building', 'yes']
# ['447288715', 'building', 'yes']
# ['447288729', 'highway', 'service']
# ['447288745', 'access', 'private']
# ['447288745', 'highway', 'service']
# ['447365572', 'building', 'yes']
# ['447365582', 'building', 'yes']
# ['447365592', 'building', 'yes']
# ['447365602', 'building', 'yes']
# ['447365612', 'highway', 'service']
# ['447365612', 'service', 'parking_aisle']
# ['447389658', 'highway', 'residential']
# ['447554166', 'highway', 'trunk']
# ['447554166', 'lanes', '4']
# ['447554166', 'layer', '0']
# ['447554166', 'name', u'环城西路']
# ['447556641', 'highway', 'primary']
# ['447556641', 'oneway', 'yes']
# ['447556641', 'tunnel', 'building_passage']
# ['447556651', 'highway', 'footway']
# ['447556663', 'highway', 'secondary']
# ['447556663', 'oneway', 'yes']
# ['447556681', 'highway', 'primary']
# ['447556681', 'lanes', '2']
# ['447556681', 'name', u'北大街']
# ['447556681', 'name:en', 'North Avenue']
# ['447556681', 'name:fr', 'Avenue Nord']
# ['447556681', 'name:zh', u'北大街']
# ['447556681', 'name:zh_pinyin', u'Běi dàjiē']
# ['447556681', 'oneway', 'yes']
# ['447556691', 'highway', 'tertiary']
# ['447556691', 'name', u'四府街']
# ['447556691', 'tunnel', 'building_passage']
# ['447563404', 'building:part', 'yes']
# ['447563419', 'highway', 'footway']
# ['447563436', 'bicycle', 'yes']
# ['447563436', 'foot', 'yes']
# ['447563436', 'highway', 'path']
# ['447563436', 'layer', '1']
# ['447563454', 'highway', 'footway']
# ['447563454', 'tunnel', 'building_passage']
# ['447563473', 'bicycle', 'yes']
# ['447563473', 'foot', 'yes']
# ['447563473', 'highway', 'path']
# ['447563473', 'layer', '1']
# ['447651420', 'highway', 'residential']
# ['447653002', 'landuse', 'residential']
# ['447681680', 'highway', 'residential']
# ['447735826', 'building', 'yes']
# ['447735836', 'building', 'yes']
# ['447735846', 'highway', 'secondary']
# ['447735846', 'oneway', 'yes']
# ['447735846', 'tunnel', 'building_passage']
# ['448271311', 'highway', 'residential']
# ['448503682', 'highway', 'residential']
# ['448503692', 'highway', 'residential']
# ['448503702', 'landuse', 'residential']
# ['448504272', 'highway', 'residential']
# ['448504754', 'highway', 'residential']
# ['448620266', 'building', 'yes']
# ['448620279', 'barrier', 'retaining_wall']
# ['448693708', 'building:part', 'yes']
# ['448693708', 'height', '60']
# ['448693729', 'building', 'yes']
# ['448693744', 'building', 'yes']
# ['448693754', 'building', 'yes']
# ['448693770', 'building', 'yes']
# ['448693790', 'highway', 'service']
# ['448693790', 'service', 'parking_aisle']
# ['448778709', 'bridge', 'yes']
# ['448778709', 'highway', 'footway']
# ['448779980', 'highway', 'residential']
# ['448779990', 'highway', 'residential']
# ['448813590', 'amenity', 'school']
# ['448813590', 'name', u'陕西国防工业职业技术学院南校区']
# ['448817087', 'amenity', 'school']
# ['448817087', 'name', u'户县善慧小学']
# ['448907638', 'landuse', 'residential']
# ['448907638', 'name', u'西安石油大学生活区']
# ['448915635', 'landuse', 'residential']
# ['448915635', 'name', u'小王店村']
# ['448915645', 'landuse', 'residential']
# ['448917437', 'landuse', 'residential']
# ['448918644', 'highway', 'primary']
# ['448918644', 'name', u'108国道']
# ['449218810', 'building', 'yes']
# ['449218820', 'building', 'yes']
# ['449218830', 'building', 'yes']
# ['449218840', 'building', 'yes']
# ['449218850', 'building', 'yes']
# ['449218860', 'building', 'yes']
# ['449218873', 'building', 'yes']
# ['449218894', 'building', 'yes']
# ['449527704', 'highway', 'track']
# ['449528406', 'highway', 'residential']
# ['449529301', 'highway', 'residential']
# ['450718167', 'amenity', 'library']
# ['450718167', 'building', 'yes']
# ['450718167', 'name', u'新区博闻楼图书馆']
# ['450727594', 'highway', 'residential']
# ['450729291', 'highway', 'residential']
# ['451575448', 'building', 'school']
# ['451575448', 'name', u'综合楼']
# ['451575459', 'building', 'school']
# ['451575471', 'leisure', 'pitch']
# ['451575471', 'name', u'足球场']
# ['451575471', 'sport', 'soccer']
# ['451579758', 'leisure', 'garden']
# ['451580290', 'leisure', 'garden']
# ['451580290', 'name', u'花园']
# ['451583770', 'landuse', 'residential']
# ['451583770', 'name', u'惠南社区']
# ['451585067', 'amenity', 'bus_station']
# ['451585067', 'building', 'yes']
# ['451585067', 'name', u'户县汽车北站']
# ['452244455', 'highway', 'residential']
# ['452245345', 'highway', 'residential']
# ['452246149', 'highway', 'residential']
# ['452246903', 'highway', 'residential']
# ['452413373', 'highway', 'residential']
# ['452416393', 'highway', 'unclassified']
# ['452417680', 'highway', 'residential']
# ['452418880', 'highway', 'residential']
# ['452594080', 'highway', 'secondary']
# ['452596041', 'landuse', 'residential']
# ['452723715', 'building', 'school']
# ['452723725', 'building', 'school']
# ['452723735', 'building', 'school']
# ['452723745', 'building', 'school']
# ['452723755', 'building', 'school']
# ['452742786', 'highway', 'path']
# ['452743332', 'landuse', 'residential']
# ['452757621', 'highway', 'tertiary']
# ['453712589', 'highway', 'residential']
# ['453714088', 'highway', 'residential']
# ['453715250', 'highway', 'residential']
# ['453767360', 'highway', 'secondary']
# ['453767360', 'ref', 'X225']
# ['453767370', 'highway', 'tertiary']
# ['453767370', 'source', 'bing']
# ['453767380', 'highway', 'residential']
# ['453767380', 'source', 'bing']
# ['453767391', 'highway', 'track']
# ['453767391', 'source', 'bing']
# ['453767401', 'highway', 'unclassified']
# ['453767401', 'source', 'bing']
# ['453785577', 'building', 'yes']
# ['453785587', 'building', 'yes']
# ['453786113', 'building', 'yes']
# ['453789375', 'building', 'yes']
# ['453789385', 'building', 'yes']
# ['453789395', 'building', 'yes']
# ['453791011', 'building', 'yes']
# ['453795358', 'building', 'yes']
# ['453799294', 'building', 'yes']
# ['453799821', 'building', 'yes']
# ['453800709', 'building', 'yes']
# ['453805863', 'building', 'yes']
# ['453805873', 'building', 'yes']
# ['453805883', 'building', 'yes']
# ['453805893', 'building', 'yes']
# ['453805905', 'building', 'yes']
# ['453805915', 'building', 'yes']
# ['453805925', 'building', 'yes']
# ['453805935', 'building', 'yes']
# ['453805945', 'building', 'yes']
# ['453805955', 'building', 'yes']
# ['453805965', 'building', 'yes']
# ['453805978', 'building', 'yes']
# ['453805995', 'building', 'yes']
# ['453806006', 'building', 'yes']
# ['453806016', 'building', 'yes']
# ['453806327', 'building', 'yes']
# ['453806872', 'building', 'yes']
# ['453981537', 'highway', 'residential']
# ['455471301', 'highway', 'residential']
# ['455471926', 'highway', 'residential']
# ['455473611', 'highway', 'residential']
# ['455700854', 'highway', 'secondary']
# ['455700854', 'name', u'朱雀大街']
# ['456108252', 'building', 'yes']
# ['456108262', 'building', 'yes']
# ['456108272', 'building', 'yes']
# ['456110040', 'building', 'yes']
# ['456110050', 'building', 'yes']
# ['456110060', 'building', 'yes']
# ['456111343', 'highway', 'service']
# ['456111343', 'service', 'alley']
# ['456111355', 'building', 'yes']
# ['456111365', 'building', 'yes']
# ['456111375', 'building', 'yes']
# ['456112279', 'building', 'yes']
# ['456112687', 'building', 'yes']
# ['456113110', 'building', 'yes']
# ['456113120', 'building', 'yes']
# ['456113131', 'building', 'yes']
# ['456113141', 'building', 'yes']
# ['456113151', 'building', 'yes']
# ['456114496', 'highway', 'secondary']
# ['456114496', 'oneway', 'yes']
# ['456114506', 'building', 'yes']
# ['456117764', 'building', 'yes']
# ['456117774', 'building', 'yes']
# ['456117785', 'building', 'yes']
# ['456117795', 'building', 'yes']
# ['456117805', 'building', 'yes']
# ['456117815', 'building', 'yes']
# ['456153805', 'electrified', 'contact_line']
# ['456153805', 'frequency', '50']
# ['456153805', 'gauge', '1435']
# ['456153805', 'railway', 'rail']
# ['456153815', 'building', 'yes']
# ['456153825', 'highway', 'footway']
# ['456590004', 'highway', 'residential']
# ['456590016', 'highway', 'residential']
# ['456591244', 'highway', 'residential']
# ['456621630', 'building', 'yes']
# ['456621640', 'building', 'yes']
# ['456621650', 'building', 'yes']
# ['456621660', 'building', 'yes']
# ['456638525', 'building', 'yes']
# ['456638535', 'building', 'yes']
# ['456638546', 'building', 'yes']
# ['456638556', 'building', 'yes']
# ['456638566', 'building', 'yes']
# ['456638576', 'building', 'yes']
# ['456638586', 'building', 'yes']
# ['456638596', 'highway', 'service']
# ['456638608', 'highway', 'residential']
# ['456638620', 'building', 'yes']
# ['456638630', 'highway', 'service']
# ['456638640', 'building', 'yes']
# ['456638650', 'building', 'yes']
# ['456638660', 'building', 'yes']
# ['456638670', 'area', 'no']
# ['456638670', 'leisure', 'track']
# ['457035237', 'highway', 'residential']
# ['457035237', 'name', u'西仓巷']
# ['457035237', 'name:en', 'Xichang Alley']
# ['457035247', 'highway', 'residential']
# ['457042939', 'highway', 'secondary']
# ['457042939', 'oneway', 'yes']
# ['457047968', 'highway', 'unclassified']
# ['457047968', 'lanes', '2']
# ['457047968', 'oneway', 'yes']
# ['457067469', 'highway', 'service']
# ['457087640', 'highway', 'primary']
# ['457087640', 'oneway', 'yes']
# ['457090723', 'highway', 'residential']
# ['457090723', 'surface', 'asphalt']
# ['457090733', 'highway', 'unclassified']
# ['457090743', 'highway', 'tertiary']
# ['457090743', 'name', u'凤城二路']
# ['457090743', 'source', 'bing']
# ['457092000', 'covered', 'yes']
# ['457092000', 'highway', 'unclassified']
# ['457092000', 'layer', '-1']
# ['457094765', 'highway', 'unclassified']
# ['457277789', 'highway', 'residential']
# ['457277799', 'highway', 'residential']
# ['457277809', 'highway', 'residential']
# ['457277819', 'highway', 'secondary']
# ['457277830', 'highway', 'secondary']
# ['457277830', 'lanes', '2']
# ['457277830', 'oneway', 'yes']
# ['457301946', 'highway', 'residential']
# ['457301946', 'name', u'电子东街']
# ['457301956', 'highway', 'unclassified']
# ['457301956', 'name', u'天谷八路']
# ['457301956', 'source', 'Bing']
# ['457301967', 'bridge', 'yes']
# ['457301967', 'highway', 'tertiary']
# ['457301967', 'layer', '1']
# ['457301967', 'maxspeed', '70']
# ['457301967', 'name', 'Keji 7 road']
# ['457301977', 'highway', 'unclassified']
# ['457307900', 'highway', 'residential']
# ['457307900', 'name', u'北新街']
# ['457307900', 'name:en', 'Beixing Street']
# ['457336029', 'highway', 'tertiary']
# ['457336029', 'name', u'纺渭路']
# ['457336069', 'highway', 'residential']
# ['457336094', 'highway', 'unclassified']
# ['457336094', 'name', u'公园北路']
# ['457340032', 'highway', 'unclassified']
# ['457340032', 'name', u'柳虹路']
# ['457344965', 'highway', 'unclassified']
# ['457344965', 'name', u'新广路']
# ['457643057', 'landuse', 'recreation_ground']
# ['403556', 'ref', 'G210']
# ['403556', 'name', u'210国道']
# ['403556', 'type', 'route']
# ['403556', 'route', 'road']
# ['403556',
#  'description',
#  'G210 runs from Baotou,Inner Mongolia to Nanning,Guangxi Province']
# ['918885', 'alt_name', u'包茂高速']
# ['918885',
#  'description',
#  'G65 connects Baotou, Inner Mongolia and Maoming, Guangdong.']
# ['918885', 'name', u'G65 包茂高速公路']
# ['918885', 'name:en', 'G65 Baomao Expressway']
# ['918885', 'network', 'CN-expressways']
# ['918885', 'ref', 'G65']
# ['918885', 'route', 'road']
# ['918885', 'type', 'route']
# ['1992417', 'name', u'咸铜铁路']
# ['1992417', 'type', 'route']
# ['1992417', 'route', 'railway']
# ['1992417', 'name:en', 'Xiantong Railway']
# ['1992417', 'name:zh', u'咸铜铁路']
# ['1992417', 'network', 'CN-railway']
# ['1992417', 'wikipedia', u'zh:咸铜铁路']
# ['1992417', 'name:zh_pinyin', u'xiántóng tiĕlù']
# ['2971129', 'admin_level', '5']
# ['2971129', 'boundary', 'administrative']
# ['2971129', 'int_name', 'Shangluo']
# ['2971129', 'name', u'商洛市 / Shangluo']
# ['2971129', 'name:en', 'Shangluo City']
# ['2971129', 'name:ja', u'商洛市']
# ['2971129', 'name:zh', u'商洛市']
# ['2971129', 'name:zh_py', u'Shāngluò Shì']
# ['2971129', 'type', 'boundary']
# ['2971129', 'wikidata', 'Q515983']
# ['2971129', 'wikipedia', u'zh:商洛市']
# ['3048442', 'admin_level', '5']
# ['3048442', 'boundary', 'administrative']
# ['3048442', 'name', u'宝鸡市 / Baoji']
# ['3048442', 'name:en', 'Baoji City']
# ['3048442', 'name:ja', u'宝鶏市']
# ['3048442', 'name:zh', u'宝鸡市']
# ['3048442', 'name:zh_pinyin', u'Bǎojī Shì']
# ['3048442', 'type', 'boundary']
# ['3048442', 'wikipedia:en', 'Baoji']
# ['3221014', 'admin_level', '6']
# ['3221014', 'boundary', 'administrative']
# ['3221014', 'name', u'渭城区 (Weicheng)']
# ['3221014', 'name:en', 'Weicheng District']
# ['3221014', 'name:zh', u'渭城区']
# ['3221014', 'name:zh_pinyin', u'Wèichéng Qū']
# ['3221014', 'type', 'boundary']
# ['3221014', 'wikidata', 'Q1201166']
# ['3221014', 'wikipedia', 'en:Weicheng District, Xianyang']
# ['3226090', 'admin_level', '6']
# ['3226090', 'boundary', 'administrative']
# ['3226090', 'name', u'高陵县 (Gaoling)']
# ['3226090', 'name:en', 'Gaoling County']
# ['3226090', 'name:zh', u'高陵县']
# ['3226090', 'name:zh_pinyin', u'Gāolíng Xiàn']
# ['3226090', 'type', 'boundary']
# ['3226090', 'wikidata', 'Q280060']
# ['3226090', 'wikipedia', u'zh:高陵区']
# ['3226100', 'name', u'渼陂湖']
# ['3226100', 'natural', 'water']
# ['3226100', 'type', 'multipolygon']
# ['3226100', 'website', 'http://zjq.in']
# ['3377434', 'type', 'multipolygon']
# ['3377434', 'landuse', 'residential']
# ['3472940', 'name', u'百盛']
# ['3472940', 'type', 'multipolygon']
# ['3472940', 'building', 'commercial']
# ['3844753', 'type', 'multipolygon']
# ['3895358', 'type', 'multipolygon']
# ['4248460', 'name', '45']
# ['4248460', 'type', 'route']
# ['4248460', 'route', 'bus']
# ['4729754', 'name', 'K700']
# ['4729754', 'ref', 'K700']
# ['4729754', 'route', 'bus']
# ['4729754', 'type', 'route']
# ['4744326', 'name', 'K228']
# ['4744326', 'ref', 'K228']
# ['4744326', 'route', 'bus']
# ['4744326', 'type', 'route']
# ['5145355', 'name', u'展区']
# ['5145355', 'type', 'level']
# ['5145355', 'level', '0']
# ['5454552', 'ref', '1']
# ['5454552', 'name', u'西安地铁一号线']
# ['5454552', 'type', 'route']
# ['5454552', 'route', 'subway']
# ['6300022', 'name', 'Tang Dynasty Art Garden Hotel']
# ['6300022', 'type', 'multipolygon']
# ['6528500', 'landuse', 'farmland']
# ['6528500', 'type', 'multipolygon']
# ['6644982', 'restriction', 'only_straight_on']
# ['6644982', 'type', 'restriction']
# ['6742517', 'building', 'commercial']
# ['6742517', 'building:levels', '5']
# ['6742517', 'name', u'万达百货民乐园店']
# ['6742517', 'name:en', 'Wanda Plaza']
# ['6742517', 'type', 'multipolygon']

# %% [markdown]
# Brutally printing out all the tags at once proves too much information to grok, while counting the tag keys could be useful:

# %%
tag_key_count = Counter(key for _, key, _ in all_tags(OSM_FILE))
tag_key_count.most_common()
# Out:
# [('highway', 22151),
#  ('name', 8907),
#  ('building', 6508),
#  ('oneway', 6352),
#  ('source', 4035),
#  ('bridge', 3294),
#  ('ref', 2544),
#  ('layer', 2472),
#  ('lanes', 2236),
#  ('name:en', 2072),
#  ('railway', 1957),
#  ('landuse', 1707),
#  ('power', 1267),
#  ('amenity', 1138),
#  ('service', 767),
#  ('surface', 734),
#  ('name:zh', 648),
#  ('leisure', 619),
#  ('tunnel', 606),
#  ('place', 579),
#  ('natural', 503),
#  ('int_ref', 463),
#  ('waterway', 378),
#  ('website', 341),
#  ('gauge', 275),
#  ('tourism', 251),
#  ('name:zh_pinyin', 248),
#  ('lanes:start', 246),
#  ('lanes:end', 246),
#  ('electrified', 223),
#  ('flagfp', 223),
#  ('frequency', 215),
#  ('access', 213),
#  ('barrier', 208),
#  ('type', 204),
#  ('voltage', 204),
#  ('maxspeed', 190),
#  ('name:fr', 189),
#  ('foot', 172),
#  ('wikipedia', 167),
#  ('fixme', 162),
#  ('shop', 160),
#  ('water', 152),
#  ('addr:street', 144),
#  ('addr:city', 144),
#  ('boundary', 143),
#  ('admin_level', 143),
#  ('bicycle', 130),
#  ('note', 129),
#  ('usage', 128),
#  ('buildingpart', 113),
#  ('sport', 113),
#  ('building:levels', 103),
#  ('name:ru', 102),
#  ('roof:shape', 98),
#  ('area', 98),
#  ('aeroway', 95),
#  ('china_class', 92),
#  ('construction', 91),
#  ('historic', 90),
#  ('motor_vehicle', 85),
#  ('mtb', 85),
#  ('addr:housename', 79),
#  ('addr:postcode', 78),
#  ('addr:housenumber', 77),
#  ('embankment', 74),
#  ('man_made', 71),
#  ('horse', 62),
#  ('junction', 54),
#  ('boat', 54),
#  ('route', 52),
#  ('highspeed', 52),
#  ('office', 50),
#  ('cuisine', 47),
#  ('cycleway', 43),
#  ('width', 42),
#  ('operator', 41),
#  ('sidewalk', 40),
#  ('crossing', 39),
#  ('int_name', 39),
#  ('code', 36),
#  ('toll', 36),
#  ('wikidata', 36),
#  ('zhb_code', 36),
#  ('source:name', 35),
#  ('building:part', 35),
#  ('nsdi_code', 35),
#  ('footway', 35),
#  ('name:vi', 33),
#  ('alt_name', 30),
#  ('height', 30),
#  ('religion', 29),
#  ('cables', 27),
#  ('name:ja', 26),
#  ('level', 24),
#  ('atm', 24),
#  ('name:de', 24),
#  ('material', 22),
#  ('gns:UNI', 22),
#  ('gns:DSG', 22),
#  ('gns:UFI', 22),
#  ('gns:ADM1', 22),
#  ('backrest', 21),
#  ('colour', 21),
#  ('seats', 21),
#  ('wheelchair', 20),
#  ('entrance', 19),
#  ('cutting', 19),
#  ('network', 18),
#  ('wikipedia:en', 17),
#  ('phone', 16),
#  ('internet_access', 16),
#  ('fee', 15),
#  ('min_height', 15),
#  ('parking', 12),
#  ('buildingpart:verticalpassage', 12),
#  ('snowmobile', 10),
#  ('designation', 10),
#  ('motorcar', 10),
#  ('public_transport', 10),
#  ('toilets:position', 10),
#  ('alt_name:en', 10),
#  ('ski', 10),
#  ('artwork_type', 10),
#  ('trail_visibility', 9),
#  ('ele', 9),
#  ('created_by', 8),
#  ('description', 8),
#  ('covered', 8),
#  ('sac_scale', 8),
#  ('lit', 8),
#  ('indoor', 8),
#  ('name:es', 8),
#  ('capacity', 8),
#  ('opening_hours', 8),
#  ('restriction', 7),
#  ('motorcycle', 7),
#  ('aerialway', 7),
#  ('name:ko', 7),
#  ('name:cn', 7),
#  ('parent_basin', 7),
#  ('is_in:continent', 6),
#  ('hires:imagery', 6),
#  ('hires', 6),
#  ('name:zh_py', 6),
#  ('local_ref', 6),
#  ('hires:checkdate', 5),
#  ('width:lanes:end', 5),
#  ('noexit', 5),
#  ('width:lanes:start', 5),
#  ('denomination', 5),
#  ('bench', 5),
#  ('old_name', 5),
#  ('shelter', 5),
#  ('is_in:country_code', 5),
#  ('destination', 4),
#  ('door', 4),
#  ('motorroad', 4),
#  ('name:sk', 4),
#  ('length', 4),
#  ('tracktype', 4),
#  ('roundabout', 4),
#  ('smoking', 4),
#  ('is_in:country', 4),
#  ('name:pt', 3),
#  ('alt_name:zh_pinyin', 3),
#  ('name:ro', 3),
#  ('population', 3),
#  ('internet_access:fee', 3),
#  ('drive_through', 3),
#  ('gns:dsg', 3),
#  ('name:cs', 3),
#  ('emergency', 3),
#  ('stars', 3),
#  ('bus', 3),
#  ('alt_name:vi', 3),
#  ('wifi', 3),
#  ('seamark:type', 2),
#  ('name:zh_tradition', 2),
#  ('attribution', 2),
#  ('name:uk', 2),
#  ('source:tracer', 2),
#  ('leaf_type', 2),
#  ('name:pl', 2),
#  ('toilets:disposal', 2),
#  ('capacity:women', 2),
#  ('male', 2),
#  ('source:position', 2),
#  ('drive_in', 2),
#  ('capacity:disabled', 2),
#  ('name:sr', 2),
#  ('name:hi', 2),
#  ('name:hu', 2),
#  ('seamark:mooring:category', 2),
#  ('name:zh-simplified', 2),
#  ('takeaway', 2),
#  ('golf', 2),
#  ('name:kn', 2),
#  ('name:kr', 2),
#  ('capacity:parent', 2),
#  ('leaf_cycle', 2),
#  ('email', 2),
#  ('description:en', 2),
#  ('source:zoomlevel', 2),
#  ('addr:country', 2),
#  ('name:zh-traditional', 2),
#  ('supervised', 2),
#  ('wikipedia:zh', 2),
#  ('name:zh-classical', 2),
#  ('addr:street:en', 2),
#  ('old_name:vi', 2),
#  ('name:kg', 1),
#  ('official_name:az', 1),
#  ('name:kw', 1),
#  ('official_name:ay', 1),
#  ('official_name:an', 1),
#  ('official_name:af', 1),
#  ('official_name:simple', 1),
#  ('ref_int', 1),
#  ('official_name:pcd', 1),
#  ('fax', 1),
#  ('name:kl', 1),
#  ('name:uz', 1),
#  ('name:ur', 1),
#  ('icao', 1),
#  ('name:ug', 1),
#  ('name:ks', 1),
#  ('name:ia', 1),
#  ('name:lez', 1),
#  ('name:id', 1),
#  ('roof:height', 1),
#  ('official_name:zh', 1),
#  ('name:is', 1),
#  ('name:iu', 1),
#  ('name:it', 1),
#  ('official_name:za', 1),
#  ('alt_name:ru', 1),
#  ('name:si', 1),
#  ('official_name:ast', 1),
#  ('official_name:stq', 1),
#  ('official_name:sl', 1),
#  ('official_name:sh', 1),
#  ('name:bm', 1),
#  ('name:bn', 1),
#  ('name:bo', 1),
#  ('name:bh', 1),
#  ('name:bi', 1),
#  ('official_name:sv', 1),
#  ('name:be', 1),
#  ('hoops', 1),
#  ('name:ba', 1),
#  ('microbrewery', 1),
#  ('name:kbd', 1),
#  ('official_name:hr', 1),
#  ('addr:street:zh_pinyin', 1),
#  ('name:crh', 1),
#  ('name:ps', 1),
#  ('ISO3166-1:numeric', 1),
#  ('official_name:en', 1),
#  ('roof:colour', 1),
#  ('alt_name:eo', 1),
#  ('official_name:lad', 1),
#  ('name:pa', 1),
#  ('from', 1),
#  ('name:pih', 1),
#  ('official_name:nrm', 1),
#  ('official_name:zh-traditional', 1),
#  ('official_name:nov', 1),
#  ('drinkable', 1),
#  ('name:scn', 1),
#  ('name:my', 1),
#  ('flag', 1),
#  ('name:vec', 1),
#  ('name:UN:ru', 1),
#  ('name:pnt', 1),
#  ('official_name:als', 1),
#  ('name:pnb', 1),
#  ('name:be-tarask', 1),
#  ('name:mt', 1),
#  ('name:mr', 1),
#  ('name:bxr', 1),
#  ('ISO3166-1', 1),
#  ('ISO3166-2', 1),
#  ('name:ml', 1),
#  ('name:mn', 1),
#  ('name:mi', 1),
#  ('name:mk', 1),
#  ('information', 1),
#  ('name:fi', 1),
#  ('alt_name:de', 1),
#  ('name:xmf', 1),
#  ('name:hif', 1),
#  ('name:fo', 1),
#  ('name:fy', 1),
#  ('iata', 1),
#  ('name:fa', 1),
#  ('official_name:li', 1),
#  ('outdoor_seating', 1),
#  ('official_name:la', 1),
#  ('name:min', 1),
#  ('name:ty', 1),
#  ('name:ts', 1),
#  ('name:tt', 1),
#  ('official_name:zh-simplified', 1),
#  ('name:tk', 1),
#  ('name:th', 1),
#  ('postal_code', 1),
#  ('name:ta', 1),
#  ('name:tg', 1),
#  ('name:te', 1),
#  ('outer', 1),
#  ('name:pms', 1),
#  ('short_name:ru', 1),
#  ('name:UN:ar', 1),
#  ('official_name:yo', 1),
#  ('payment:bitcoin', 1),
#  ('name:gag', 1),
#  ('name_1', 1),
#  ('name:gan', 1),
#  ('name:ar', 1),
#  ('name:am', 1),
#  ('official_name:wuu', 1),
#  ('name:ab', 1),
#  ('name:cbk-zam', 1),
#  ('official_name:bjn', 1),
#  ('name:ilo', 1),
#  ('reg', 1),
#  ('name:so', 1),
#  ('name:sn', 1),
#  ('name:sm', 1),
#  ('name:war', 1),
#  ('name:sg', 1),
#  ('name:se', 1),
#  ('name:sc', 1),
#  ('name:arc', 1),
#  ('official_name:hsb', 1),
#  ('name:arz', 1),
#  ('name:et', 1),
#  ('name:sw', 1),
#  ('name:st', 1),
#  ('name:ss', 1),
#  ('name:sq', 1),
#  ('official_name:mg', 1),
#  ('name:tpi', 1),
#  ('name:diq', 1),
#  ('name:ie', 1),
#  ('park_ride', 1),
#  ('name:he', 1),
#  ('name:ha', 1),
#  ('name:bpy', 1),
#  ('name:hy', 1),
#  ('name:UN:zh', 1),
#  ('name:hr', 1),
#  ('name:srn', 1),
#  ('name:szl', 1),
#  ('name:lmo', 1),
#  ('official_name:ace', 1),
#  ('official_name:oc', 1),
#  ('division_code', 1),
#  ('name:haw', 1),
#  ('name:hak', 1),
#  ('name:roa-tara', 1),
#  ('official_name:de', 1),
#  ('official_name:da', 1),
#  ('name:xal', 1),
#  ('name:wo', 1),
#  ('name:ang', 1),
#  ('official_name:bs', 1),
#  ('official_name:br', 1),
#  ('name:ka', 1),
#  ('name:kk', 1),
#  ('name:ki', 1),
#  ('name:kv', 1),
#  ('name:ku', 1),
#  ('name:ky', 1),
#  ('name:frr', 1),
#  ('name:frp', 1),
#  ('name:tr', 1),
#  ('name:tet', 1),
#  ('name:lv', 1),
#  ('name:lt', 1),
#  ('capital', 1),
#  ('name:lb', 1),
#  ('name:ln', 1),
#  ('name:lo', 1),
#  ('name:el', 1),
#  ('name:eo', 1),
#  ('name:ee', 1),
#  ('name:eu', 1),
#  ('plant:output:hot_water', 1),
#  ('name:eml', 1),
#  ('name:ckb', 1),
#  ('name:ast', 1),
#  ('official_name:ca', 1),
#  ('official_name:pam', 1),
#  ('official_name:nds-nl', 1),
#  ('official_name:pag', 1),
#  ('city_served', 1),
#  ('contact:email', 1),
#  ('official_name:zea', 1),
#  ('name:krc', 1),
#  ('name:tl', 1),
#  ('ramp', 1),
#  ('name:sah', 1),
#  ('name:udm', 1),
#  ('name:os', 1),
#  ('name:or', 1),
#  ('official_name:sr', 1),
#  ('name:rw', 1),
#  ('name:UN:en', 1),
#  ('building_1', 1),
#  ('craft', 1),
#  ('name:UN:es', 1),
#  ('official_name:nds', 1),
#  ('name:new', 1),
#  ('name:dv', 1),
#  ('name:bar', 1),
#  ('name:yi', 1),
#  ('official_name:io', 1),
#  ('official_name:jv', 1),
#  ('official_name:gl', 1),
#  ('official_name:zh-classical', 1),
#  ('name:koi', 1),
#  ('name:vo', 1),
#  ('short_name', 1),
#  ('name:ext', 1),
#  ('name:tzl', 1),
#  ('ISO3166-1:alpha3', 1),
#  ('ISO3166-1:alpha2', 1),
#  ('official_name:sco', 1),
#  ('name:mwl', 1),
#  ('name:cy', 1),
#  ('official_name:pl', 1),
#  ('name:cv', 1),
#  ('name:cu', 1),
#  ('official_name:bcl', 1),
#  ('official_name:ceb', 1),
#  ('name:ce', 1),
#  ('name:ca', 1),
#  ('name:UN:fr', 1),
#  ('name:kab', 1),
#  ('name:kaa', 1),
#  ('name:mdf', 1),
#  ('Flagfp', 1),
#  ('name:chy', 1),
#  ('official_name:eo', 1),
#  ('name:chr', 1),
#  ('name:dsb', 1),
#  ('official_name:nl', 1),
#  ('official_name:no', 1),
#  ('official_name:nn', 1),
#  ('name:nah', 1),
#  ('name:nap', 1),
#  ('name:jbo', 1),
#  ('incline', 1),
#  ('name:nso', 1),
#  ('tributary_of', 1),
#  ('name:mzn', 1),
#  ('step_count', 1),
#  ('name:zh-min-nan', 1),
#  ('generator:source', 1),
#  ('contact:phone', 1),
#  ('name:mhr', 1),
#  ('official_name:ms', 1),
#  ('name:csb', 1),
#  ('official_name:bg', 1),
#  ('name:pap', 1),
#  ('name:rue', 1),
#  ('name:qu', 1),
#  ('oneway:bicycle', 1),
#  ('name:fiu-vro', 1),
#  ('official_name', 1),
#  ('timezone', 1),
#  ('name:zu', 1),
#  ('name:na', 1),
#  ('name:ne', 1),
#  ('name:vep', 1),
#  ('name:ga', 1),
#  ('name:gd', 1),
#  ('name:gn', 1),
#  ('official_name:bat-smg', 1),
#  ('name:gv', 1),
#  ('name:gu', 1)]

# %% [markdown]
# To get another overview, aggregate the tags into sets by keys:

# %%
agg = defaultdict(set)
for elem, key, val in all_tags(OSM_FILE):
    agg[key].add(val)
pprint(dict(agg))
# Out:
# {'Flagfp': set(['1']),
#  'ISO3166-1': set(['CN']),
#  'ISO3166-1:alpha2': set(['CN']),
#  'ISO3166-1:alpha3': set(['CHN']),
#  'ISO3166-1:numeric': set(['156']),
#  'ISO3166-2': set(['CN-61']),
#  'access': set(['customers',
#                 'designated',
#                 'destination',
#                 'half restricted',
#                 'no',
#                 'permissive',
#                 'private',
#                 'unknown',
#                 'yes']),
#  'addr:city': set(['Qu Jiang New District Xian',
#                    'Si-an',
#                    u'Weiyang District, Xi’an, Shaanxi',
#                    "Xi'an",
#                    'Xian',
#                    u'咸阳',
#                    u'咸阳市',
#                    u'西安',
#                    u'西安市',
#                    u'陕西西安']),
#  'addr:country': set(['CN']),
#  'addr:housename': set(['14#',
#                         'KaiYuan Mall',
#                         'Saigao Block',
#                         u'万家灯火小区',
#                         u'中国建设银行',
#                         u'华润万家 昆明路店',
#                         u'卡布奇诺公寓',
#                         u'向阳一区家属区',
#                         u'向阳二区家属区',
#                         u'向阳四区家属区',
#                         u'学10楼',
#                         u'学11楼',
#                         u'学8楼',
#                         u'学9楼',
#                         u'学生15楼',
#                         u'崇鋈楼',
#                         u'户县史家庄小学',
#                         u'教学一楼',
#                         u'教学七楼',
#                         u'教学三楼',
#                         u'教学九楼',
#                         u'教学二楼',
#                         u'教学五楼',
#                         u'教学八楼',
#                         u'教学六楼',
#                         u'教学四楼',
#                         u'新西门',
#                         u'昆明花园',
#                         u'枫林华府',
#                         u'校广播台',
#                         u'田家炳教育书院',
#                         u'积学堂',
#                         u'红枫林',
#                         u'航天第四研究院职工活动中心',
#                         u'融侨城',
#                         u'融侨城 物业办公室',
#                         u'西安华天通信有限公司',
#                         u'西安印钞厂',
#                         u'西安宇航中心',
#                         u'西安宇航小学',
#                         u'西安宇航幼儿园',
#                         u'陕师大羽毛球场',
#                         u'陕西职业技师学校',
#                         u'高新逸品小区',
#                         u'黄金嘉园',
#                         u'黄金嘉园一号楼',
#                         u'黄金嘉园三号楼',
#                         u'黄金嘉园二号楼']),
#  'addr:housenumber': set(['1',
#                           '100',
#                           u'10号',
#                           '110',
#                           u'11号',
#                           '12',
#                           '127',
#                           u'127号',
#                           '138',
#                           '140',
#                           '15',
#                           '18',
#                           '198',
#                           u'1号',
#                           '2',
#                           '20',
#                           '232',
#                           u'266号',
#                           '30',
#                           '300',
#                           '319',
#                           '32',
#                           '33',
#                           '333',
#                           '34',
#                           '364',
#                           '369',
#                           '383',
#                           u'38号',
#                           '39',
#                           '398',
#                           '4',
#                           '437',
#                           '439',
#                           '461',
#                           '473',
#                           '493',
#                           '5',
#                           '53',
#                           '6',
#                           '60',
#                           '61',
#                           '619',
#                           '66',
#                           u'6号',
#                           '8',
#                           '87',
#                           u'89号',
#                           '98',
#                           u'98号',
#                           u'IBM研发中心西安软件园C座',
#                           'No. 1',
#                           'Room 2003, Unit 3-3',
#                           u'劳动南路80号',
#                           u'华为公司',
#                           u'招行ATM',
#                           u'西安软件园A座']),
#  'addr:postcode': set(['710000',
#                        '710001',
#                        '710002',
#                        '710003',
#                        '710014',
#                        '710016',
#                        '710018',
#                        '710048',
#                        '710055',
#                        '710061',
#                        '710065',
#                        '710068',
#                        '710072',
#                        '710075',
#                        '710077',
#                        '710086',
#                        '710126',
#                        '710600',
#                        '712000',
#                        '713100',
#                        '719914']),
#  'addr:street': set(['',
#                      "16 Gaoxin 5th Road, Xi'an, Shaanxi",
#                      '237 ZiQiang West Road',
#                      '2nd Ring Road',
#                      'Bei Ma Dao',
#                      'Boshi rd ',
#                      'Ci En Road',
#                      'Dongxin',
#                      'Fengcheng Wu Lu',
#                      'Jiefang Road',
#                      'Laodong North Road',
#                      'Nan Xin Street',
#                      'Nanchang rd.',
#                      'Shangu St.',
#                      'Shuyuanmen ',
#                      'SouthRingRoad',
#                      'Wei Yang Road',
#                      'West Avenue',
#                      'Western Street',
#                      'Yanta West Road',
#                      'Zhu Que Zhong Road',
#                      u'丈八三路',
#                      u'丈八五路',
#                      u'丈八六路',
#                      u'世纪大道',
#                      u'东一路',
#                      u'东大街',
#                      u'东风路',
#                      u'二环南路东段',
#                      u'仁厚庄南路',
#                      u'光华路',
#                      u'兴平市文化路',
#                      u'兴平市莽山路',
#                      u'北二街',
#                      u'北院门',
#                      u'南院门',
#                      u'友谊西路',
#                      u'友谊西路 / Youyi Xi Lu',
#                      u'向阳北路',
#                      u'含光路',
#                      u'和平路',
#                      u'团结南路',
#                      u'大寨路',
#                      u'大寨路与团结南路十字',
#                      u'太白南路 / Taibai Nan Lu',
#                      u'尚俭路',
#                      u'尚勤路',
#                      u'建国路',
#                      u'振兴路',
#                      u'文景路',
#                      u'文景路与风城十路十字东南',
#                      u'昆明路',
#                      u'昆明路三号桥',
#                      u'昆明路与团结南路十字',
#                      u'昆明路二号桥',
#                      u'未央路',
#                      u'李家村路',
#                      u'毕塬西路',
#                      u'环城南路西段',
#                      u'田洪正街',
#                      u'电子正街',
#                      u'瞪羚路',
#                      u'科技路',
#                      u'科技路 / Keji Lu',
#                      u'莲湖路',
#                      u'西大街 Xī dàjiē',
#                      u'西长安街',
#                      u'解放市场',
#                      u'解放路',
#                      u'金旭路',
#                      u'钟鼓楼广场',
#                      u'锦业一路',
#                      u'长安区滦镇沣峪口',
#                      u'长安区西沣路兴隆段',
#                      u'长安南路',
#                      u'韦曲南街',
#                      u'高新一路 / Gaoxin Yi Lu']),
#  'addr:street:en': set(['Huajue Lane', 'Lianhu Road']),
#  'addr:street:zh_pinyin': set([u'liánhú lù']),
#  'admin_level': set(['2', '4', '5', '6']),
#  'aerialway': set(['cable_car', 'gondola', 'station']),
#  'aeroway': set(['aerodrome',
#                  'apron',
#                  'hangar',
#                  'runway',
#                  'taxiway',
#                  'terminal']),
#  'alt_name': set(['Lishan',
#                   "Stelenwald;Xi'an Beilin Museum",
#                   'Xijundian University',
#                   u'上海—西安高速公路',
#                   u"义井镇;义井;仪井镇;I-ching;I-ching-chen;Chin-t'ou-chen;Yijing Zhen",
#                   u'二曲镇;周至县;Chowchih;Chou-chih-hsien;Chzhouchzhi;Chou-chih;Chowchihhsien;二曲;Erqu Zhen;Zhouzhi Xian',
#                   u'伊洛河',
#                   u'侯家村;Houjia',
#                   u'包茂高速',
#                   u'周至;Zhouzhi Xian;Chou-chih Hsien',
#                   u'哑柏镇;Ya-pai;Ya-pei-chen;Wa-pai;Ya-pai-chen;Yabai Zhen',
#                   u'回民街',
#                   u'大寨路',
#                   u'大杨;Dayangcun',
#                   u'大秦寺塔',
#                   u'尚品格蓝',
#                   u"店头镇;Tien-t'ou;T'ien-t'ou-chen",
#                   u'楼观镇',
#                   u'永寿;Yongshou',
#                   u'永寿县;监军镇;永寿;Yung-shou-hsien;Yung-shou;Ku-tun;Chien-chun-chen;Chien-chun',
#                   u'洛河',
#                   u'石牛乡',
#                   u'调剂餐厅',
#                   u'辛家寨镇',
#                   u'阳洪;Yang-hung-tien;Yang-hung;Yanghong Zhen',
#                   u'陈河镇',
#                   u'马召镇;Ma-chao-chen;Ma-chao;Mazhao Zhen',
#                   u'黑河水库;Heihe Reservoir']),
#  'alt_name:de': set([u'Zweite eurasische Kontinentalbrücke']),
#  'alt_name:en': set(['Beiluo River',
#                      u'G30 Lianyungang–Khorgas Expressway',
#                      "G40 Shanghai-Xi'an Expressway",
#                      'Giant Wild Goose Pagoda',
#                      u"Nanjing–Xi'an Railway",
#                      'New Eurasian Continental Bridge',
#                      u"Xi'an–Ankang Railway",
#                      u"Xi'an–Chengdu High-Speed Railway",
#                      'Yiluo River']),
#  'alt_name:eo': set([u'Ĉinujo']),
#  'alt_name:ru': set([u'Китай']),
#  'alt_name:vi': set([u'Hoa huyện', u'Kiền', u'Tạc Thuỷ']),
#  'alt_name:zh_pinyin': set([u'bĕiluò hé', u'yīluò hé']),
#  'amenity': set(['arts_centre',
#                  'atm',
#                  'bank',
#                  'bar',
#                  'bench',
#                  'bicycle_parking',
#                  'bus_station',
#                  'cafe',
#                  'car_wash',
#                  'childcare',
#                  'cinema',
#                  'clinic',
#                  'college',
#                  'community_centre',
#                  'drinking_water',
#                  'fast_food',
#                  'fire_station',
#                  'food_court',
#                  'fountain',
#                  'fuel',
#                  'grave_yard',
#                  'hospital',
#                  'kindergarten',
#                  'library',
#                  'marketplace',
#                  'parking',
#                  'parking_entrance',
#                  'pharmacy',
#                  'place_of_worship',
#                  'police',
#                  'post_box',
#                  'post_office',
#                  'pub',
#                  'public_building',
#                  'restaurant',
#                  'school',
#                  'shelter',
#                  'swimming_pool',
#                  'taxi',
#                  'telephone',
#                  'theatre',
#                  'toilets',
#                  'university',
#                  'waste_basket',
#                  'yes']),
#  'area': set(['no', 'yes']),
#  'artwork_type': set(['statue']),
#  'atm': set(['yes']),
#  'attribution': set([u'不可公交卡充值',
#                      u'创始人即首任校长纪念碑']),
#  'backrest': set(['yes']),
#  'barrier': set(['block',
#                  'bollard',
#                  'city_wall',
#                  'entrance',
#                  'fence',
#                  'gate',
#                  'hedge',
#                  'kissing_gate',
#                  'lift_gate',
#                  'retaining_wall',
#                  'toll_booth',
#                  'wall']),
#  'bench': set(['no']),
#  'bicycle': set(['designated', 'destination', 'no', 'yes']),
#  'boat': set(['no']),
#  'boundary': set(['administrative']),
#  'bridge': set(['aqueduct', 'no', 'viaduct', 'yes']),
#  'building': set(['apartments',
#                   'college',
#                   'commercial',
#                   'dam',
#                   'dormitory',
#                   'hospital',
#                   'house',
#                   'hut',
#                   'industrial',
#                   'no',
#                   'public',
#                   'residential',
#                   'retail',
#                   'roof',
#                   'school',
#                   'stadium',
#                   'tower',
#                   'university',
#                   'warehouse',
#                   'yes',
#                   u'仁厚庄园']),
#  'building:levels': set(['1',
#                          '11',
#                          '18',
#                          '2',
#                          '22',
#                          '24',
#                          '26',
#                          '27',
#                          '28',
#                          '3',
#                          '32',
#                          '4',
#                          '5',
#                          '6',
#                          '7',
#                          '9']),
#  'building:part': set(['roof', 'tower', 'yes']),
#  'building_1': set(['yes']),
#  'buildingpart': set(['corridor', 'room', 'stage', 'verticalpassage']),
#  'buildingpart:verticalpassage': set(['stairway']),
#  'bus': set(['yes']),
#  'cables': set(['3', '6']),
#  'capacity': set(['1000', '18', '40', '5', '50']),
#  'capacity:disabled': set(['no']),
#  'capacity:parent': set(['no']),
#  'capacity:women': set(['no']),
#  'capital': set(['4']),
#  'china_class': set(['countytown', 'xiang', 'zhen']),
#  'city_served': set(["Xi'an"]),
#  'code': set(['ADA80006',
#               'ADC00006',
#               'ADC18006',
#               'ADC20006',
#               'ADC21006',
#               'ADC22006',
#               'ADC23006',
#               'ADC23106',
#               'ADC24006',
#               'AFA00000',
#               'AFG00006',
#               'AFG26006',
#               'BDC18000102',
#               'BDC20110163',
#               'BDC22000183',
#               'BDC25000313',
#               'BFG26000883']),
#  'colour': set(['brown']),
#  'construction': set(['motorway',
#                       'motorway_link',
#                       'primary',
#                       'rail',
#                       'secondary',
#                       'service',
#                       'subway',
#                       'tertiary',
#                       'yes']),
#  'contact:email': set(['Tours@YoungPioneerTours.com']),
#  'contact:phone': set(['+86 (0)29 862 123 59']),
#  'covered': set(['yes']),
#  'craft': set(['shoemaker']),
#  'created_by': set(['andnav.org', 'dkt_GNS-import-1']),
#  'crossing': set(['traffic_signals', 'uncontrolled', 'zebra']),
#  'cuisine': set(['american',
#                  'asian',
#                  'bavarian',
#                  'brazilian',
#                  'burger',
#                  'chicken',
#                  'chinese',
#                  'chinese;asian',
#                  'coffee_shop',
#                  'german',
#                  'ice_cream',
#                  'japanese',
#                  'noddle',
#                  'noodles',
#                  'pizza',
#                  'regional',
#                  'sandwich',
#                  'thai',
#                  u'清真_羊肉泡馍_Halal',
#                  u'烤鱼，面食，盖饭']),
#  'cutting': set(['yes']),
#  'cycleway': set(['lane',
#                   'no',
#                   'opposite_lane',
#                   'opposite_track',
#                   'shared_lane',
#                   'track']),
#  'denomination': set(['Gelug-pa',
#                       'Tang vajrayana',
#                       'mahayana',
#                       u'佛教']),
#  'description': set(['G210 runs from Baotou,Inner Mongolia to Nanning,Guangxi Province',
#                      "G211 runs from Yinchuan in Ningxia to Xi'an in Shaanxi.",
#                      'G310 runs northwest from Lianyungang, Jiangsu towards Anhui, Henan, Shaanxi provinces, and ends in Tianshui, Gansu.',
#                      'G5 connects the cities of Beijing and Kunming, Yunnan',
#                      'G65 connects Baotou, Inner Mongolia and Maoming, Guangdong.',
#                      'Highway from Fuzhou, Fujian to Yinchuan, Ningxia',
#                      u'The first company to offer budget tours to the Democratic People’s Republic of Korea.',
#                      'Wei river is a river in west-central China and is the largest tributary of the Yellow River.']),
#  'description:en': set(['Longhai railway connects Lianyungang on the Yellow Sea with Lanzhou through Jiangsu, Anhui, Henan, Shaanxi, and Gansu provinces.',
#                         "Xikang Railway connects Xi'an, Shaanxi with Ankang, Shaanxi."]),
#  'designation': set(['KaiYuan Mall',
#                      'unset',
#                      u'二期草坪',
#                      u'奥林匹克花园一二期',
#                      u'奥林匹克花园二期大门',
#                      u'奥林匹克花园运动会所',
#                      u'废弃的收费站',
#                      u'西安奥林匹克花园',
#                      u'西安奥林匹克花园入口大门',
#                      u'西安市灞桥区纺织城小学']),
#  'destination': set(['Huang He', 'Huang He basin', 'Wei He basin', 'Yangtze']),
#  'division_code': set(['610426']),
#  'door': set(['yes']),
#  'drinkable': set(['no']),
#  'drive_in': set(['no']),
#  'drive_through': set(['no']),
#  'ele': set(['1302', '1414', '15600', '1615', '2043', '2100', '2150', '479']),
#  'electrified': set(['contact_line', 'no', 'yes']),
#  'email': set(['info.gpax@parkhotelgroup.com', 'shuyuanhostel@hotmail.com']),
#  'embankment': set(['yes']),
#  'emergency': set(['no', 'yes']),
#  'entrance': set(['emergency', 'main', 'yes']),
#  'fax': set(['+86 29 87672666']),
#  'fee': set(['no', 'yes', u'招行ATM']),
#  'fixme': set(['"chinese GPS" offset',
#                '???',
#                'access really private?',
#                'check if tunnel here...',
#                'continue',
#                'cross-check "chinese" offset',
#                'end of detailed BING imagery',
#                'low detail',
#                'no physical tags',
#                'oneway',
#                'two ways + round about',
#                'yes']),
#  'flag': set(['http://upload.wikimedia.org/wikipedia/commons/f/fa/Flag_of_the_People%27s_Republic_of_China.svg']),
#  'flagfp': set(['1']),
#  'foot': set(['designated', 'destination', 'no', 'permissive', 'yes']),
#  'footway': set(['crossing', 'sidewalk']),
#  'frequency': set(['50']),
#  'from': set([u'连云港 - Lianyungang']),
#  'gauge': set(['1435']),
#  'generator:source': set(['coal']),
#  'gns:ADM1': set(['26']),
#  'gns:DSG': set(['ADM2', 'ADM3']),
#  'gns:UFI': set(['-1906363',
#                  '-1910734',
#                  '-1910760',
#                  '-1911281',
#                  '-1912516',
#                  '-1914121',
#                  '-1915458',
#                  '-1915528',
#                  '-1921828',
#                  '-1924067',
#                  '-1930304',
#                  '-1930762',
#                  '-1931843',
#                  '-1931875',
#                  '-1933604',
#                  '-1939462',
#                  '6011371',
#                  '6430201',
#                  '9213841',
#                  '9213842',
#                  '9213844',
#                  '9213883']),
#  'gns:UNI': set(['6816704',
#                  '6816708',
#                  '6816740',
#                  '6816764',
#                  '6816765',
#                  '6816766',
#                  '6816769',
#                  '6816771',
#                  '6816782',
#                  '6816786',
#                  '6816800',
#                  '6816802',
#                  '6816803',
#                  '6816805',
#                  '6816808',
#                  '6816810',
#                  '6816811',
#                  '6816820',
#                  '9282012',
#                  '9282013',
#                  '9282015',
#                  '9282054']),
#  'gns:dsg': set(['MT: mountain', 'RSV: reservoir(s)']),
#  'golf': set(['driving_range', 'green']),
#  'height': set(['10',
#                 '12',
#                 '13.9',
#                 '15.4',
#                 '21.6',
#                 '23.1',
#                 '25',
#                 '29.3',
#                 '30.8',
#                 '35',
#                 '37',
#                 '38.5',
#                 '40',
#                 '44.7',
#                 '46.2',
#                 '50',
#                 '52.4',
#                 '58.5',
#                 '6.2',
#                 '60',
#                 '64.5',
#                 '7.7',
#                 '8']),
#  'highspeed': set(['yes']),
#  'highway': set(['bus_stop',
#                  'construction',
#                  'crossing',
#                  'cycleway',
#                  'footway',
#                  'living_street',
#                  'mini_roundabout',
#                  'motorway',
#                  'motorway_junction',
#                  'motorway_link',
#                  'path',
#                  'pedestrian',
#                  'platform',
#                  'primary',
#                  'primary_link',
#                  'raceway',
#                  'residential',
#                  'rest_area',
#                  'road',
#                  'secondary',
#                  'secondary_link',
#                  'service',
#                  'services',
#                  'steps',
#                  'tertiary',
#                  'tertiary_link',
#                  'track',
#                  'traffic_signals',
#                  'trunk',
#                  'trunk_link',
#                  'turning_circle',
#                  'unclassified',
#                  'via_ferrata']),
#  'hires': set(['no', 'yes']),
#  'hires:checkdate': set(['2015-07-18', '2015-07-19']),
#  'hires:imagery': set(['Bing']),
#  'historic': set(['archaeological_site',
#                   'city_gate',
#                   'memorial',
#                   'monument',
#                   'ruins',
#                   'school',
#                   'wayside_shrine']),
#  'hoops': set(['1']),
#  'horse': set(['designated', 'no', 'private', 'yes']),
#  'iata': set(['XIY']),
#  'icao': set(['ZLXY']),
#  'incline': set(['up']),
#  'indoor': set(['yes']),
#  'information': set(['office']),
#  'int_name': set(['Asian Highway AH34',
#                   'Asian Highway AH5',
#                   'Ba He',
#                   'Chan He',
#                   'Dianzi West Road',
#                   'Dianzizhengjie Rd',
#                   'Dongyi Road',
#                   'Laoyazui Shuiku',
#                   'Liquan',
#                   'Luo He',
#                   "People's Republic of China",
#                   'Shaanxi',
#                   'Shangluo',
#                   'Shangpin Gelan',
#                   'Weihe',
#                   'Xianyang',
#                   'Xidian University',
#                   'Yanta Qu',
#                   'Ziwu Avenus',
#                   'dianzi 5 road',
#                   'fangzhicheng primary school',
#                   u'调剂餐厅']),
#  'int_ref': set(['AH34', 'AH5']),
#  'internet_access': set(['wlan', 'yes']),
#  'internet_access:fee': set(['no']),
#  'is_in:continent': set(['Asia']),
#  'is_in:country': set(['China']),
#  'is_in:country_code': set(['CN']),
#  'junction': set(['crossing', 'roundabout']),
#  'landuse': set(['basin',
#                  'brownfield',
#                  'cemetery',
#                  'commercial',
#                  'construction',
#                  'farm',
#                  'farmland',
#                  'farmyard',
#                  'forest',
#                  'grass',
#                  'industrial',
#                  'meadow',
#                  'military',
#                  'quarry',
#                  'railway',
#                  'recreation_ground',
#                  'reservoir',
#                  'residential',
#                  'retail']),
#  'lanes': set(['1', '2', '2; 4', '2;4', '3', '4', '6', '7', '8']),
#  'lanes:end': set(['1', '2', '3', '4']),
#  'lanes:start': set(['1', '2', '3', '4']),
#  'layer': set(['+1',
#                '-1',
#                '-2',
#                '-3',
#                '-5',
#                '0',
#                '0; 5',
#                '1',
#                '2',
#                '3',
#                '4',
#                '5']),
#  'leaf_cycle': set(['deciduous', 'semi_evergreen']),
#  'leaf_type': set(['broadleaved', 'mixed']),
#  'leisure': set(['common',
#                  'garden',
#                  'golf_course',
#                  'ice_rink',
#                  'park',
#                  'pitch',
#                  'playground',
#                  'recreation_ground',
#                  'sauna',
#                  'sports_centre',
#                  'stadium',
#                  'swimming_pool',
#                  'track',
#                  'water_park',
#                  'yes']),
#  'length': set(['2485', '2800', '3000', '3800']),
#  'level': set(['0', '1', '2', '3', '6']),
#  'lit': set(['no', 'yes']),
#  'local_ref': set([u'公交五公司(东去)',
#                    u'公交五公司(北去)',
#                    u'公交五公司(南去)',
#                    u'公交五公司(西去)',
#                    u'徐家庄北口(东去)',
#                    u'徐家庄北口(西去)']),
#  'male': set(['yes']),
#  'man_made': set(['chimney',
#                   'flagpole',
#                   'goods_conveyor',
#                   'pier',
#                   'pipeline',
#                   'tower',
#                   'wastewater_plant',
#                   'water_well',
#                   'water_works',
#                   'works']),
#  'material': set(['brick', 'wood']),
#  'maxspeed': set(['100', '120', '20', '30', '350', '50', '60', '70', '80']),
#  'microbrewery': set(['no']),
#  'min_height': set(['0',
#                     '13.9',
#                     '15.4',
#                     '21.6',
#                     '23.1',
#                     '29.3',
#                     '30.8',
#                     '37',
#                     '38.5',
#                     '44.7',
#                     '46.2',
#                     '52.4',
#                     '58.5',
#                     '6.2',
#                     '7.7']),
#  'motor_vehicle': set(['designated',
#                        'destination',
#                        'no',
#                        'permissive',
#                        'private',
#                        'yes']),
#  'motorcar': set(['no', 'unknown']),
#  'motorcycle': set(['unknown']),
#  'motorroad': set(['yes']),
#  'mtb': set(['yes']),
#  'name': set([u' 陕西中医大学',
#               u'06号',
#               '1',
#               '103',
#               '106,721',
#               '107',
#               '107, 34',
#               '107,34',
#               '107,512,34',
#               '107,512,608,34',
#               u'107省道',
#               u'108国道',
#               u'108省道',
#               u'10号宿舍楼',
#               u'10号教学楼',
#               u'113分叉',
#               u'113县道',
#               u'113县道3',
#               u'11号宿舍楼',
#               u'12号宿舍楼',
#               u'12楼',
#               u'13号宿舍楼',
#               '14,312,...',
#               u'14号宿舍楼',
#               u'17楼',
#               u'19号楼',
#               u'19号楼（1994年建）',
#               u'1北楼',
#               u'1号宿舍楼',
#               u'1号教学楼',
#               u'1号楼',
#               u'1号高层',
#               '2',
#               '205',
#               '206',
#               '207,35,...',
#               '209, ...',
#               u'20楼',
#               u'210国道',
#               u'211国道',
#               '212, ...',
#               '220',
#               u'24楼',
#               '251',
#               '251, 908, 512, 608, ...',
#               '251, 908, 608',
#               '251,29,908',
#               '251,901,29',
#               '251,908,29, ...',
#               '261',
#               '261, 262',
#               '262',
#               '29,411',
#               '29,908,411',
#               '2nd Ring Road',
#               u'2号宿舍楼',
#               u'2号教学楼',
#               u'2号楼',
#               u'2号高层',
#               '3',
#               '308,X7,...',
#               u'310国道',
#               '312,14,604,X7,...',
#               u'312国道',
#               '313',
#               '32',
#               '32,710',
#               '324',
#               '33',
#               '34',
#               '351',
#               u'3号宿舍楼',
#               u'3号教学楼',
#               u'3号楼',
#               u'3号高层',
#               '4',
#               '40, ...',
#               '40, 262, ...',
#               '40,400,721',
#               '402',
#               '411',
#               '45',
#               u'45号楼',
#               u'47号楼',
#               u'4号宿舍楼',
#               u'4号教学楼',
#               u'4号高层',
#               '5',
#               u'500M射电望远镜',
#               '502',
#               u'505体育馆',
#               '506, ...',
#               '512',
#               '512,212,...',
#               '512,29,608,...',
#               '512,712,...',
#               '526, ...',
#               u'54楼',
#               u'557村道',
#               u'559村道',
#               u'559村道2',
#               u'559村道3',
#               u'55号楼',
#               '59',
#               u'5号宿舍楼',
#               u'5号教学楼',
#               '6',
#               u'6,16,k35,k205,311,411,506,900,900区间,916,教育专线,通宵2号线',
#               u'6,k35,k205,311,411,506,900,900区间,916,教育专线,通宵2号线',
#               '607',
#               '608',
#               '611, 603',
#               u'6号宿舍楼',
#               u'6号教学楼',
#               '707',
#               '707,...',
#               '709, 526, ...',
#               '710',
#               '713, 44, ...',
#               '721',
#               '721,...',
#               u'7号宿舍楼',
#               u'7号教学楼',
#               u'7天快捷酒店',
#               u'7天连锁酒店',
#               '8',
#               u'85中',
#               u'8号宿舍楼',
#               u'8号教学楼',
#               '902, ...',
#               '905, 526, ...',
#               '905, 526, 30, ...',
#               '908, 29',
#               '908, 29, ...',
#               '908, 29, 608, 707, ...',
#               u'9号宿舍楼',
#               'A',
#               'ABC Bank ',
#               'Airport Shuttle Service / Long Hai Hotel',
#               'Alley Yuth Hostel',
#               'Antique Market',
#               'Applied Materials',
#               'Archeological Exploration Center',
#               'Atour Hotel',
#               'Aurum International Hotel',
#               u'A楼',
#               'B',
#               'B1',
#               'B2',
#               'B3',
#               'B4',
#               'Bacchus Pizza',
#               'Banana Leaf',
#               u'Bang Bang 面',
#               'Bank of Communications',
#               'Banpo Site',
#               'Basketball pitch',
#               'Baskin & Robins',
#               'Beer Garden',
#               'Bierhaus - Paulaner',
#               'Building3',
#               'Bus terminal',
#               u'B楼',
#               'C',
#               'C051',
#               'C511',
#               'CNG  Gas Station ',
#               'Cable car Ticket office',
#               'Cambridge Restaurant',
#               'Car Repair',
#               'Car Repair Parking',
#               "Chang'an University",
#               'Chess Pavilion',
#               'China Construction Bank',
#               'China Construction Bank 24-hour Self-service Bank',
#               'China Lanzhou Beef Noodles',
#               'China Unicom',
#               'City Gate',
#               'Coffee House',
#               "Crowne Plaza Xi'an",
#               u'C楼',
#               'DHL',
#               'DQ',
#               'Dabeigou Shuiku',
#               'Daming Palace Heritage Museum',
#               'Daming Palace Natural Heritage Park',
#               'Daxing Rd(E)',
#               'Days Hotel & Suites',
#               'Dicos',
#               'Dumplings',
#               u'D楼',
#               'Eastwood Inn',
#               u'Emerson研发中心',
#               'Empark Grand Hotel',
#               "Empress' Tomb",
#               'Epin life',
#               "Evan's Park",
#               'Exhibition Hall',
#               u'E楼',
#               'Facebook Hostel',
#               'Facebook Youth Hostel',
#               'First Noodle under the sun',
#               'Five Li Pass',
#               'Foreign Language Studies University, new Campus',
#               'Foreign Language Studies University, old Campus',
#               'Free shuttle to Mausoleum',
#               'Free shuttle to Teracotta Army',
#               'Furong Lake',
#               'Fuxue Alley',
#               u'F楼',
#               'G210',
#               'G211',
#               'G30',
#               'G3001',
#               'G3011',
#               'G310',
#               'G40',
#               u'G65 包茂高速公路',
#               'G65W',
#               u'G70 福银高速',
#               'G70;G40',
#               'Gaoling Xian',
#               'Gaoxin erlu',
#               'Giant',
#               'Golden Flower Hotel',
#               'Golden Lock Gate',
#               'Gooseberry Cafe',
#               u'Grand Mercure Xian On Renmin Square 西安豪华美居人民大厦',
#               'Grand Park Xian',
#               'Grand Soluxe International Hotel',
#               u'Große Wildganspagode Xian',
#               'Guangzhong Hotel',
#               'Guava Youth Hostel',
#               u'G楼',
#               'HSBC',
#               'Haidilao Hot Pot Cheng',
#               'Hairy Woman Cave',
#               'Han Tang Inn',
#               'Hantang House',
#               'Hanting Hotels',
#               'Hanyangling',
#               'High Fly Pizza',
#               'Home World',
#               'Hooters',
#               'Howard Johnson Ginwa Plaza',
#               'HuaRenWanJia',
#               'Huaqing Aegean Int. Hot Spring Resort & Spa',
#               'Huaqing Hot Springs',
#               'Huashan Gate',
#               'Hunyuan Stone',
#               'IMAX',
#               'Ibis Heping Gate Hotel',
#               'Japanese',
#               'Jianguo Hotel',
#               "Jianguo Hotel Xi'An",
#               'Jiefang Hotel',
#               'Jin Suo Guan',
#               'Jinjang Hotel',
#               'Jinjiang',
#               'K0009 pit',
#               'K2 summit',
#               'K228',
#               'K45',
#               'K600',
#               'K616',
#               'K700',
#               'K800',
#               'KFC',
#               u'KFC汽车穿梭餐厅',
#               'Keji 7 road',
#               'Keji Er Rd',
#               'Lao Sun Jia',
#               'Li',
#               'Longhai Line',
#               'Lotus',
#               'METRO',
#               'MYFO Wanshunyuan INN',
#               'Majieling Tunnel',
#               u'Mark and Henry Apartment(马克亨瑞公寓酒店）',
#               "McDonald's",
#               'McDonalds',
#               'Mcdonalds',
#               'Meet Capsule Hotel',
#               'Melody Hotel',
#               'Mercure on Renmin Square Xian',
#               'Merida',
#               "Ming's wine",
#               'Minsheng Jiale Shopping Plaza',
#               'More pits',
#               'Mr.Li',
#               'Muhuguan Tunnel',
#               'Nan Yao Tou',
#               'New Century Club',
#               'New Eurasian Land Bridge',
#               'Noodle shop',
#               'Oujiexi Holiday Hotel',
#               'PAPA Capsule Hostel',
#               'PSB office for visa extensions',
#               'Pacific Coffee ',
#               'Parkson',
#               u'Patisserie Française',
#               'Paulaner',
#               'Pit K0006',
#               'Pizza Hut',
#               'Plank Walk',
#               'Plant Market',
#               'Police Station',
#               'Prince Lofty',
#               'Public Bus Stop for Terracota Warriors (Bus 306)',
#               'Public bus stop',
#               'Qianxuesen Library',
#               'Qingke Terrace',
#               'Qunxian Temple',
#               "Ramada Xi'an Bell Tower",
#               'Real Love (7th floor)',
#               'Ren Ren Ju',
#               'Ren Ren Le',
#               'Ring Expy',
#               'S101',
#               'S104',
#               'S105',
#               'S107',
#               'S108',
#               'S201',
#               'S202',
#               'S307',
#               u'SOLO公寓',
#               'Saiga Electronics Market',
#               'See Tang Hostel',
#               'See tang hostel',
#               'Shaanxi Grand Opera House',
#               'Shaanxi Yijia Express Hotel',
#               'Shaanxi electric power company  community',
#               'Shalou Terrace',
#               'Shangpin Gelan',
#               'Shangri La',
#               'Shell',
#               'Shengna Fashion Square',
#               'Sheraton',
#               'Sheraton North',
#               'Shizhan',
#               'Shuttle Service To The Airport ',
#               'Shuyuan International Party Hostel',
#               'SkyBar',
#               'Smoothie King',
#               'South Gate Tower',
#               'South Heavenly Gate',
#               'Sports Complex',
#               'St. Louis Portugese',
#               'Starbucks',
#               'Starbucks ',
#               'Starbucks Coffee',
#               'Subway',
#               'Super 8',
#               u'Super 8 速8酒店',
#               'Suwu Tome',
#               u'TIGER国际公寓',
#               'Tang Cheng Hotel',
#               'Tang Du Stele Forest Art Museum',
#               'Tang Dynasty Art Garden Hotel',
#               'Tangyan Lu',
#               'Tangyan Nan Lu',
#               'Temple of 8 Immortals',
#               'Temple of the Eight Immortals',
#               'Terracotta Factory ',
#               'Terrakotta Armee Xian',
#               'The Arsenals of Resistance',
#               'The Main Building',
#               'The Pegasus Company',
#               "The Tang Dynasty, Xi'an",
#               'Three Sisters Dumplings',
#               'Tianyi Hotel',
#               'Ticket office',
#               'Tourist bus 4',
#               'Unicom',
#               'Vanguard',
#               'Wal-Mart',
#               'Warriors International Hostel',
#               'Watsons',
#               'Weipu Expwy',
#               'West Electronic Market',
#               'West Restaurant',
#               'Wugong Air Base',
#               'Wyndham hotel',
#               'X101',
#               'X216',
#               'X227',
#               'X319',
#               'XISU',
#               'Xi Ba Lu ( Terracotta Warrior Museum)',
#               "Xi'An Hometown Hostel",
#               "Xi'an",
#               "Xi'an Bell Tower Lijing Hotel",
#               "Xi'an Da Qin Terracotta & Lacquer Furniture Art Factory",
#               "Xi'an Facebook Youth Hostel ",
#               "Xi'an See Tang Hostel",
#               "Xi'an Warriors Hostel",
#               'XiQi International HoteI',
#               'Xianyang',
#               'Xidian University (New Campus)',
#               'Xiwan Gong Lu',
#               'Yaijie Guesthouse',
#               'Yanta Rd',
#               'Yasen Park',
#               'YeJia Inn',
#               'Yong Ning International Art museum',
#               'Young Pioneer Tours',
#               'Yuan village food tourist park',
#               'Zhouling',
#               'beixiu1',
#               'bus 702',
#               u'décathlon store',
#               'ecco footware',
#               'grand noble hotel',
#               'greenants outdoor',
#               'mia house',
#               'pagoda',
#               'parada 702',
#               u'一中北路',
#               u'一卡通中心',
#               u'一卡通服务大厅',
#               u'一号宿舍楼',
#               u'一号楼',
#               u'一号路',
#               u'丁家村西街',
#               u'丁家桥',
#               u'丁家桥: 107, 218, 251, 908',
#               u'丁家桥: 218, 251',
#               u'丁家桥巷',
#               u'丁家桥村道',
#               u'丁村',
#               u'丁白路',
#               u'丁香餐厅',
#               u'七一东路',
#               u'七一西路',
#               u'七号楼',
#               u'七号路',
#               u'万北路',
#               u'万南西路',
#               u'万国一径',
#               u'万国二径',
#               u'万家灯火',
#               u'万家福便利店',
#               u'万寿中路',
#               u'万寿北路',
#               u'万寿南路',
#               u'万寿路站',
#               u'万年路',
#               u'万庆巷',
#               u'万豪酒店',
#               u'万达广场一号路',
#               u'万达百货民乐园店',
#               u'丈八一路',
#               u'丈八七路',
#               u'丈八三路',
#               u'丈八东路',
#               u'丈八二路',
#               u'丈八五路',
#               u'丈八六路',
#               u'丈八北路',
#               u'丈八北路 / Zhangba Bei Lu',
#               u'丈八北路站',
#               u'丈八四路',
#               u'丈八四路北段',
#               u'丈八街办',
#               u'丈八西路',
#               u'丈杜路',
#               u'三五零七社区',
#               u'三兆村',
#               u'三兆路',
#               u'三兆路 Sānzhào Rd',
#               u'三南路',
#               u'三原',
#               u'三原县',
#               u'三原县 (Sanyuan)',
#               u'三原站',
#               u'三号坑',
#               u'三号楼',
#               u'三号路',
#               u'三姐妹饺子 @ 东木头市店',
#               u'三家庄',
#               u'三张镇',
#               u'三星',
#               u'三星工业园区',
#               u'三星快速干道',
#               u'三星立交',
#               u'三桥收费站',
#               u'三桥村',
#               u'三桥立交',
#               u'三桥站',
#               u'三桥街办',
#               u'三殿桥',
#               u'三民村站',
#               u'三渠镇',
#               u'三爻站',
#               u'三环辅道',
#               u'三航路',
#               u'三贤路',
#               u'三过村',
#               u'三里镇',
#               u'上小径',
#               u'上林体育馆',
#               u'上林斜路',
#               u'上林路',
#               u'上河道',
#               u'上王村',
#               u'上草村',
#               u'上陆陌',
#               u'下北街',
#               u'下寨镇',
#               u'下庙镇',
#               u'下草村',
#               u'下西街',
#               u'专家楼',
#               u'世博园站',
#               u'世博大道',
#               u'世园花卉交易中心(绿叶庄园)',
#               u'世家星城',
#               u'世纪大道',
#               u'世纪大道辅道',
#               u'世纪西路',
#               u'世纪金花',
#               u'世纪锦绣乐乐超市',
#               u'丘',
#               u'东10舍',
#               u'东11舍',
#               u'东12舍',
#               u'东13舍',
#               u'东14舍',
#               u'东15舍',
#               u'东16舍',
#               u'东一巷',
#               u'东一楼',
#               u'东一路',
#               u'东七路',
#               u'东七道',
#               u'东七道巷',
#               u'东三楼',
#               u'东三环路',
#               u'东三环辅道',
#               u'东三路',
#               u'东三道',
#               u'东三道巷',
#               u'东九道',
#               u'东九道巷',
#               u'东二楼',
#               u'东二环',
#               u'东二环路',
#               u'东二路',
#               u'东二道',
#               u'东二道巷',
#               u'东五路',
#               u'东五道',
#               u'东仁路',
#               u'东仓巷',
#               u'东仪路',
#               u'东伍村',
#               u'东侯王村',
#               u'东保安滩村',
#               u'东停车场',
#               u'东元桥',
#               u'东元超市',
#               u'东八路',
#               u'东八道',
#               u'东八道巷',
#               u'东六路',
#               u'东六道',
#               u'东六道巷',
#               u'东关南街',
#               u'东关正街',
#               u'东兴街',
#               u'东北巷',
#               u'东区水房 锅炉房',
#               u'东区食堂',
#               u'东十一道巷',
#               u'东十道巷',
#               u'东半截巷',
#               u'东南城角',
#               u'东南城角隧道',
#               u'东南足球场',
#               u'东县门',
#               u'东司马村',
#               u'东四上道',
#               u'东四下道',
#               u'东四府村',
#               u'东四路',
#               u'东场',
#               u'东城大道',
#               u'东堡村',
#               u'东大时尚购物广场',
#               u'东大汽车站',
#               u'东大环山路口',
#               u'东大街',
#               u'东大街办',
#               u'东尧上村',
#               u'东岩村',
#               u'东岳庙',
#               u'东岳庙商城',
#               u'东峰酒店',
#               u'东广场',
#               u'东庄村',
#               u'东操场',
#               u'东新巷',
#               u'东新街',
#               u'东新路',
#               u'东方米兰',
#               u'东方红东路',
#               u'东方红广场',
#               u'东方红西路',
#               u'东明街',
#               u'东晋桃源',
#               u'东曹村',
#               u'东月路',
#               u'东月路公交停车场',
#               u'东杨万村',
#               u'东柳巷',
#               u'东梆子市街',
#               u'东江坡村',
#               u'东滩村',
#               u'东滩社区',
#               u'东环城路',
#               u'东环线',
#               u'东环路',
#               u'东盛北路',
#               u'东祝村',
#               u'东等驾坡',
#               u'东羊市',
#               u'东羊村',
#               u'东花园',
#               u'东街',
#               u'东街北堡',
#               u'东街北巷',
#               u'东街南巷',
#               u'东西街夜市',
#               u'东道巷',
#               u'东郡',
#               u'东长安街',
#               u'东门',
#               u'东门外',
#               u'东门宾馆',
#               u'东门广场',
#               u'东阶',
#               u'东韩村',
#               u'东风大街',
#               u'东风路',
#               u'东食堂',
#               u'东龙窝村',
#               u'两岔河站',
#               u'中一巷',
#               u'中三1300',
#               u'中三巷',
#               u'中二1200',
#               u'中二巷',
#               u'中五台路',
#               u'中兆村',
#               u'中兴路',
#               u'中冶一曲江山',
#               u'中华西路',
#               u'中南街',
#               u'中和巷',
#               u'中国',
#               u'中国农业银行',
#               u'中国唐苑',
#               u'中国工商银行ATM',
#               u'中国建筑西北设计研究院有限公司',
#               u'中国建设银行',
#               u'中国建设银行ATM',
#               u'中国电信营业厅',
#               u'中国石油',
#               u'中国邮政',
#               u'中国邮政李家村支行',
#               u'中国银行',
#               u'中图国际',
#               u'中山街',
#               u'中山门',
#               u'中心一楼',
#               u'中心三楼',
#               u'中心二楼',
#               u'中心大街北段',
#               u'中心大道',
#               u'中心环道',
#               u'中森路',
#               u'中环广场',
#               u'中祝村',
#               u'中航大厦',
#               u'中艮大道',
#               u'中街',
#               u'中通快递',
#               u'中铁一局医院',
#               u'丰一东路',
#               u'丰一西路',
#               u'丰三西路',
#               u'丰二东路',
#               u'丰二西路',
#               u'丰京路',
#               u'丰仪镇',
#               u'丰北巷',
#               u'丰原街',
#               u'丰原镇',
#               u'丰四东路',
#               u'丰四中路',
#               u'丰庆公园',
#               u'丰庆公园 东门',
#               u'丰庆公园 北门',
#               u'丰庆公园东门',
#               u'丰庆路',
#               u'丰收路',
#               u'丰景路',
#               u'丰登东路',
#               u'丰登北路',
#               u'丰登西路',
#               u'丰登路',
#               u'丰盛路',
#               u'丰禾二巷',
#               u'丰禾路',
#               u'丰镐一路',
#               u'丰镐东路',
#               u'丰镐二路',
#               u'丰隆路',
#               u'临平镇',
#               u'临河',
#               u'临渭区',
#               u'临渭区 (Linwei)',
#               u'临潼',
#               u'临潼北站',
#               u'临潼区',
#               u"临潼区 (Chang'an)",
#               u'临蓝路',
#               u'丹凤门东路',
#               u'丹凤门西路',
#               u'丹江',
#               u'丹江流域',
#               u'主体育场',
#               u'主楼',
#               u'主楼A座',
#               u'主楼B座',
#               u'主楼C座',
#               u'主楼D座',
#               u'主楼E座',
#               u'主题山坡',
#               u'乐园小巷',
#               u'乐天大街',
#               u'乐居场',
#               u'乐水大道',
#               u'乐游原（青龙寺遗址公园）',
#               u'乐育北路',
#               u'乐育南路',
#               u'乒乓球场',
#               u'乘风路',
#               u'九号楼',
#               u'九号路',
#               u'九峰乡',
#               u'九间房',
#               u'九间房镇',
#               u'九龙路',
#               u'习武园',
#               u'书山道',
#               u'书海楼',
#               u'书记办公室',
#               u'书院门 步行街',
#               u'书香路',
#               u'乾县',
#               u'乾县 (Qian)',
#               u'乾县服务区',
#               u'乾县站',
#               u'乾陵',
#               u'二十所社区南福利区',
#               u'二号楼',
#               u'二号路',
#               u'二府庄路',
#               u'二府街',
#               u'二曲镇',
#               u'二期小径',
#               u'二环东路',
#               u'二环北路',
#               u'二环北路东段',
#               u'二环北路西段',
#               u'二环南路',
#               u'二环南路东段',
#               u'二环南路西段',
#               u'二环路',
#               u'二环路延伸道',
#               u'二马路',
#               u'二龙山水库',
#               u'云天苑A座',
#               u'云天苑B座',
#               u'云天苑C座',
#               u'云天苑C座电信4G基站',
#               u'云天苑D座',
#               u'云天苑D座移动234G基站',
#               u'云天苑E座',
#               u'云天苑E座联通3G基站',
#               u'云天苑F座',
#               u'云天苑操场',
#               u'云天苑餐厅',
#               u'云天苑餐厅移动23G基站',
#               u'云阳镇',
#               u'互助立交',
#               u'五一巷',
#               u'五台街办',
#               u'五号楼',
#               u'五号路',
#               u'五味十字',
#               u'五四巷',
#               u'五岳庙门',
#               u'五府井',
#               u'五星街',
#               u'五星街办',
#               u'五路口',
#               u'五路口站',
#               u'五道十字东街',
#               u'五道十字南街',
#               u'五道十字西街',
#               u'亘垣堡',
#               u'亚美大厦',
#               u'亞洲公路34號線',
#               u'亞洲公路5號線',
#               u'交口镇',
#               u'交大一村',
#               u'交大二、三村',
#               u'交大二附院',
#               u'交大公安处',
#               u'交大出版大厦',
#               u'交大南门',
#               u'交大机械厂',
#               u'交大校医院',
# ...
#                       'Wei basin',
#                       'Wei basin (Huang He)']),
#  'park_ride': set(['yes']),
#  'parking': set(['surface', 'underground']),
#  'payment:bitcoin': set(['yes']),
#  'phone': set(['+86 29 85675999',
#                '+86 29 87672666',
#                '+86 29 88315552',
#                '+8613384912615',
#                '+862983133018',
#                '+86298385555',
#                '+862987608888',
#                '0086(029) 87389911',
#                '029-68519348',
#                u'029-81292881(考务） 81292882（市场） 81292880（督察）',
#                '029-86291507',
#                '029-87239098',
#                '86-29-85563333',
#                '86-29-88866888',
#                '86-2988668888']),
#  'place': set(['city',
#                'county',
#                'hamlet',
#                'island',
#                'locality',
#                'neighbourhood',
#                'region',
#                'square',
#                'suburb',
#                'town',
#                'village',
#                'yes']),
#  'plant:output:hot_water': set(['yes']),
#  'population': set(['5000', '5500', '6501200']),
#  'postal_code': set(['713400']),
#  'power': set(['generator',
#                'line',
#                'minor_line',
#                'plant',
#                'pole',
#                'station',
#                'substation',
#                'tower',
#                'transformer']),
#  'public_transport': set(['platform', 'station', 'stop_position']),
#  'railway': set(['abandoned',
#                  'buffer_stop',
#                  'construction',
#                  'crossing',
#                  'disused',
#                  'halt',
#                  'level_crossing',
#                  'platform',
#                  'rail',
#                  'station',
#                  'subway',
#                  'subway_entrance',
#                  'yes']),
#  'ramp': set(['yes']),
#  'ref': set(['05/23',
#              '05L/23R',
#              '05R/23L',
#              '06L/24R',
#              '06R/24L',
#              '07/25',
#              '1',
#              '101',
#              '102',
#              '103',
#              '104',
#              '105',
#              '106',
#              '107',
#              '108',
#              '109',
#              '110',
#              '111',
#              '112',
#              '113',
#              '114',
#              '2',
#              '205',
#              '206',
#              '210',
#              '220',
#              '313',
#              '324',
#              '33',
#              '34',
#              '351',
#              '402',
#              '59',
#              '6',
#              '607',
#              '608',
#              '609, 237, 24, 224, 619, 23, 22, 401, 527, 510, 5, 27, 701, 715, 19, 500, 408, 601, 30, 242, 44, 21',
#              'AH34',
#              'AH5',
#              'C2',
#              'G045',
#              'G108',
#              'G108;G310',
#              'G108;S201',
#              'G210',
#              'G211',
#              'G30',
#              'G3001',
#              'G3011',
#              'G309',
#              'G30N',
#              'G310',
#              'G310;G108',
#              'G312',
#              'G40',
#              'G40;G70',
#              'G5',
#              'G65',
#              'G65W',
#              'G69',
#              'G70',
#              'G70;G40',
#              'K228',
#              'K45',
#              'K600',
#              'K616',
#              'K700',
#              'K800',
#              'S101',
#              'S104',
#              'S105',
#              'S106',
#              'S106;S107',
#              'S107',
#              'S108',
#              'S20',
#              'S201',
#              'S202',
#              'S208',
#              'S307',
#              'X101',
#              'X102',
#              'X104',
#              'X105',
#              'X106',
#              'X108',
#              'X201',
#              'X202',
#              'X204',
#              'X207',
#              'X208',
#              'X212',
#              'X213',
#              'X214',
#              'X215',
#              'X219',
#              'X225',
#              'X234',
#              'X301',
#              'X303',
#              'X309',
#              'X312',
#              'X313',
#              'X315',
#              'X316',
#              'X317',
#              'X319',
#              'X331',
#              'XIY',
#              'Y252',
#              'Y344',
#              'Y414',
#              u'储藏室',
#              u'咸阳',
#              u'商洛',
#              u'安康',
#              u'宝鸡',
#              u'杨凌',
#              u'榆林',
#              u'汉中',
#              u'渭南',
#              u'陕 / 秦']),
#  'ref_int': set(['G312']),
#  'reg': set(['G312']),
#  'religion': set(['buddhist', 'christian', 'muslim', 'taoist']),
#  'restriction': set(['no_left_turn',
#                      'no_u_turn',
#                      'only_right_turn',
#                      'only_straight_on']),
#  'roof:colour': set(['#66ab9f']),
#  'roof:height': set(['16']),
#  'roof:shape': set(['dome', 'pyramidal']),
#  'roundabout': set(['yes']),
#  'route': set(['bus', 'railway', 'road', 'subway', 'train']),
#  'sac_scale': set(['mountain_hiking']),
#  'seamark:mooring:category': set(['dolphin']),
#  'seamark:type': set(['mooring']),
#  'seats': set(['2', '4', '6']),
#  'service': set(['alley',
#                  'driveway',
#                  'parking_aisle',
#                  'siding',
#                  'spur',
#                  'yard']),
#  'shelter': set(['no', 'yes']),
#  'shop': set(['bakery',
#               'beverages',
#               'bicycle',
#               'books',
#               'boutique',
#               'car',
#               'car_repair',
#               'clothes',
#               'computer',
#               'confectionery',
#               'convenience',
#               'copyshop',
#               'department_store',
#               'doityourself',
#               'electronics',
#               'furniture',
#               'gift',
#               'greengrocer',
#               'hairdresser',
#               'jewelry',
#               'kiosk',
#               'mall',
#               'massage',
#               'mobile_phone',
#               'optician',
#               'outdoor',
#               'photo',
#               'plants',
#               'shoes',
#               'sports',
#               'stationery',
#               'supermarket',
#               'ticket',
#               'variety_store',
#               'wine',
#               'yes']),
#  'short_name': set(['Grand Park']),
#  'short_name:ru': set([u'КНР']),
#  'sidewalk': set(['both', 'left', 'right']),
#  'ski': set(['no']),
#  'smoking': set(['isolated', 'no', 'separated', 'yes']),
#  'snowmobile': set(['no']),
#  'source': set(['Bing',
#                 'China Data Center, University of Michigan',
#                 'GNS',
#                 'GPS',
#                 'GPS on OSM',
#                 'GPX',
#                 'Lakewalker / Landsat',
#                 'MapBox Satellite',
#                 'Mapbox',
#                 'Yahoo',
#                 'along river',
#                 'bing',
#                 'cyclemap',
#                 'estimated',
#                 'gps;bing',
#                 'http://upload.wikimedia.org/wikipedia/commons/4/4b/Administrative_Division_Baoji.png',
#                 'http://upload.wikimedia.org/wikipedia/commons/f/f4/Administrative_Division_Weinan.png',
#                 'http://www.fzcxx.cn/',
#                 'https://upload.wikimedia.org/wikipedia/commons/8/8a/Administrative_Division_Xianyang.png',
#                 "https://upload.wikimedia.org/wikipedia/commons/f/fe/Administrative_Division_Xi'an.png",
#                 'landsat',
#                 'mapbox',
#                 'osm-gpx',
#                 'ourairports.com',
#                 'wikipedia',
#                 'yahoo satelite',
#                 u'二期草坪',
#                 u'奥林匹克花园一二期',
#                 u'奥林匹克花园二期大门',
#                 u'奥林匹克花园运动会所',
#                 u'废弃的收费站',
#                 u'西安奥林匹克花园',
#                 u'西安奥林匹克花园入口大门']),
#  'source:name': set(['GNS']),
#  'source:position': set(['mapbox']),
#  'source:tracer': set(['scanaerial']),
#  'source:zoomlevel': set(['15']),
#  'sport': set(['basketball',
#                'gaelic_football',
#                'golf',
#                'motor',
#                'soccer',
#                'swimming',
#                'table_tennis',
#                'tennis',
#                'volleyball']),
#  'stars': set(['4', '5']),
#  'step_count': set(['10']),
#  'supervised': set(['yes']),
#  'surface': set(['asphalt',
#                  'cobblestone',
#                  'compacted',
#                  'concrete',
#                  'grass',
#                  'gravel',
#                  'paved',
#                  'paving_stones',
#                  'unpaved']),
#  'takeaway': set(['yes']),
#  'timezone': set(['Asia/Chongqing']),
#  'toilets:disposal': set(['flush']),
#  'toilets:position': set(['seated']),
#  'toll': set(['yes']),
#  'tourism': set(['artwork',
#                  'attraction',
#                  'caravan_site',
#                  'guest_house',
#                  'hostel',
#                  'hotel',
#                  'information',
#                  'motel',
#                  'museum',
#                  'theme_park',
#                  'viewpoint',
#                  'yes',
#                  'zoo']),
#  'tracktype': set(['grade3']),
#  'trail_visibility': set(['excellent', 'good']),
#  'tributary_of': set(['Wei River']),
#  'tunnel': set(['building_passage', 'yes']),
#  'type': set(['boundary',
#               'building',
#               'collection',
#               'level',
#               'multipolygon',
#               'public',
#               'restriction',
#               'route',
#               'watershed',
#               'waterway']),
#  'usage': set(['main', 'military']),
#  'voltage': set(['25000']),
#  'water': set(['lake', 'pond', 'reservoir']),
#  'waterway': set(['canal',
#                   'dam',
#                   'ditch',
#                   'drain',
#                   'river',
#                   'riverbank',
#                   'stream',
#                   'weir']),
#  'website': set(['centuryginwa.com.cn',
#                  'http://dmgpark.com/',
#                  'http://enhz.sntcm.edu.cn/',
#                  'http://http://www.gaokehotel.cn/',
#                  'http://ltecn.com',
#                  'http://www.chd.edu.cn/',
#                  'http://www.cscecnwi.com/',
#                  'http://www.dtbxf.com',
#                  'http://www.ihg.com/crowneplaza/hotels/us/en/xian/siazq/hoteldetail',
#                  'http://www.legardens.com',
#                  'http://www.niuyizui.com.cn/',
#                  'http://www.nwpu.edu.cn/',
#                  'http://www.shaanxirk.com/',
#                  'http://www.snnu.edu.cn/',
#                  'http://www.youngpioneertours.com/',
#                  'http://xian.baronyhotels.com/',
#                  'http://zjq.in',
#                  'http://zjq.in/',
#                  'ourlotus.com',
#                  'segbuy.com',
#                  'www.hqspa.com',
#                  'www.parkhotelgroup.com',
#                  'zictionliberal-hotel.com']),
#  'wheelchair': set(['limited', 'no', 'yes']),
#  'width': set(['1', '15', '2', '3', '4', '7', '7 m']),
#  'width:lanes:end': set(['3.5|3.5|3.5|3.5', '3|3']),
#  'width:lanes:start': set(['3.5|3.5|3.5|3.5', '3|3']),
#  'wifi': set(['free']),
#  'wikidata': set(['Q1061858',
#                   'Q1089609',
#                   'Q112568',
#                   'Q1152653',
#                   'Q1201078',
#                   'Q1201091',
#                   'Q1201092',
#                   'Q1201166',
#                   'Q1201362',
#                   'Q1201570',
#                   'Q1201612',
#                   'Q1201642',
#                   'Q1201675',
#                   'Q1204238',
#                   'Q1204978',
#                   'Q1245669',
#                   'Q1339819',
#                   'Q1339891',
#                   'Q1339915',
#                   'Q1358528',
#                   'Q1358596',
#                   'Q1358657',
#                   'Q148',
#                   'Q194635',
#                   'Q198072',
#                   'Q280060',
#                   'Q47974',
#                   'Q497341',
#                   'Q515983',
#                   'Q5826',
#                   'Q773033',
#                   'Q785966',
#                   'Q814746',
#                   'Q847641',
#                   'Q937661']),
#  'wikipedia': set(['de:Daqin-Pagode',
#                    u'de:Stelenwald von Xi’an',
#                    'en:Baqiao District',
#                    "en:Beilin District, Xi'an",
#                    "en:Chang'an District, Xi'an",
#                    'en:China',
#                    'en:Chinese pyramids',
#                    'en:Chinese_pyramids',
#                    'en:Chunhua County',
#                    'en:Hu County',
#                    'en:Huayin',
#                    'en:Jing River',
#                    'en:Jingyang County',
#                    'en:Lantian County',
#                    'en:Lianhu District',
#                    'en:Lintong District',
#                    'en:Liquan County',
#                    'en:Luo River (Henan)',
#                    'en:Luo River (Shaanxi)',
#                    'en:Mount Li',
#                    'en:Qian County',
#                    'en:Qindu District',
#                    'en:Sanyuan County',
#                    'en:Shaanxi University of Chinese Medicine',
#                    'en:Wei River',
#                    'en:Weicheng District, Xianyang',
#                    "en:Weiyang District, Xi'an",
#                    'en:Wugong County',
#                    "en:Xi'an",
#                    u"en:Xi'an–Chengdu_High-Speed_Railway",
#                    'en:Xianyang',
#                    "en:Xincheng District, Xi'an",
#                    'en:Xingping',
#                    'en:Yangling District',
#                    'en:Yanliang District',
#                    'en:Yanta District',
#                    'en:Yongshou County',
#                    'en:Zhongnanshan Tunnel',
#                    'en:Zhouzhi County',
#                    'pl:Hua Shan',
#                    u'zh:乾县',
#                    u'zh:二曲镇',
#                    u'zh:仪井镇',
#                    u'zh:侯家村镇',
#                    u'zh:八云塔',
#                    u'zh:兴平市',
#                    u'zh:华阴市',
#                    u'zh:咸铜铁路',
#                    u'zh:咸阳市',
#                    u'zh:哑柏镇',
#                    u'zh:商洛市',
#                    u'zh:店头镇 (永寿县)',
#                    u'zh:楼观镇',
#                    u'zh:沪陕高速公路',
#                    u'zh:泔河水库',
#                    u'zh:渭南市',
#                    u'zh:监军镇',
#                    u'zh:石牛乡 (乾县)',
#                    u'zh:秦岭中学',
#                    u'zh:终南镇',
#                    u'zh:西北工业大学',
#                    u'zh:西安市',
#                    u'zh:西安鼓楼',
#                    u'zh:西康铁路',
#                    u'zh:辛家寨镇',
#                    u'zh:阳洪镇',
#                    u'zh:陈河镇 (周至县)',
#                    u'zh:陕西省',
#                    u'zh:集贤镇 (周至县)',
#                    u'zh:马召镇',
#                    u'zh:高陵区']),
#  'wikipedia:en': set(['Baoji',
#                       'China_National_Highway_108',
#                       'Dali County',
#                       'Fufeng County',
#                       'Fuping County, Shaanxi',
#                       u'G30 Lianyungang–Khorgas Expressway',
#                       'Hua County, Shaanxi',
#                       'Linwei District',
#                       'Linyou County',
#                       'Luonan County',
#                       'Mei County, Shaanxi',
#                       'Northwestern_Polytechnical_University',
#                       'Shangzhou District',
#                       'Tongguan County',
#                       'Weinan',
#                       "Xi'an City People's Stadium",
#                       'Zhashui County']),
#  'wikipedia:zh': set([u'http://zh.wikipedia.org/wiki/福银高速',
#                       u'西延铁路']),
#  'zhb_code': set(['09DB460000',
#                   '09DD000000',
#                   '09DD140000',
#                   '09DD160000',
#                   '09DD180000',
#                   '09DD200000',
#                   '09DD210000',
#                   '09DD211800',
#                   '09DD220000',
#                   '09DD240000',
#                   '09DD260000',
#                   '11FJ000000',
#                   '11FJ460000'])}

# %% [markdown]
# Now, let's investigate the tags with keys occurred most often. First, the highway tags:

# %%
pprint(agg['highway'])
# Out:
# set(['bus_stop',
#      'construction',
#      'crossing',
#      'cycleway',
#      'footway',
#      'living_street',
#      'mini_roundabout',
#      'motorway',
#      'motorway_junction',
#      'motorway_link',
#      'path',
#      'pedestrian',
#      'platform',
#      'primary',
#      'primary_link',
#      'raceway',
#      'residential',
#      'rest_area',
#      'road',
#      'secondary',
#      'secondary_link',
#      'service',
#      'services',
#      'steps',
#      'tertiary',
#      'tertiary_link',
#      'track',
#      'traffic_signals',
#      'trunk',
#      'trunk_link',
#      'turning_circle',
#      'unclassified',
#      'via_ferrata'])

# %% [markdown]
# Meh, the highway tags look as boring as all the hours you could spend asking "Are we there yet?" when driving on them. What about the name tags?

# %%
pprint(agg['name'])
# Out:
# set([u' 陕西中医大学',
#      u'06号',
#      '1',
#      '103',
#      '106,721',
#      '107',
#      '107, 34',
#      '107,34',
#      '107,512,34',
#      '107,512,608,34',
#      u'107省道',
#      u'108国道',
#      u'108省道',
#      u'10号宿舍楼',
#      u'10号教学楼',
#      u'113分叉',
#      u'113县道',
#      u'113县道3',
#      u'11号宿舍楼',
#      u'12号宿舍楼',
#      u'12楼',
#      u'13号宿舍楼',
#      '14,312,...',
#      u'14号宿舍楼',
#      u'17楼',
#      u'19号楼',
#      u'19号楼（1994年建）',
#      u'1北楼',
#      u'1号宿舍楼',
#      u'1号教学楼',
#      u'1号楼',
#      u'1号高层',
#      '2',
#      '205',
#      '206',
#      '207,35,...',
#      '209, ...',
#      u'20楼',
#      u'210国道',
#      u'211国道',
#      '212, ...',
#      '220',
#      u'24楼',
#      '251',
#      '251, 908, 512, 608, ...',
#      '251, 908, 608',
#      '251,29,908',
#      '251,901,29',
#      '251,908,29, ...',
#      '261',
#      '261, 262',
#      '262',
#      '29,411',
#      '29,908,411',
#      '2nd Ring Road',
#      u'2号宿舍楼',
#      u'2号教学楼',
#      u'2号楼',
#      u'2号高层',
#      '3',
#      '308,X7,...',
#      u'310国道',
#      '312,14,604,X7,...',
#      u'312国道',
#      '313',
#      '32',
#      '32,710',
#      '324',
#      '33',
#      '34',
#      '351',
#      u'3号宿舍楼',
#      u'3号教学楼',
#      u'3号楼',
#      u'3号高层',
#      '4',
#      '40, ...',
#      '40, 262, ...',
#      '40,400,721',
#      '402',
#      '411',
#      '45',
#      u'45号楼',
#      u'47号楼',
#      u'4号宿舍楼',
#      u'4号教学楼',
#      u'4号高层',
#      '5',
#      u'500M射电望远镜',
#      '502',
#      u'505体育馆',
#      '506, ...',
#      '512',
#      '512,212,...',
#      '512,29,608,...',
#      '512,712,...',
#      '526, ...',
#      u'54楼',
#      u'557村道',
#      u'559村道',
#      u'559村道2',
#      u'559村道3',
#      u'55号楼',
#      '59',
#      u'5号宿舍楼',
#      u'5号教学楼',
#      '6',
#      u'6,16,k35,k205,311,411,506,900,900区间,916,教育专线,通宵2号线',
#      u'6,k35,k205,311,411,506,900,900区间,916,教育专线,通宵2号线',
#      '607',
#      '608',
#      '611, 603',
#      u'6号宿舍楼',
#      u'6号教学楼',
#      '707',
#      '707,...',
#      '709, 526, ...',
#      '710',
#      '713, 44, ...',
#      '721',
#      '721,...',
#      u'7号宿舍楼',
#      u'7号教学楼',
#      u'7天快捷酒店',
#      u'7天连锁酒店',
#      '8',
#      u'85中',
#      u'8号宿舍楼',
#      u'8号教学楼',
#      '902, ...',
#      '905, 526, ...',
#      '905, 526, 30, ...',
#      '908, 29',
#      '908, 29, ...',
#      '908, 29, 608, 707, ...',
#      u'9号宿舍楼',
#      'A',
#      'ABC Bank ',
#      'Airport Shuttle Service / Long Hai Hotel',
#      'Alley Yuth Hostel',
#      'Antique Market',
#      'Applied Materials',
#      'Archeological Exploration Center',
#      'Atour Hotel',
#      'Aurum International Hotel',
#      u'A楼',
#      'B',
#      'B1',
#      'B2',
#      'B3',
#      'B4',
#      'Bacchus Pizza',
#      'Banana Leaf',
#      u'Bang Bang 面',
#      'Bank of Communications',
#      'Banpo Site',
#      'Basketball pitch',
#      'Baskin & Robins',
#      'Beer Garden',
#      'Bierhaus - Paulaner',
#      'Building3',
#      'Bus terminal',
#      u'B楼',
#      'C',
#      'C051',
#      'C511',
#      'CNG  Gas Station ',
#      'Cable car Ticket office',
#      'Cambridge Restaurant',
#      'Car Repair',
#      'Car Repair Parking',
#      "Chang'an University",
#      'Chess Pavilion',
#      'China Construction Bank',
#      'China Construction Bank 24-hour Self-service Bank',
#      'China Lanzhou Beef Noodles',
#      'China Unicom',
#      'City Gate',
#      'Coffee House',
#      "Crowne Plaza Xi'an",
#      u'C楼',
#      'DHL',
#      'DQ',
#      'Dabeigou Shuiku',
#      'Daming Palace Heritage Museum',
#      'Daming Palace Natural Heritage Park',
#      'Daxing Rd(E)',
#      'Days Hotel & Suites',
#      'Dicos',
#      'Dumplings',
#      u'D楼',
#      'Eastwood Inn',
#      u'Emerson研发中心',
#      'Empark Grand Hotel',
#      "Empress' Tomb",
#      'Epin life',
#      "Evan's Park",
#      'Exhibition Hall',
#      u'E楼',
#      'Facebook Hostel',
#      'Facebook Youth Hostel',
#      'First Noodle under the sun',
#      'Five Li Pass',
#      'Foreign Language Studies University, new Campus',
#      'Foreign Language Studies University, old Campus',
#      'Free shuttle to Mausoleum',
#      'Free shuttle to Teracotta Army',
#      'Furong Lake',
#      'Fuxue Alley',
#      u'F楼',
#      'G210',
#      'G211',
#      'G30',
#      'G3001',
#      'G3011',
#      'G310',
#      'G40',
#      u'G65 包茂高速公路',
#      'G65W',
#      u'G70 福银高速',
#      'G70;G40',
#      'Gaoling Xian',
#      'Gaoxin erlu',
#      'Giant',
#      'Golden Flower Hotel',
#      'Golden Lock Gate',
#      'Gooseberry Cafe',
#      u'Grand Mercure Xian On Renmin Square 西安豪华美居人民大厦',
#      'Grand Park Xian',
#      'Grand Soluxe International Hotel',
#      u'Große Wildganspagode Xian',
#      'Guangzhong Hotel',
#      'Guava Youth Hostel',
#      u'G楼',
#      'HSBC',
#      'Haidilao Hot Pot Cheng',
#      'Hairy Woman Cave',
#      'Han Tang Inn',
#      'Hantang House',
#      'Hanting Hotels',
#      'Hanyangling',
#      'High Fly Pizza',
#      'Home World',
#      'Hooters',
#      'Howard Johnson Ginwa Plaza',
#      'HuaRenWanJia',
#      'Huaqing Aegean Int. Hot Spring Resort & Spa',
#      'Huaqing Hot Springs',
#      'Huashan Gate',
#      'Hunyuan Stone',
#      'IMAX',
#      'Ibis Heping Gate Hotel',
#      'Japanese',
#      'Jianguo Hotel',
#      "Jianguo Hotel Xi'An",
#      'Jiefang Hotel',
#      'Jin Suo Guan',
#      'Jinjang Hotel',
#      'Jinjiang',
#      'K0009 pit',
#      'K2 summit',
#      'K228',
#      'K45',
#      'K600',
#      'K616',
#      'K700',
#      'K800',
#      'KFC',
#      u'KFC汽车穿梭餐厅',
#      'Keji 7 road',
#      'Keji Er Rd',
#      'Lao Sun Jia',
#      'Li',
#      'Longhai Line',
#      'Lotus',
#      'METRO',
#      'MYFO Wanshunyuan INN',
#      'Majieling Tunnel',
#      u'Mark and Henry Apartment(马克亨瑞公寓酒店）',
#      "McDonald's",
#      'McDonalds',
#      'Mcdonalds',
#      'Meet Capsule Hotel',
#      'Melody Hotel',
#      'Mercure on Renmin Square Xian',
#      'Merida',
#      "Ming's wine",
#      'Minsheng Jiale Shopping Plaza',
#      'More pits',
#      'Mr.Li',
#      'Muhuguan Tunnel',
#      'Nan Yao Tou',
#      'New Century Club',
#      'New Eurasian Land Bridge',
#      'Noodle shop',
#      'Oujiexi Holiday Hotel',
#      'PAPA Capsule Hostel',
#      'PSB office for visa extensions',
#      'Pacific Coffee ',
#      'Parkson',
#      u'Patisserie Française',
#      'Paulaner',
#      'Pit K0006',
#      'Pizza Hut',
#      'Plank Walk',
#      'Plant Market',
#      'Police Station',
#      'Prince Lofty',
#      'Public Bus Stop for Terracota Warriors (Bus 306)',
#      'Public bus stop',
#      'Qianxuesen Library',
#      'Qingke Terrace',
#      'Qunxian Temple',
#      "Ramada Xi'an Bell Tower",
#      'Real Love (7th floor)',
#      'Ren Ren Ju',
#      'Ren Ren Le',
#      'Ring Expy',
#      'S101',
#      'S104',
#      'S105',
#      'S107',
#      'S108',
#      'S201',
#      'S202',
#      'S307',
#      u'SOLO公寓',
#      'Saiga Electronics Market',
#      'See Tang Hostel',
#      'See tang hostel',
#      'Shaanxi Grand Opera House',
#      'Shaanxi Yijia Express Hotel',
#      'Shaanxi electric power company  community',
#      'Shalou Terrace',
#      'Shangpin Gelan',
#      'Shangri La',
#      'Shell',
#      'Shengna Fashion Square',
#      'Sheraton',
#      'Sheraton North',
#      'Shizhan',
#      'Shuttle Service To The Airport ',
#      'Shuyuan International Party Hostel',
#      'SkyBar',
#      'Smoothie King',
#      'South Gate Tower',
#      'South Heavenly Gate',
#      'Sports Complex',
#      'St. Louis Portugese',
#      'Starbucks',
#      'Starbucks ',
#      'Starbucks Coffee',
#      'Subway',
#      'Super 8',
#      u'Super 8 速8酒店',
#      'Suwu Tome',
#      u'TIGER国际公寓',
#      'Tang Cheng Hotel',
#      'Tang Du Stele Forest Art Museum',
#      'Tang Dynasty Art Garden Hotel',
#      'Tangyan Lu',
#      'Tangyan Nan Lu',
#      'Temple of 8 Immortals',
#      'Temple of the Eight Immortals',
#      'Terracotta Factory ',
#      'Terrakotta Armee Xian',
#      'The Arsenals of Resistance',
#      'The Main Building',
#      'The Pegasus Company',
#      "The Tang Dynasty, Xi'an",
#      'Three Sisters Dumplings',
#      'Tianyi Hotel',
#      'Ticket office',
#      'Tourist bus 4',
#      'Unicom',
#      'Vanguard',
#      'Wal-Mart',
#      'Warriors International Hostel',
#      'Watsons',
#      'Weipu Expwy',
#      'West Electronic Market',
#      'West Restaurant',
#      'Wugong Air Base',
#      'Wyndham hotel',
#      'X101',
#      'X216',
#      'X227',
#      'X319',
#      'XISU',
#      'Xi Ba Lu ( Terracotta Warrior Museum)',
#      "Xi'An Hometown Hostel",
#      "Xi'an",
#      "Xi'an Bell Tower Lijing Hotel",
#      "Xi'an Da Qin Terracotta & Lacquer Furniture Art Factory",
#      "Xi'an Facebook Youth Hostel ",
#      "Xi'an See Tang Hostel",
#      "Xi'an Warriors Hostel",
#      'XiQi International HoteI',
#      'Xianyang',
#      'Xidian University (New Campus)',
#      'Xiwan Gong Lu',
#      'Yaijie Guesthouse',
#      'Yanta Rd',
#      'Yasen Park',
#      'YeJia Inn',
#      'Yong Ning International Art museum',
#      'Young Pioneer Tours',
#      'Yuan village food tourist park',
#      'Zhouling',
#      'beixiu1',
#      'bus 702',
#      u'décathlon store',
#      'ecco footware',
#      'grand noble hotel',
#      'greenants outdoor',
#      'mia house',
#      'pagoda',
#      'parada 702',
#      u'一中北路',
#      u'一卡通中心',
#      u'一卡通服务大厅',
#      u'一号宿舍楼',
#      u'一号楼',
#      u'一号路',
#      u'丁家村西街',
#      u'丁家桥',
#      u'丁家桥: 107, 218, 251, 908',
#      u'丁家桥: 218, 251',
#      u'丁家桥巷',
#      u'丁家桥村道',
#      u'丁村',
#      u'丁白路',
#      u'丁香餐厅',
#      u'七一东路',
#      u'七一西路',
#      u'七号楼',
#      u'七号路',
#      u'万北路',
#      u'万南西路',
#      u'万国一径',
#      u'万国二径',
#      u'万家灯火',
#      u'万家福便利店',
#      u'万寿中路',
#      u'万寿北路',
#      u'万寿南路',
#      u'万寿路站',
#      u'万年路',
#      u'万庆巷',
#      u'万豪酒店',
#      u'万达广场一号路',
#      u'万达百货民乐园店',
#      u'丈八一路',
#      u'丈八七路',
#      u'丈八三路',
#      u'丈八东路',
#      u'丈八二路',
#      u'丈八五路',
#      u'丈八六路',
#      u'丈八北路',
#      u'丈八北路 / Zhangba Bei Lu',
#      u'丈八北路站',
#      u'丈八四路',
#      u'丈八四路北段',
#      u'丈八街办',
#      u'丈八西路',
#      u'丈杜路',
#      u'三五零七社区',
#      u'三兆村',
#      u'三兆路',
#      u'三兆路 Sānzhào Rd',
#      u'三南路',
#      u'三原',
#      u'三原县',
#      u'三原县 (Sanyuan)',
#      u'三原站',
#      u'三号坑',
#      u'三号楼',
#      u'三号路',
#      u'三姐妹饺子 @ 东木头市店',
#      u'三家庄',
#      u'三张镇',
#      u'三星',
#      u'三星工业园区',
#      u'三星快速干道',
#      u'三星立交',
#      u'三桥收费站',
#      u'三桥村',
#      u'三桥立交',
#      u'三桥站',
#      u'三桥街办',
#      u'三殿桥',
#      u'三民村站',
#      u'三渠镇',
#      u'三爻站',
#      u'三环辅道',
#      u'三航路',
#      u'三贤路',
#      u'三过村',
#      u'三里镇',
#      u'上小径',
#      u'上林体育馆',
#      u'上林斜路',
#      u'上林路',
#      u'上河道',
#      u'上王村',
#      u'上草村',
#      u'上陆陌',
#      u'下北街',
#      u'下寨镇',
#      u'下庙镇',
#      u'下草村',
#      u'下西街',
#      u'专家楼',
#      u'世博园站',
#      u'世博大道',
#      u'世园花卉交易中心(绿叶庄园)',
#      u'世家星城',
#      u'世纪大道',
#      u'世纪大道辅道',
#      u'世纪西路',
#      u'世纪金花',
#      u'世纪锦绣乐乐超市',
#      u'丘',
#      u'东10舍',
#      u'东11舍',
#      u'东12舍',
#      u'东13舍',
#      u'东14舍',
#      u'东15舍',
#      u'东16舍',
#      u'东一巷',
#      u'东一楼',
#      u'东一路',
#      u'东七路',
#      u'东七道',
#      u'东七道巷',
#      u'东三楼',
#      u'东三环路',
#      u'东三环辅道',
#      u'东三路',
#      u'东三道',
#      u'东三道巷',
#      u'东九道',
#      u'东九道巷',
#      u'东二楼',
#      u'东二环',
#      u'东二环路',
#      u'东二路',
#      u'东二道',
#      u'东二道巷',
#      u'东五路',
#      u'东五道',
#      u'东仁路',
#      u'东仓巷',
#      u'东仪路',
#      u'东伍村',
#      u'东侯王村',
#      u'东保安滩村',
#      u'东停车场',
#      u'东元桥',
#      u'东元超市',
#      u'东八路',
#      u'东八道',
#      u'东八道巷',
#      u'东六路',
#      u'东六道',
#      u'东六道巷',
#      u'东关南街',
#      u'东关正街',
#      u'东兴街',
#      u'东北巷',
#      u'东区水房 锅炉房',
#      u'东区食堂',
#      u'东十一道巷',
#      u'东十道巷',
#      u'东半截巷',
#      u'东南城角',
#      u'东南城角隧道',
#      u'东南足球场',
#      u'东县门',
#      u'东司马村',
#      u'东四上道',
#      u'东四下道',
#      u'东四府村',
#      u'东四路',
#      u'东场',
#      u'东城大道',
#      u'东堡村',
#      u'东大时尚购物广场',
#      u'东大汽车站',
#      u'东大环山路口',
#      u'东大街',
#      u'东大街办',
#      u'东尧上村',
#      u'东岩村',
#      u'东岳庙',
#      u'东岳庙商城',
#      u'东峰酒店',
#      u'东广场',
#      u'东庄村',
#      u'东操场',
#      u'东新巷',
#      u'东新街',
#      u'东新路',
#      u'东方米兰',
#      u'东方红东路',
#      u'东方红广场',
#      u'东方红西路',
#      u'东明街',
#      u'东晋桃源',
#      u'东曹村',
#      u'东月路',
#      u'东月路公交停车场',
#      u'东杨万村',
#      u'东柳巷',
#      u'东梆子市街',
#      u'东江坡村',
#      u'东滩村',
#      u'东滩社区',
#      u'东环城路',
#      u'东环线',
#      u'东环路',
#      u'东盛北路',
#      u'东祝村',
#      u'东等驾坡',
#      u'东羊市',
#      u'东羊村',
#      u'东花园',
#      u'东街',
#      u'东街北堡',
#      u'东街北巷',
#      u'东街南巷',
#      u'东西街夜市',
#      u'东道巷',
#      u'东郡',
#      u'东长安街',
#      u'东门',
#      u'东门外',
#      u'东门宾馆',
#      u'东门广场',
#      u'东阶',
#      u'东韩村',
#      u'东风大街',
#      u'东风路',
#      u'东食堂',
#      u'东龙窝村',
#      u'两岔河站',
#      u'中一巷',
#      u'中三1300',
#      u'中三巷',
#      u'中二1200',
#      u'中二巷',
#      u'中五台路',
#      u'中兆村',
#      u'中兴路',
#      u'中冶一曲江山',
#      u'中华西路',
#      u'中南街',
#      u'中和巷',
#      u'中国',
#      u'中国农业银行',
#      u'中国唐苑',
#      u'中国工商银行ATM',
#      u'中国建筑西北设计研究院有限公司',
#      u'中国建设银行',
#      u'中国建设银行ATM',
#      u'中国电信营业厅',
#      u'中国石油',
#      u'中国邮政',
#      u'中国邮政李家村支行',
#      u'中国银行',
#      u'中图国际',
#      u'中山街',
#      u'中山门',
#      u'中心一楼',
#      u'中心三楼',
#      u'中心二楼',
#      u'中心大街北段',
#      u'中心大道',
#      u'中心环道',
#      u'中森路',
#      u'中环广场',
#      u'中祝村',
#      u'中航大厦',
#      u'中艮大道',
#      u'中街',
#      u'中通快递',
#      u'中铁一局医院',
#      u'丰一东路',
#      u'丰一西路',
#      u'丰三西路',
#      u'丰二东路',
#      u'丰二西路',
#      u'丰京路',
#      u'丰仪镇',
#      u'丰北巷',
#      u'丰原街',
#      u'丰原镇',
#      u'丰四东路',
#      u'丰四中路',
#      u'丰庆公园',
#      u'丰庆公园 东门',
#      u'丰庆公园 北门',
#      u'丰庆公园东门',
#      u'丰庆路',
#      u'丰收路',
#      u'丰景路',
#      u'丰登东路',
#      u'丰登北路',
#      u'丰登西路',
#      u'丰登路',
#      u'丰盛路',
#      u'丰禾二巷',
#      u'丰禾路',
#      u'丰镐一路',
#      u'丰镐东路',
#      u'丰镐二路',
#      u'丰隆路',
#      u'临平镇',
#      u'临河',
#      u'临渭区',
#      u'临渭区 (Linwei)',
#      u'临潼',
#      u'临潼北站',
#      u'临潼区',
#      u"临潼区 (Chang'an)",
#      u'临蓝路',
#      u'丹凤门东路',
#      u'丹凤门西路',
#      u'丹江',
#      u'丹江流域',
#      u'主体育场',
#      u'主楼',
#      u'主楼A座',
#      u'主楼B座',
#      u'主楼C座',
#      u'主楼D座',
#      u'主楼E座',
#      u'主题山坡',
#      u'乐园小巷',
#      u'乐天大街',
#      u'乐居场',
#      u'乐水大道',
#      u'乐游原（青龙寺遗址公园）',
#      u'乐育北路',
#      u'乐育南路',
#      u'乒乓球场',
#      u'乘风路',
#      u'九号楼',
#      u'九号路',
#      u'九峰乡',
#      u'九间房',
#      u'九间房镇',
#      u'九龙路',
#      u'习武园',
#      u'书山道',
#      u'书海楼',
#      u'书记办公室',
#      u'书院门 步行街',
#      u'书香路',
#      u'乾县',
#      u'乾县 (Qian)',
#      u'乾县服务区',
#      u'乾县站',
#      u'乾陵',
#      u'二十所社区南福利区',
#      u'二号楼',
#      u'二号路',
#      u'二府庄路',
#      u'二府街',
#      u'二曲镇',
#      u'二期小径',
#      u'二环东路',
#      u'二环北路',
#      u'二环北路东段',
#      u'二环北路西段',
#      u'二环南路',
#      u'二环南路东段',
#      u'二环南路西段',
#      u'二环路',
#      u'二环路延伸道',
#      u'二马路',
#      u'二龙山水库',
#      u'云天苑A座',
#      u'云天苑B座',
#      u'云天苑C座',
#      u'云天苑C座电信4G基站',
#      u'云天苑D座',
#      u'云天苑D座移动234G基站',
#      u'云天苑E座',
#      u'云天苑E座联通3G基站',
#      u'云天苑F座',
#      u'云天苑操场',
#      u'云天苑餐厅',
#      u'云天苑餐厅移动23G基站',
#      u'云阳镇',
#      u'互助立交',
#      u'五一巷',
#      u'五台街办',
#      u'五号楼',
#      u'五号路',
#      u'五味十字',
#      u'五四巷',
#      u'五岳庙门',
#      u'五府井',
#      u'五星街',
#      u'五星街办',
#      u'五路口',
#      u'五路口站',
#      u'五道十字东街',
#      u'五道十字南街',
#      u'五道十字西街',
#      u'亘垣堡',
#      u'亚美大厦',
#      u'亞洲公路34號線',
#      u'亞洲公路5號線',
#      u'交口镇',
#      u'交大一村',
#      u'交大二、三村',
#      u'交大二附院',
#      u'交大公安处',
#      u'交大出版大厦',
#      u'交大南门',
#      u'交大机械厂',
#      u'交大校医院',
#      u'交大电脑城',
#      u'交大街',
#      u'交大邮局',
#      u'交大附中',
#      u'交斜镇',
#      u'交通银行',
#      u'交通银行ATM',
#      u'交通馆',
#      u'产业园公交枢纽站',
#      u'产业路',
#      u'京昆高速',
#      u'亮宝楼',
#      u'人人乐',
#      u'人人乐超市',
#      u'人人家超市',
#      u'人民东路',
#      u'人民中路',
#      u'人民剧院',
#      u'人民北路',
#      u'人民南巷',
#      u'人民南路',
#      u'人民广场街',
#      u'人民西巷',
#      u'人民西路',
#      u'人民路',
#      u'人民路广场',
#      u'人民银行大街',
#      u'什王村',
#      u'仁义东巷',
#      u'仁义路',
#      u'仁厚庄北路',
#      u'仁厚庄南路',
#      u'仁宗庙',
#      u'仁村',
#      u'介家巷',
#      u'从新巷',
#      u'仓程路',
#      u'仓门巷',
#      u'付村花园东区',
#      u'代家镇',
#      u'代王街办',
#      u'仪井镇',
#      u'仪凤东街',
#      u'仪凤南街',
#      u'仪风北街',
#      u'仪风西街',
#      u'仲英书院 东1舍',
#      u'仲英书院 东21舍',
#      u'仲英书院 东2舍',
#      u'仲英书院 东3舍',
#      u'任留街道',
#      u'企业路',
#      u'伊古斋黄桂柿子饼',
#      u'优佳超市',
#      u'会展东路',
#      u'会展中心',
#      u'会展路',
#      u'会昌路',
#      u'会议中心',
#      u'伞塔路',
#      u'伟丰花园',
#      u'低温实验室',
#      u'住房',
#      u'体乐南巷',
#      u'体育场',
#      u'体育场北路',
#      u'体育教室',
#      u'体育训练中心',
#      u'体育路',
#      u'体育部',
#      u'体育馆',
#      u'体育馆东路',
#      u'何家塬',
#      u'何寨站',
#      u'何寨镇',
#      u'余下小区',
#      u'余下村',
#      u'余下站',
#      u'余下镇',
#      u'余下饮食街',
#      u'余姚村',
#      u'供热交换站',
#      u'侯家',
#      u'侯家村镇',
#      u'侯家湾菜市场',
#      u'便利店',
#      u'便民巷',
#      u'保东村',
#      u'保兴村',
#      u'保安处',
#      u'保安镇',
#      u'保研路',
#      u'保税区站',
#      u'保西村',
#      u'信合巷',
#      u'信息与网络中心',
#      u'信息大道',
#      u'信息工程学院',
#      u'信远楼',
#      u'修远1号教学楼',
#      u'修远2号教学楼',
#      u'修远3号教学楼',
#      u'修远4号教学楼',
#      u'修远大道',
#      u'修远湖',
#      u'候家湾村：324',
#      u'倚中路',
#      u'倚天路',
#      u'值班室',
#      u'停车场',
#      u'健康北路',
#      u'健康西路',
#      u'健康路',
#      u'健身器材',
#      u'元一村',
#      u'元三村',
#      u'元二村',
#      u'元北村',
#      u'元南村',
#      u'元和路',
#      u'元朔路',
#      u'元村',
#      u'元村十二户',
#      u'元架村',
#      u'元王村',
#      u'元西村',
#      u'兆丰东路',
#      u'兆丰西路',
#      u'兆寨村',
#      u'先锋巷',
#      u'光华路',
#      u'光和路',
#      u'光夏路',
#      u'光大南路',
#      u'光大路',
#      u'光德路',
#      u'光明巷',
#      u'光明西路',
#      u'光明路',
#      u'光智路',
#      u'光泰路',
#      u'光辉小巷三巷',
#      u'光辉巷',
#      u'光远路',
#      u'光顺门大街',
#      u'八云塔',
#      u'八佳路',
#      u'八号楼',
#      u'八号路',
#      u'八家巷',
#      u'八府庄北路',
#      u'八组正街',
#      u'八里店站',
#      u'八院',
#      u'公园北路',
#      u'公园南街',
#      u'公园南路',
#      u'公园南路环道',
#      u'公园街',
#      u'公墓',
#      u'公字楼',
#      u'公安处',
#      u'公安长安分局',
#      u'公寓',
#      u'公寓1楼',
#      u'公寓2楼',
#      u'公寓3楼',
#      u'公寓4楼',
#      u'公社巷',
#      u'六号楼',
#      u'六号路',
#      u'六合窑',
#      u'六村堡',
#      u'六村堡街办',
#      u'六艺楼',
#      u'六谷庄',
#      u'兰博基尼',
#      u'兰园1号楼',
#      u'兰园2号楼',
#      u'兰园3号楼',
#      u'兰池大道',
#      u'共建路',
#      u'共青团路',
#      u'关中民俗博物院',
#      u'关中环线',
#      u'关山站',
#      u'关山镇',
#      u'关石',
#      u'兴业二路',
#      u'兴业路',
#      u'兴中东路',
#      u'兴中路',
#      u'兴化东巷',
#      u'兴化巷',
#      u'兴化路',
#      u'兴华路',
#      u'兴善寺东街',
#      u'兴善寺南街',
#      u'兴善寺西街',
#      u'兴园路',
#      u'兴国初中',
#      u'兴国国际小学',
#      u'兴学巷',
#      u'兴学路',
#      u'兴寺巷',
#      u'兴工东路',
#      u'兴平',
#      u'兴平市',
#      u'兴平市 (Xingping)',
#      u'兴平火车站',
#      u'兴庆公园',
#      u'兴庆宫公园',
#      u'兴庆宫公园南门',
#      u'兴庆桥',
#      u'兴庆路',
#      u'兴教巷',
#      u'兴教路',
#      u'兴正元广场',
#      u'兴隆',
#      u'兴隆园一区',
#      u'兴隆街办',
#      u'兴隆路',
#      u'兵马俑',
#      u'兵马俑 terracotta army',
#      u'兵马俑一号坑',
#      u'兵马俑二号坑',
#      u'养老宫村',
#      u'内环南路',
#      u'军人服务社',
#      u'军警路',
#      u'农业银行',
#      u'农兴路',
#      u'农林巷',
#      u'农行ATM',
#      u'冯村',
#      u'冰窖巷',
#      u'冶金厂',
#      u'净业寺龙潭',
#      u'凝固实验室',
#      u'凤凰东路',
#      u'凤凰北街',
#      u'凤凰南街',
#      u'凤凰台',
#      u'凤凰台东街',
#      u'凤凰大道',
#      u'凤凰山',
#      u'凤华路',
#      u'凤吉路',
#      u'凤和路',
#      u'凤城一路',
#      u'凤城七路',
#      u'凤城三路',
#      u'凤城九路',
#      u'凤城二路',
#      u'凤城五路',
#      u'凤城八路',
#      u'凤城六路',
#      u'凤城北路',
#      u'凤城十一路',
#      u'凤城十二路',
#      u'凤城十路',
#      u'凤城南路',
#      u'凤城四路',
#      u'凤新路',
#      u'凤林北路',
#      u'凤栖东路',
#      u'凤栖原',
#      u'凤栖原站',
#      u'凤栖山',
#      u'凤栖西路',
#      u'凤栖路',
#      u'凤祥路',
#      u'凤竹一路',
#      u'凤竹三路',
#      u'凤竹五路',
#      u'凤鸣路',
#      u'凯宾斯基酒店',
#      u'凯德广场',
#      u'凯越华庭',
#      u'出口加工B区',
#      u'出口加工b区',
#      u'出口小径',
#      u'出口小径支',
#      u'出版集团',
#      u'出租车站',
#      u'出站口',
#      u'凿齿北村',
#      u'凿齿村',
#      u'刑侦科',
#      u'刘峰腊牛肉夹馍',
#      u'刘志军腊牛羊肉',
#      u'刘纪孝腊牛羊肉店',
#      u'创业大道',
#      u'创业路',
#      u'创意馆',
#      u'创新二路',
#      u'创新路',
#      u'创汇路',
#      u'利民巷',
#      u'利民心超市',
#      u'到六号楼',
#      u'前卫镇',
#      u'前厅',
#      u'前进东路',
#      u'前进西路',
#      u'前进路',
#      u'剑桥公寓',
#      u'剧院巷',
#      u'副书记办公室',
#      u'办公室、组织部、科技创新部',
#      u'办公楼',
#      u'加油站',
#      u'加油站-加气站',
#      u'务庄站',
#      u'励志书院 东6舍',
#      u'励志楼',
#      u'励志路',
#      u'劳动公园',
#      u'劳动北路',
#      u'劳动南路',
#      u'劳动局家属院',
#      u'劳动西路',
#      u'劳动路',
#      u'劳动路站',
#      u'劳武巷',
#      u'勇字楼',
#      u'勤学路',
#      u'勤工路',
#      u'化妆间',
#      u'化学实验室',
#      u'化学楼',
#      u'化工南巷',
#      u'化工楼',
#      u'化育巷',
#      u'化觉巷旅游纪念品街',
#      u'北53楼',
#      u'北一路',
#      u'北三楼',
#      u'北三环',
#      u'北三环辅道',
#      u'北二楼',
#      u'北二街',
#      u'北关',
#      u'北关正街',
#      u'北关路',
#      u'北其轻',
#      u'北坊巷',
#      u'北夏家十字',
#      u'北大街',
#      u'北大街站',
#      u'北客站',
#      u'北小径',
#      u'北屯镇',
#      u'北巷',
#      u'北市村',
#      u'北平街',
#      u'北广场路',
#      u'北广济街',
#      u'北张街',
#      u'北新街',
#      u'北曹家巷',
#      u'北杜镇',
#      u'北板桥村',
#      u'北极路',
#      u'北柳巷',
#      u'北森林',
#      u'北殿北路',
#      u'北殿南路',
#      u'北殿正街',
#      u'北池头一路',
#      u'北池头二路',
#      u'北池头站',
#      u'北沈家桥',
#      u'北沙坡街',
#      u'北洛河',
#      u'北洛河流域',
#      u'北洞巷小区',
#      u'北火巷',
#      u'北环城路',
#      u'北环路',
#      u'北田街道',
#      u'北绣山活动中心',
#      u'北苑站',
#      u'北街',
#      u'北辰立交',
#      u'北辰路',
#      u'北边羽毛球、排球、篮球场',
#      u'北郭门',
#      u'北长巷',
#      u'北门',
#      u'北门广场',
#      u'北门路',
#      u'北陆路',
#      u'北院门',
#      u'北雷加油站',
#      u'北雷村',
#      u'北马道巷',
#      u'十一号楼',
#      u'十三号楼',
#      u'十二号楼',
#      u'十五号楼',
#      u'十八盘 Eighteen Coils',
#      u'十号楼',
#      u'十四井路',
#      u'十四号楼',
#      u'十四街坊',
#      u'十里铺',
#      u'十里铺北路',
#      u'千户村',
#      u'升旗台环岛',
#      u'半坡',
#      u'半坡立交',
#      u'半坡立交道',
#      u'半坡站',
#      u'半坡路',
#      u'半岛北路',
#      u'半岛南一路',
#      u'半引路',
#      u'华东服饰城',
#      u'华东服饰广场',
#      u'华严寺',
#      u'华为公司',
#      u'华兴一路',
#      u'华兴二路',
#      u'华县',
#      u'华县 (Hua)',
#      u'华县站',
#      u'华县西',
#      u'华城万象一期',
#      u'华夏银行',
#      u'华山',
#      u'华山东峰',
#      u'华山北',
#      u'华山北峰',
#      u'华山南峰 Hua Shan South Peak',
#      u'华山国际酒店',
#      u'华山大街',
#      u'华山西',
#      u'华山西峰',
#      u'华山路',
#      u'华州区',
#      u'华泰世纪华城小区',
#      u'华泰工地',
#      u'华润万家',
#      u'华润万家 昆明路店',
#      u'华润万家超市',
#      u'华润二十四城',
#      u'华清东路',
#      u'华清池',
#      u'华清立交',
#      u'华清西路',
#      u'华胥',
#      u'华胥镇',
#      u'华西路',
#      u'华西镇',
#      u'华远西路',
#      u'华阳',
#      u'华阴',
#      u'华阴市',
#      u'华阴市 (Huayin)',
#      u'卓越路',
#      u'南53楼',
#      u'南三环路',
#      u'南三环辅道',
#      u'南二楼',
#      u'南二街',
#      u'南五台',
#      u'南五台服务区',
#      u'南位镇',
#      u'南关正街',
#      u'南关西路',
#      u'南关路',
#      u'南区西路',
#      u'南区路',
#      u'南坊巷',
#      u'南堡南巷',
#      u'南大街',
#      u'南宅巷',
#      u'南安村纵街',
#      u'南小巷',
#      u'南小径',
#      u'南山书院',
#      u'南巷',
#      u'南市站',
#      u'南市镇',
#      u'南广场',
#      u'南广济街',
#      u'南廓门',
#      u'南新街',
#      u'南方修鞋',
#      u'南方路',
#      u'南村1号楼',
#      u'南村2号楼',
#      u'南板桥村',
#      u'南林路',
#      u'南柳巷',
#      u'南森林',
#      u'南横线',
#      u'南殿北路',
#      u'南殿南路',
#      u'南殿西街',
#      u'南油巷',
#      u'南洋书院 东7舍',
#      u'南洋书院 东8舍',
#      u'南洋书院 东9舍',
#      u'南洋大酒店',
#      u'南涝店村',
#      u'南牌楼巷',
#      u'南环东路',
#      u'南环街',
#      u'南环西路',
#      u'南留村',
#      u'南稍门',
#      u'南章曲村',
#      u'南竹里馆路',
#      u'南绿地',
#      u'南羊村',
#      u'南花园',
#      u'南花园径',
#      u'南草坪',
#      u'南街',
#      u'南街小学',
#      u'南西南巷',
#      u'南边篮球场',
#      u'南郭路',
#      u'南长巷',
#      u'南门',
#      u'南阳街',
#      u'南阶',
#      u'南院门',
#      u'南雷村',
#      u'南马道巷',
#      u'博士路',
#      u'博学路',
#      u'博文路 / Bowen Lu',
#      u'博爱路',
#      u'博物馆南街',
#      u'博闻楼',
#      u'卜蜂莲花',
#      u'卡布奇诺公寓',
#      u'卧龙巷',
#      u'卫华巷',
#      u'卫星路',
#      u'印刷学院',
#      u'印花布园小区',
#      u'历史拐点纪念碑',
#      u'厚德路',
#      u'厚镇',
#      u'原华清路',
#      u'县北门巷',
#      u'县门巷',
#      u'县门街东路',
#      u'县门街西路',
#      u'友谊东路',
#      u'友谊北路',
#      u'友谊西路',
#      u'友谊路',
#      u'双仁府',
#      u'双北村',
#      u'双拥路',
#      u'双柏树村',
#      u'双槐村',
#      u'双泉路',
#      u'双照镇',
#      u'双王乡',
#      u'双竹村',
#      u'发展大道',
#      u'发展路',
#      u'口口香腊汁肉店',
#      u'口镇',
#      u'口镇小学',
#      u'古城国际青年旅舍',
#      u'古新巷',
#      u'古渡公园',
#      u'古迹岭',
#      u'古都新世界大酒店',
#      u'召公镇',
#      u'叮当书屋',
#      u'史东村',
#      u'史东村村委会',
#      u'史家堡村',
#      u'史家寨镇',
#      u'史德镇',
#      u'史西村',
#      u'号6',
#      u'司竹镇',
#      u'司马村',
#      u'吉原美郡国际城',
#      u'吉庆巷',
#      u'吉泰路',
#      u'吉祥一巷',
#      u'吉祥三巷',
#      u'吉祥二巷',
#      u'吉祥巷',
#      u'吉祥村站',
#      u'吉祥西街',
#      u'吉祥路',
#      u'同德路',
#      u'同文路',
#      u'同盛祥',
#      u'后勤集团',
#      u'后卫寨站',
#      u'后村西路',
#      u'向上路',
#      u'向荣巷',
#      u'向荣街',
#      u'向阳一区家属区',
#      u'向阳东路',
#      u'向阳中路',
#      u'向阳二区公园',
#      u'向阳二区家属区',
#      u'向阳北路',
#      u'向阳南路',
#      u'向阳四区家属区',
#      u'向阳四区绿化带',
#      u'向阳街',
#      u'向阳路',
#      u'吕公东路',
#      u'吕公寨村',
#      u'吕家堡村',
#      u'吖咪营养餐',
#      u'含元路',
#      u'含光路',
#      u'含章路',
#      u'含英路',
#      u'启光大厦',
#      u'启夏苑',
#      u'启德书院',
#      u'启德广场',
#      u'启真湖',
#      u'吴家坟',
#      u'吴赵村',
#      u'员曲乡',
#      u'周原岐山面',
#      u'周园1号楼',
#      u'周园2号楼',
#      u'周园3号楼',
#      u'周城镇',
#      u'周宋小学ZhouSong Primary School',
#      u'周宋幼儿园ZhouSong kindergarten',
#      u'周家庄北村',
#      u'周家庄村',
#      u'周至县',
#      u'周至县 (Zhouzhi)',
#      u'周至水街',
#      u'周陵街办',
#      u'周鱼路ZhouYu Lu',
#      u'和平工业园区二号路',
#      u'和平电影院',
#      u'和平路',
#      u'和平门',
#      u'和平门-文昌门隧道',
#      u'咸余路',
#      u'咸宁东路',
#      u'咸宁桥',
#      u'咸宁西路',
#      u'咸宋路',
#      u'咸平路',
#      u'咸户路',
#      u'咸河',
#      u'咸通北路',
#      u'咸通南路',
#      u'咸通路',
#      u'咸铜铁路',
#      u'咸阳',
#      u'咸阳东',
#      u'咸阳中学',
#      u'咸阳北站',
#      u'咸阳南',
#      u'咸阳博物馆',
#      u'咸阳市',
#      u'咸阳市 / Xianyang',
#      u'咸阳湖',
#      u'咸阳秦都',
#      u'咸阳立交匝道',
#      u'咸阳站',
#      u'咸阳西',
#      u'咸阳钟楼',
#      u'哈佛公馆',
#      u'哈哈',
#      u'响桥村',
#      u'哑柏镇',
#      u'唐久便利店',
#      u'唐兴数码',
#      u'唐兴路',
#      u'唐园1号楼',
#      u'唐园2号楼',
#      u'唐园3号楼',
#      u'唐城墙公园',
#      u'唐城墙遗址公园',
#      u'唐大慈恩寺遗址公园',
#      u'唐宫仙指',
#      u'唐延南路',
#      u'唐延路',
#      u'唐苑东路（天街）',
#      u'唐苑北路',
#      u'唯实路',
#      u'商州区 (Shangzhou)',
#      u'商洛北站',
#      u'商洛市 / Shangluo',
#      u'商通路',
#      u'商铺',
#      u'啤酒路',
#      u'喂子坪乡',
#      u'喷泉广场',
#      u'嘉华街',
#      u'嘉天國際',
#      u'四号楼',
#      u'四号路',
#      u'四合院',
#      u'四大发明广场',
#      u'四季东巷',
#      u'四季西巷',
#      u'四屯镇',
#      u'四府街',
#      u'四段巷',
#      u'四浩庄',
#      u'团委',
#      u'团结一路',
#      u'团结三路',
#      u'团结东路',
#      u'团结中路',
#      u'团结二路',
#      u'团结北路',
#      u'团结南路',
#      u'团结四路',
#      u'团结村',
#      u'团结西路',
#      u'团结路',
#      u'园丁面食屋',
#      u'围墙巷',
#      u'围棋寨村',
#      u'国家法官学院陕西司法警察分院',
#      u'国家电网',
#      u'国展中心',
#      u'国维淀粉厂',
#      u'国美电器（三环-电视塔店）',
#      u'国色天香',
#      u'国防教育中心',
#      u'国际港务区站',
#      u'图书馆',
#      u'图书馆/实验室',
#      u'圆测塔',
#      u'圆通',
#      u'圆通快递',
#      u'土木工程大楼',
#      u'土桥乡',
#      u'土门',
#      u'土门坊',
#      u'圣和家园：162',
#      u'地下车库',
#      u'场新街',
#      u'坊上人',
#      u'坡龙头',
#      u'坳一村',
#      u'坳三村',
#      u'坳二村',
#      u'坳河村',
#      u'垃圾台',
#      u'城关镇',
#      u'城南大道',
#      u'城角村',
#      u'城隍庙巷',
#      u'基师塔',
#      u'基建处',
#      u'塔巷',
#      u'墨香斋',
#      u'复聪路',
#      u'夏家十字',
#      u'夏家庄',
#      u'外借部',
#      u'外国语大学南校区',
#      u'外国语学院',
#      u'外教别墅区',
#      u'外环北路',
#      u'外环南路',
#      u'多相流国家重点实验室',
#      u'大丰路',
#      u'大兆乡',
#      u'大兆乡中心小学',
#      u'大兆卫生院',
#      u'大兆村',
#      u'大兴东路',
#      u'大兴善寺',
#      u'大兴国禅寺',
#      u'大兴立交',
#      u'大厅',
#      u'大唐不夜城',
#      u'大唐群英谱',
#      u'大唐芙蓉园',
#      u'大唐芙蓉园西门',
#      u'大唐西市',
#      u'大唐西市博物馆',
#      u'大唐通易坊',
#      u'大墙乡',
#      u'大学东路',
#      u'大学习巷',
#      u'大学南路',
#      u'大学生文体教育中心',
#      u'大学生活动中心',
#      u'大学生超市',
#      u'大学路',
#      u'大寨乡',
#      u'大寨小学',
#      u'大寨路',
#      u'大居安',
#      u'大居安村',
#      u'大峪',
#      u'大峪水库',
#      u'大差市',
#      u'大庆路',
#      u'大庞路',
#      u'大慈恩寺',
#      u'大新巷',
#      u'大明宫',
#      u'大明宫国家遗址公园',
#      u'大明宫桥',
#      u'大明宫西',
#      u'大明宫雁塔购物广场',
#      u'大明镇',
#      u'大有巷',
#      u'大杨乡',
#      u'大林超市',
#      u'大楼',
#      u'大王镇',
#      u'大白杨东路',
#      u'大白杨南路',
#      u'大皮院',
#      u'大真情寺',
#      u'大礼堂',
#      u'大秦塔',
#      u'大程乡',
#      u'大程站',
#      u'大程镇',
#      u'大良路',
#      u'大荆镇',
#      u'大荔县 (Dali)',
#      u'大莲花池街',
#      u'大西客专',
#      u'大雁塔',
#      u'大雁塔南广场',
#      u'大雁塔喷泉广场',
#      u'大雁塔小学',
#      u'大雁塔文化休闲景区',
#      u'大雁塔站',
#      u'大风阁',
#      u'大鲍陂',
#      u'大麦市街',
#      u'天下第一面 @ 吉祥村店',
#      u'天人路',
#      u'天台一路',
#      u'天台三路',
#      u'天台九路',
#      u'天台二路',
#      u'天台五路',
#      u'天台八路',
#      u'天台八路 付一路',
#      u'天台六路',
#      u'天台四路',
#      u'天台路',
#      u'天地源·兰亭坊 / Tiandi Yuan Lanting Fang',
#      u'天坛西路',
#      u'天坛路',
#      u'天天美食城',
#      u'天文台',
#      u'天朗•蓝湖树',
#      u'天池 Sky Pool',
#      u'天谷八路',
#      u'天问路',
#      u'太乙宫',
#      u'太乙宫街办',
#      u'太乙峪',
#      u'太乙立交',
#      u'太乙路',
#      u'太元路',
#      u'太华北路',
#      u'太华路',
#      u'太华路立交',
#      u'太和路',
#      u'太安街',
#      u'太平峪',
#      u'太平庄村',
#      u'太平村',
#      u'太平镇',
#      u'太液池',
#      u'太白北路',
#      u'太白南路 / Taibai Nan Lu',
#      u'太白南路建材市场',
#      u'太白南路站',
#      u'太白环岛',
#      u'太白立交',
#      u'太阳庙门',
#      u'太阳新城',
#      u'太阳新街',
#      u'太阳水岸新城',
#      u'太阳水岸新城：162',
#      u'太阳雨洗浴中心',
#      u'夫水',
#      u'奋勇巷',
#      u'奥林匹克公园',
#      u'奥林匹克花园3期',
#      u'奥林匹克花园4期',
#      u'奥林匹克花园5-6期',
#      u'奥林匹克花园一二期',
#      u'奥林匹克花园幼儿园',
#      u'奥林匹克花园运动会所',
#      u'奥林匹克花园销售中心',
#      u'女澡堂',
#      u'女生宿舍',
#      u'姚坊乡',
#      u'姚家',
#      u'姜寨北路',
#      u'姜寨南路',
#      u'姜溪花都社区：162',
#      u'姜白路',
#      u'姬家乡',
#      u'威斯汀',
#      u'娄敬路',
#      u'子午大道',
#      u'子午峪',
#      u'子午街办',
#      u'子午西街',
#      u'孙家老铺肉夹馍',
#      u'孙家肉丸胡辣汤',
#      u'孙武路',
#      u'孟塬镇',
#      u'孟家巷',
#      u'孟村镇',
#      u'孟杨路',
#      u'学10楼',
#      u'学11楼',
#      u'学12楼',
#      u'学13楼',
#      u'学14楼',
#      u'学1楼',
#      u'学20楼',
#      u'学21楼',
#      u'学2楼',
#      u'学3楼',
#      u'学4楼',
#      u'学5楼',
#      u'学7咯 学6楼',
#      u'学8楼',
#      u'学9楼',
#      u'学士路',
#      u'学子食府',
#      u'学府城南区',
#      u'学府大街',
#      u'学府大道',
#      u'学府快餐',
#      u'学术活动中心',
#      u'学校食堂',
#      u'学森路',
#      u'学汇路',
#      u'学海道',
#      u'学生15楼',
#      u'学生公寓',
#      u'学生公寓(女)',
#      u'学生公寓(男)',
#      u'学生公寓3号楼',
#      u'学生宿舍',
#      u'学生活动中心（已关闭）',
#      u'学舟楼',
#      u'学苑东路',
#      u'学苑中路',
#      u'学苑北路',
#      u'学苑南路',
#      u'学苑西路',
#      u'学院路',
#      u'宁西线',
#      u'宁西铁路',
#      u'宁西铁路二线',
#      u'安东街',
#      u'安乐镇',
#      u'安仁街',
#      u'安全巷',
#      u'安华南路',
#      u'安华西路',
#      u'安古路',
#      u'安吉巷 / Anji Xiang',
#      u'安善坊村',
#      u'安国寺',
#      u'安图书大厦',
#      u'安定路',
#      u'安村至西安段',
#      u'安村镇',
#      u'安虹路',
#      u'安西街',
#      u'安远门桥',
#      u'安远门站',
#      u'安邸立交',
#      u'宋东村',
#      u'宋家堡村',
#      u'宋家巷',
#      u'宋村',
#      u'宋滩村',
#      u'宋西村',
#      u'宏府麒麟山',
#      u'宏道路',
#      u'官刘路',
#      u'官厅立交',
#      u'官池镇',
#      u'定一村',
#      u'定三村',
#      u'定二村',
#      u'定五村',
#      u'定六村',
#      u'定四村',
#      u'定家小酥肉',
#      u'定居路',
#      u'定舟村',
#      u'定舟村北堡',
#      u'定舟村南堡',
#      u'定舟纸箱产业园',
#      u'宜品生活',
#      u'宜家家居',
#      u'宝宇大连海鲜鱼港',
#      u'宝来惠超市',
#      u'宝泉路',
#      u'宝苑路',
#      u'宝鸡市 / Baoji',
#      u'实验大楼',
#      u'实验楼',
#      u'宴友思大街',
#      u'家3楼',
#      u'家5楼',
#      u'家6楼',
#      u'家世界',
#      u'家佛堂村',
#      u'家园东路',
#      u'家园西路',
#      u'家属10号楼',
#      u'家属11号楼',
#      u'家属12号楼',
#      u'家属13号楼',
#      u'家属14号楼',
#      u'家属15号楼',
#      u'家属16号楼',
#      u'家属17号楼',
#      u'家属1号楼',
#      u'家属2号楼',
#      u'家属3号楼',
#      u'家属4号楼',
#      u'家属5号楼',
#      u'家属6号楼',
#      u'家属7号楼',
#      u'家属8号楼',
#      u'家属9号楼',
#      u'家属区',
#      u'家属楼',
#      u'家属楼（在建）',
#      u'宿舍',
#      u'宿舍;派乐汉堡',
#      u'宿舍楼',
#      u'密啶径',
#      u'富仁乡',
#      u'富力城',
#      u'富定街',
#      u'富平县 (Fuping)',
#      u'富村',
#      u'富源二路',
#      u'富裕路',
#      u'富豪大厦',
#      u'寒窑商街',
#      u'寒窑路',
#      u'寨子村',
#      u'寨尚村',
#      u'小丰村',
#      u'小兆村',
#      u'小公园',
#      u'小六汤包',
#      u'小吃城',
#      u'小商店',
#      u'小寨',
#      u'小寨东路',
#      u'小寨站',
#      u'小寨西路',
#      u'小寨路',
#      u'小居安',
#      u'小居安村',
#      u'小山包',
#      u'小峪',
#      u'小峪水库',
#      u'小康桥餐厅',
#      u'小河水库',
#      u'小王店',
#      u'小王店村',
#      u'小皮院',
#      u'小花园',
#      u'小路',
#      u'小雁塔',
#      u'小雁塔公园',
#      u'小雁塔寺路',
#      u'小鲍陂',
#      u'少陵桥',
#      u'尚俭路',
#      u'尚勤路',
#      u'尚宏路',
#      u'尚客优酒店',
#      u'尚平路',
#      u'尚德路',
#      u'尚新路',
#      u'尚朴路',
#      u'尚村镇',
#      u'尚爱路',
#      u'尚礼路',
#      u'尚稷路',
#      u'尚苑路',
#      u'尹村',
#      u'局连村',
#      u'居安路',
#      u'屈家路',
#      u'展区',
#      u'展宏路',
#      u'山南路',
#      u'山水秦唐小区',
#      u'岐山特色小吃',
#      u'岔道口村',
#      u'崇业路',
#      u'崇凝镇',
#      u'崇威桥',
#      u'崇实书院 西16舍',
#      u'崇实书院 西17舍',
#      u'崇文镇',
#      u'崇皇乡',
#      u'崇鋈楼',
#      u'崔家营',
#      u'崔村',
#      u'嵩山路',
#      u'巡航北路',
#      u'工交巷',
#      u'工农路',
#      u'工农路立交',
#      u'工商银行',
#      u'工科大楼',
#      u'工科实验楼',
#      u'工程坊',
#      u'工程实践训练中心',
#      u'工程训练中心',
#      u'巩头',
#      u'市图书馆',
#      u'市图书馆站',
#      u'市建四公司',
#      u'师大商业街',
#      u'师大奥林匹克学校',
#      u'师大职院',
#      u'师大路',
#      u'师苑超市',
#      u'希望路',
#      u'帕提欧小区',
#      u'席王',
#      u'席王路',
#      u'常宁大街',
#      u'常青二路',
#      u'常青路',
#      u'幕布',
#      u'干训中心',
#      u'平东村',
#      u'平娃烤肉',
#      u'平安路',
#      u'平安里',
#      u'平西村',
#      u'平陵乡',
#      u'幸市镇',
#      u'幸福中路',
#      u'幸福北路',
#      u'幸福南路',
#      u'幸福路',
#      u'幼儿园',
#      u'广仁寺',
#      u'广仁寺路',
#      u'广场环道',
#      u'广大门村什字街',
#      u'广大门村后街',
#      u'广安路',
#      u'广新园民族村',
#      u'广泰门站',
#      u'广济街',
#      u'广济镇',
#      u'广运东路',
#      u'广运桥',
#      u'广运潭大道',
#      u'庄头村',
#      u'庄头镇',
#      u'庆丰小区',
#      u'庆镇村',
#      u'库峪',
#      u'底张街办',
#      u'店头镇',
#      u'店子村',
#      u'店张镇',
#      u'庙前街',
#      u'庙后街',
#      u'庙坡头路 Miào pōtóu lù',
#      u'庙子巷',
#      u'庙王路',
#      u'府东一路',
#      u'府东二路',
#      u'府东巷',
#      u'府兴巷',
#      u'府羊街',
#      u'府胜巷',
#      u'庞光镇',
#      u'庞留井村',
#      u'庞留小学',
#      u'庞留村',
#      u'废弃的收费站',
#      u'康东村',
#      u'康中村',
#      u'康乐巷',
#      u'康乐路',
#      u'康北村',
#      u'康复北路',
#      u'康复南路',
#      u'康复巷',
#      u'康复西路',
#      u'康复路',
#      u'康复路站',
#      u'康宁路',
#      u'康定路',
#      u'康家湾',
#      u'康师傅私房牛肉面',
#      u'康杜村',
#      u'康桥苑餐厅',
#      u'康桥镇',
#      u'康王村',
#      u'康西村',
#      u'康龙高尔夫俱乐部',
#      u'延兴门站',
#      u'延凤路',
#      u'延大路',
#      u'延安大学西安创新学院',
#      u'延安街',
#      u'延平门站',
#      u'延长石油',
#      u'建业三路',
#      u'建业二路',
#      u'建东街',
#      u'建中巷',
#      u'建华路',
#      u'建国一巷',
#      u'建国三巷',
#      u'建国二巷',
#      u'建国五巷',
#      u'建国六巷',
#      u'建国四巷',
#      u'建国巷',
#      u'建国路',
#      u'建工路',
#      u'建强路',
#      u'建福门街',
#      u'建章桥',
#      u'建章路',
#      u'建行ATM',
#      u'建西街',
#      u'建设巷',
#      u'建设路',
#      u'建设银行',
#      u'建设银行丈八六路支行',
#      u'开元商城',
#      u'开元商城钟楼店',
#      u'开元广场',
#      u'开元路',
#      u'开水房',
#      u'开米广场',
#      u'开远门桥',
#      u'开远门站',
#      u'开通巷',
#      u'引水灌溉渠',
#      u'引镇街办',
#      u'弘知路',
#      u'张兴家',
#      u'张卜镇',
#      u'张家坡村',
#      u'张家坪乡',
#      u'张家堡',
#      u'张家村',
#      u'张家滩村',
#      u'张庄路',
#      u'张康村',
#      u'彩虹一路',
#      u'彩虹北二路',
#      u'彩虹北路',
#      u'彩虹南二路',
#      u'彭康书院 东17舍',
#      u'彭康书院 东18 19 20舍',
#      u'彭康路',
#      u'徐家庄',
#      u'徐家湾',
#      u'徐杨街道',
#      u'德克士',
#      u'德发长饺子',
#      u'德发长饺子馆',
#      u'德邦奥迪维修保养',
#      u'志诚丽柏酒店',
#      u'思源北路',
#      u'思源南路',
#      u'思源学院',
#      u'思源楼',
#      u'思源活动中心',
#      u'思源路',
#      u'思源阁',
#      u'怡丰城',
#      u'怡园路',
#      u'怡康药店',
#      u'怡心居二期',
#      u'恒丰银行',
#      u'恒大城',
#      u'悦园路',
#      u'悬铃路',
#      u'情侣湖',
#      u'惠刘站',
#      u'惠北社区',
#      u'惠南社区',
#      u'惠安厂',
#      u'惠宾商务酒店',
#      u'惠民巷',
#      u'惠民路',
#      u'惠风路',
#      u'愿景园小区',
#      u'慈善街',
#      u'慈恩东路',
#      u'慈恩路',
#      u'慈恩镇',
#      u'成才南街',
#      u'成才大道',
#      u'成道宫村',
#      u'户县',
#      u'户县 (Hu)',
#      u'户县东关小学',
#      u'户县中医医院',
#      u'户县中心苗圃',
#      u'户县二中',
#      u'户县人民体育场',
#      u'户县人民医院',
#      u'户县人民路小学',
#      u'户县元村小学',
#      u'户县兴伦购物中心',
#      u'户县北关中学',
#      u'户县北街小学',
#      u'户县南关中学',
#      u'户县南关小学',
#      u'户县县政府',
#      u'户县史家庄小学',
#      u'户县善慧小学',
#      u'户县文庙',
#      u'户县汽车北站',
#      u'户县汽车南站',
#      u'户县汽车站',
#      u'户县电厂',
#      u'户县电厂中学',
#      u'户县电厂小学',
#      u'户县站',
#      u'户县第一中学',
#      u'户县第二中学',
#      u'户县第六中学',
#      u'户县第四中学',
#      u'户县西街小学',
#      u'户电路',
#      u'户菜路',
#      u'房陆佰',
#      u'扶苏路',
#      u'扶风县 (Fufeng)',
#      u'抗战北路',
#      u'抗战路',
#      u'护国兴教寺',
#      u'护城河',
#      u'报告厅',
#      u'报恩寺街',
#      u'抱龙峪',
#      u'拉萨路',
#      u'招商银行',
#      u'招行ATM',
#      u'挚信樱花园',
#      u'振兴南街',
#      u'振兴路',
#      u'振华北路',
#      u'振华南路',
#      u'振华路',
#      u'排球场',
#      u'排球羽毛球乒乓球场',
#      u'接待室',
#      u'控制室',
#      u'搪瓷北巷',
#      u'搪瓷南巷',
#      u'操场',
#      u'操场东巷',
#      u'收发室',
#      u'政府街',
#      u'政法巷',
#      u'政通大道',
#      u'故市镇',
#      u'敏行路',
#      u'教一楼',
#      u'教二100',
#      u'教二楼',
#      u'教公寓3楼',
#      u'教公寓4楼',
#      u'教公寓5楼',
#      u'教单1楼',
#      u'教单2楼',
#      u'教单3楼',
#      u'教单4楼',
#      u'教单5楼',
#      u'教场门',
#      u'教堂',
#      u'教学一楼',
#      u'教学七楼',
#      u'教学三楼',
#      u'教学九楼',
#      u'教学二楼',
#      u'教学五楼',
#      u'教学八楼',
#      u'教学六楼',
#      u'教学区东门',
#      u'教学区北一门',
#      u'教学区北二门',
#      u'教学南路',
#      u'教学四楼',
#      u'教学楼',
#      u'教学西楼A座',
#      u'教学西楼B座',
#      u'教学西楼C座',
#      u'教学西楼D座',
#      u'教工楼1#',
#      u'教工浴室',
#      u'教工食堂',
#      u'教师公寓',
#      u'教育博物馆',
#      u'教育基金会办公室',
#      u'教育巷',
#      u'敦义路',
#      u'敦行路',
#      u'敬业路',
#      u'敬贤大街',
#      u'数字化大楼',
#      u'敷水镇',
#      u'文体楼',
#      u'文体路',
#      u'文兴路',
#      u'文化东路',
#      u'文化大街',
#      u'文化大街北段',
#      u'文化大街南段',
#      u'文化宫广场',
#      u'文化巷',
#      u'文化广场',
#      u'文化街',
#      u'文化西路',
#      u'文化路',
#      u'文娱巷',
#      u'文峰大街',
#      u'文昌门',
#      u'文景公园',
#      u'文景立交',
#      u'文景路',
#      u'文曲路',
#      u'文林路',
#      u'文汇东路',
#      u'文汇楼',
#      u'文汇西路',
#      u'文治书院 西18 19 20舍',
#      u'文治路',
#      u'文津楼',
#      u'文渊楼',
#      u'文澜楼',
#      u'文科科研楼',
#      u'文艺南路',
#      u'文艺西路',
#      u'文艺路',
#      u'文艺路南口',
#      u'文艺路天桥',
#      u'文苑北路',
#      u'文苑南路',
#      u'文苑路',
#      u'斗门',
#      u'斗门街办',
#      u'斜口街办',
#      u'新世纪超市',
#      u'新丰',
#      u'新丰镇',
#      u'新丰镇机务段',
#      u'新丰镇站',
#      u'新兴北路',
#      u'新兴南路',
#      u'新兴街道',
#      u'新兴路',
#      u'新勇学生活动中心',
#      u'新区博闻楼图书馆',
#      u'新区笃学楼',
#      u'新医路',
#      u'新华书店',
#      u'新华书店西安图书大厦',
#      u'新华巷',
#      u'新华街',
#      u'新华路',
#      u'新合乡',
#      u'新园路',
#      u'新城区',
#      u'新城区 (Xincheng)',
#      u'新城坊',
#      u'新城餐厅',
#      u'新安村',
#      u'新寺路',
#      u'新市街道',
#      u'新广路',
#      u'新庄村',
#      u'新庆巷',
#      u'新建二巷',
#      u'新建巷',
#      u'新建西路',
#      u'新开门东路环岛',
#      u'新开门南路 New Open Door South Rd',
#      u'新时乡',
#      u'新村',
#      u'新桥路',
#      u'新浐桥',
#      u'新盛路',
#      u'新科技楼',
#      u'新科路',
#      u'新筑',
#      u'新筑镇',
#      u'新纪元公园 / Xinji Yuan Huayuan',
#      u'新综合楼',
#      u'新西北',
#      u'新西户路',
#      u'新西门',
#      u'新贡里',
#      u'新辣道鱼火锅',
#      u'新郭门',
#      u'新阳乡',
#      u'方新路',
#      u'旅环院气象园',
#      u'无极公园',
#      u'日喀则路',
#      u'早慈巷',
#      u'旭景碧泽园',
#      u'旭邦大厦',
#      u'时代广场',
#      u'昆仑路',
#      u'昆明池路',
#      u'昆明湖',
#      u'昆明湖路',
#      u'昆明花园',
#      u'昆明路',
#      u'昆明路一号桥',
#      u'昆明路三号桥',
#      u'昆明路二号桥',
#      u'昆明路五号桥',
#      u'昆明路四号桥',
#      u'昆明路建材市场',
#      u'昆明路水渠',
#      u'昆明路西段',
#      u'昌仁里',
#      u'昌明路',
#      u'昌都路',
#      u'昌龄路',
#      u'明 秦惠王墓',
#      u'明光路',
#      u'明德一路',
#      u'明德东路',
#      u'明德华园大厦',
#      u'明德小学',
#      u'明德小巷',
#      u'明德广厦',
#      u'明德景园大厦',
#      u'明德西路',
#      u'明德路',
#      u'明德门',
#      u'明德门北社区',
#      u'明德门南东区',
#      u'明德门遗址公园',
#      u'明新巷',
#      u'明日佳居',
#      u'明珠巷',
#      u'明理路',
#      u'明秦王府城墙遗址',
#      u'明远1号教学楼',
#      u'明远2号教学楼',
#      u'明远3号教学楼',
#      u'明远4号教学楼',
#      u'明远楼',
#      u'明远湖',
#      u'明远路',
#      u'易俗街',
#      u'星光路',
#      u'星天苑A座',
#      u'星天苑B座',
#      u'星天苑C座',
#      u'星天苑D座',
#      u'星天苑E座',
#      u'星天苑F座',
#      u'星天苑G座',
#      u'星天苑H座',
#      u'星天苑北餐厅',
#      u'星天苑南餐厅',
#      u'星天苑排球场',
#      u'星天苑操场',
#      u'星天苑篮球场',
#      u'星天苑综合服务大楼',
#      u'星天苑网球场',
#      u'星天苑羽毛球场',
#      u'星天苑足球场',
#      u'星巴克咖啡',
#      u'星火东巷',
#      u'星火路',
#      u'星火路立交',
#      u'春明门站',
#      u'春风街',
#      u'昭陵镇',
#      u'晁留',
#      u'晏平寨村',
#      u'晨光',
#      u'晨光烧饼',
#      u'普化镇',
#      u'普集街镇',
#      u'景家巷',
#      u'景行楼',
#      u'景观路',
#      u'景龙池',
#      u'晶海大酒店',
#      u'智者书城',
#      u'暖气中心',
#      u'曲江',
#      u'曲江乐园',
#      u'曲江六号',
#      u'曲江六号Ⅲ',
#      u'曲江国际会展中心-A区',
#      u'曲江国际会议中心',
#      u'曲江大道',
#      u'曲江寒窑',
#      u'曲江桥',
#      u'曲江水厂',
#      u'曲江池 Qū jiāng chí',
#      u'曲江池东路 Qū jiāng chí East Rd',
#      u'曲江池北路',
#      u'曲江池北路Qū jiāng chí North Rd',
#      u'曲江池南路',
#      u'曲江池西路 Qū jiāng chí West Rd',
#      u'曲江流饮',
#      u'曲江海洋馆',
#      u'曲江立交',
#      u'曲江紫汀苑',
#      u'曲江街办',
#      u'曲黄路',
#      u'更新街',
#      u'月登阁村',
#      u'望仙三路',
#      u'望仙四路',
#      u'望仙坪寺',
#      u'望仙门街',
#      u'望贤路',
#      u'朝晖路',
#      u'朝阳一路',
#      u'朝阳七路',
#      u'朝阳三路',
#      u'朝阳二路',
#      u'朝阳五路',
#      u'朝阳公园',
#      u'朝阳六路',
#      u'朝阳四路',
#      u'朝阳大街',
#      u'朝阳巷',
#      u'朝阳路',
#      u'朝阳门站',
#      u'木塔寨',
#      u'木塔寺公园',
#      u'木塔寺桥',
#      u'未央',
#      u'未央区',
#      u'未央区 (Weiyang)',
#      u'未央宫',
#      u'未央湖',
#      u'未央湖游乐园',
#      u'未央立交',
#      u'未央路',
#      u'未央（北）',
#      u'未知',
#      u'朱坡村',
#      u'朱宏路',
#      u'朱王村',
#      u'朱行路',
#      u'朱雀东坊',
#      u'朱雀城市广场',
#      u'朱雀大街',
#      u'朱雀大街（南段）',
#      u'朱雀桥',
#      u'朱雀门-含光门隧道',
#      u'机场',
#      u'机场专用高速',
#      u'机场西',
#      u'机电学院',
#      u'机电实验教学中心',
#      u'李家村',
#      u'李家村万达广场',
#      u'李家村路',
#      u'李家楼路',
#      u'李斯路',
#      u'杏园立交',
#      u'杏林巷',
#      u'杏林镇',
#      u'杏渭路',
#      u'材料学院 强度楼',
#      u'杜化路',
#      u'杜家巷',
#      u'杜曲街办',
#      u'杜陵邑南路',
#      u'杜雁路',
#      u'杨凌',
#      u'杨凌大道',
#      u'杨凌西',
#      u'杨孔寺三组四组八组',
#      u'杨孔寺水库',
#      u'杨孔寺水库大坝',
#      u'杨家村路',
#      u'杨家滩村',
#      u'杨庄乡',
#      u'杨陵区',
#      u'杨陵区 (Yangling)',
#      u'杨陵南站',
#      u'杨陵水上运动中心',
#      u'杨陵镇站',
#      u'板桥',
#      u'林学院东院',
#      u'林苑宾馆',
#      u'林荫小道',
#      u'枣园',
#      u'枣园东路',
#      u'枣园南路',
#      u'枣园巷',
#      u'枣园站',
#      u'枣园西路',
#      u'枫丹白露苑',
#      u'枫叶北路 / Fengye Bei Lu',
#      u'枫叶南路 / Fengye Nan Lu',
#      u'枫叶新新花园 / Fengye Xinxin Huayuan',
#      u'枫叶新都市',
#      u'枫叶苑',
#      u'枫林华府',
#      u'枫林华府 东门',
#      u'枫林华府 服务中心',
#      u'枫林路 / Fenglin Road',
#      u'柏树林',
#      u'某小区工地',
#      u'柞水县 (Zhashui)',
#      u'柳亭路',
#      u'柳仓街',
#      u'柳新路',
#      u'柳枝镇',
#      u'柳烟路',
#      u'柳荫路',
#      u'柳莺路',
#      u'柳虹路',
#      u'柳雪路',
#      u'柳鸣路',
#      u'柴家十字',
#      u'标准厂房',
#      u'标新街',
#      u'标缝路',
#      u'栎阳街道',
#      u'树园站',
#      u'栖凤街',
#      u'栖斜路',
#      u'校务办公楼',
#      u'校务楼',
#      u'校北街',
#      u'校医院',
#      u'校南街',
#      u'校史馆',
#      u'校广播台',
#      u'校车停靠点',
#      u'校车搭乘处',
#      u'格力电器维修站',
#      u'格物楼',
#      u'桃下镇',
#      u'桃园东路',
#      u'桃园北路',
#      u'桃园南路 / Taoyuan Nan Lu',
#      u'桃园商场',
#      u'桃园桥',
#      u'桃园西路',
#      u'桃园路',
#      u'桃李路',
#      u'桃源路',
#      u'桃花潭站',
#      u'案板街',
#      u'桑镇',
#      u'桥南镇',
#      u'桥南镇站',
#      u'桥尚村',
#      u'桥底',
#      u'桥底镇',
#      u'桥梓口',
#      u'梁家',
#      u'梁家牌楼',
#      u'梁山站',
#      u'梁庄村',
#      u'梁村',
#      u'梁村塬',
#      u'梅园1号楼',
#      u'梅园2号楼',
#      u'梅园3号楼',
#      u'梦飞翔龙酒店',
#      u'梧桐东道',
#      u'梧桐大道',
#      u'梧桐村',
#      u'梧桐西道',
#      u'楼观台道文化景区',
#      u'楼观镇',
#      u'榆商高速',
#      u'榆楚镇',
#      u'槐荫路',
#      u'槐里东路',
#      u'樊家',
#      u'樊家腊汁肉夹馍',
#      u'樊川路',
#      u'樊记腊汁肉',
#      u'樱花一路',
#      u'樱花东道',
#      u'樱花二路',
#      u'樱花广场',
#      u'樱花西道',
#      u'樱花路',
#      u'欧亚大道',
#      u'欧亚学院：162',
#      u'欧凯罗',
#      u'歌德道',
#      u'正学街',
#      u'正气路',
#      u'正阳镇',
#      u'武功',
#      u'武功县',
#      u'武功县 (Wugong)',
#      u'武功服务区',
#      u'武功站',
#      u'武功镇',
#      u'武屯镇',
#      u'武警医院',
#      u'武警学院',
#      u'武警路',
#      u'段家路',
#      u'殷家村',
#      u'毅字楼',
#      u'每一天便利店',
#      u'毓秀园：162',
#      u'比亚迪',
#      u'毕塬东路',
#      u'毕塬西路',
#      u'毕昇路',
#      u'毛家路',
#      u'毛西路',
#      u'民乐园',
#      u'民大路',
#      u'民新路',
#      u'民洁路',
#      u'民生大厦',
#      u'民生西路',
#      u'民生路',
#      u'民生银行',
#      u'气动实验室',
#      u'水厂东路',
#      u'水岸朝阳小区1号楼',
#      u'水房',
#      u'水文巷',
#      u'水果屋',
#      u'水池',
#      u'水流乡',
#      u'水煮白鸽',
#      u'水电费交费中心',
#      u'水香路',
#      u'永乐',
#      u'永乐店',
#      u'永乐路',
#      u'永乐镇',
#      u'永信路',
#      u'永全路',
#      u'永兴坊',
#      u'永兴路',
#      u'永和路',
#      u'永城路',
#      u'永宁路',
#      u'永宁门广场',
#      u'永宁门站',
#      u'永宁门隧道',
#      u'永安滩村',
#      u'永安路',
#      u'永定路',
#      u'永寿东湖',
#      u'永寿县 (Yongshou)',
#      u'永寿站',
#      u'永徽路',
#      u'永新路',
#      u'永明岐山面',
#      u'永松路',
#      u'永祥路',
#      u'永福路',
#      u'永绥街',
#      u'永胜街',
#      u'永胜路',
#      u'永胜路北段',
#      u'永阳公园',
#      u'汇文街',
#      u'汇新路',
#      u'汇新路西段',
#      u'汇豪国际',
#      u'汈台镇',
#      u'汉 许皇后墓',
#      u'汉仓路',
#      u'汉仓路（北段）',
#      u'汉园1号楼',
#      u'汉园2号楼',
#      u'汉园3号楼',
#      u'汉城',
#      u'汉城东路',
#      u'汉城北路',
#      u'汉城服务区',
#      u'汉城湖',
#      u'汉城湖公园',
#      u'汉城街办',
#      u'汉城路',
#      u'汉城路站',
#      u'汉宣帝杜陵（上林苑）',
#      u'汉庭酒店',
#      u'汉武帝茂陵',
#      u'汉江流域',
#      u'汉阳陵',
#      u'汉马路',
#      u'江村西街',
#      u'池阳大街',
#      u'池阳街西段',
#      u'污水处理',
#      u'汤坊镇',
#      u'汤峪水库',
#      u'汤峪河',
#      u'汤峪镇',
#      u'汽车学院',
#      u'沁园路',
#      u'沁水路',
#      u'沃尔玛',
#      u'沃尔玛超市',
#      u'沈乐巷',
#      u'沈兴北路',
#      u'沈兴南路',
#      u'沈家营市场',
#      u'沈家营村',
#      u'沈平路',
#      u'沈祥巷',
#      u'沋河',
#      u'沙井村',
#      u'沙坡',
#      u'沙坡村',
#      u'沙坡环岛',
#      u'沙坡立交',
#      u'沙家水煎包',
#      u'沣东路',
#      u'沣东镇',
#      u'沣惠南路',
#      u'沣惠南路 / Fenghui Nan Lu',
#      u'沣惠路',
#      u'沣河',
#      u'沣河流域',
#      u'沣镐东路',
#      u'沪陕高速',
#      u'河堤路',
#      u'河池寨',
#      u'河滨大道',
#      u'油坊道街',
#      u'油库巷',
#      u'油库街',
#      u'油槐镇',
#      u'泉北一巷',
#      u'泉北三巷',
#      u'泉北二巷',
#      u'泉北四巷',
#      u'泉南一巷',
#      u'泉南二巷',
#      u'泔河',
#      u'泔河水库',
#      u'法院街',
#      u'泥塑艺术中心',
#      u'泰山路',
#      u'泵房',
#      u'泾河',
#      u'泾河流域',
#      u'泾河站',
#      u'泾渭七路',
#      u'泾渭三路',
#      u'泾渭九路',
#      u'泾渭八路',
#      u'泾渭六路',
#      u'泾渭十一路',
#      u'泾渭十路',
#      u'泾渭四路',
#      u'泾渭新城',
#      u'泾渭路',
#      u'泾环南路',
#      u'泾阳',
#      u'泾阳县',
#      u'泾阳县 (Jingyang)',
#      u'洋桥',
#      u'洒金桥',
#      u'洒金桥站',
#      u'洛克大厦',
#      u'洛南县',
#      u'洛南县 (Luonan)',
#      u'洛河',
#      u'洛源镇',
#      u'洛门路',
#      u'洩湖服务区',
#      u'洩湖镇',
#      u'洪庆街办',
#      u'洪庵村',
#      u'洪金鹏食堂',
#      u'测绘东路',
#      u'测绘西路',
#      u'测绘路',
#      u'浐河',
#      u'浐河东路',
#      u'浐河站',
#      u'浐河西路',
#      u'浐灞中心站',
#      u'浐灞大道',
#      u'浐灞湿地公园',
#      u'海底捞',
#      u'海棠学院',
#      u'海棠餐厅',
#      u'海欣一路',
#      u'海欣二路',
#      u'海欣五路',
#      u'消防队',
#      u'涝峪',
#      u'涝峪口',
#      u'涝峪镇',
#      u'涝店初中',
#      u'涝店镇',
#      u'涝河',
#      u'涝河大桥',
#      u'润天大道',
#      u'涧峪站',
#      u'液湖',
#      u'淳化县 (Chunhua)',
#      u'清凉寺：162',
#      u'清凉山公园',
#      u'清河',
#      u'清泰街',
#      u'清莲巷',
#      u'渔场路',
#      u'渠岸镇',
#      u'温国堡',
#      u'温泉浴室',
#      u'渭丰初级中学',
#      u'渭丰镇',
#      u'渭丰镇中心学校',
#      u'渭北村',
#      u'渭南',
#      u'渭南东',
#      u'渭南北',
#      u'渭南南',
#      u'渭南市',
#      u"渭南市 (Yan'an)",
#      u'渭南师范',
#      u'渭南村',
#      u'渭南西',
#      u'渭城区',
#      u'渭城区 (Weicheng)',
#      u'渭城镇',
#      u'渭惠路',
#      u'渭曲坊',
#      u'渭水校区体育场',
#      u'渭河',
#      u'渭河大桥',
#      u'渭河大街',
#      u'渭河水系',
#      u'渭清路',
#      u'渭滨东路',
#      u'渭滨公园',
#      u'渭滨西路',
#      u'渭滨路',
#      u'渭滨镇',
#      u'渭花路',
#      u'渭阳东路',
#      u'渭阳中路',
#      u'渭阳西路',
#      u'渭阳路',
#      u'渭青南路',
#      u'渭青路',
#      u'游凤镇',
#      u'游泳池',
#      u'游泳馆',
#      u'游泳馆（在建）',
#      u'渼陂东路',
#      u'渼陂湖',
#      u'渼陂西路',
#      u'湘子庙',
#      u'湾子镇',
#      u'溢香楼',
#      u'满堂悦MOMA',
#      u'滦宋路',
#      u'滦白路',
#      u'滦镇东街',
#      u'滦镇街办',
#      u'滨河东路',
#      u'滨河南路',
#      u'滨河西路',
#      u'漆水河',
#      u'漆水河流域',
#      u'漠峪河',
#      u'漠西乡',
#      u'漠西站',
#      u'潘家村',
#      u'潘家村北路',
#      u'潭滨北路',
#      u'潭滨南路',
#      u'潼关县 (Tongguan)',
#      u'潼河路',
#      u'澡堂',
#      u'灞柳一路',
#      u'灞柳西路',
#      u'灞桥',
#      u'灞桥北街',
#      u'灞桥区',
#      u'灞桥区 (Baqiao)',
#      u'灞桥服务区',
#      u'灞桥镇',
#      u'灞河',
#      u'灞河东路',
#      u'灞河流域',
#      u'灞源',
#      u'灞源站',
#      u'灞源镇',
#      u'火炬路',
#      u'火神庙巷',
#      u'火药局巷',
#      u'火车站',
#      u'灯光控制组',
#      u'灵沼街办',
#      u'灵源站',
#      u'灵源镇',
#      u'炮房街',
#      u'炮里街办',
#      u'烟霞镇',
#      u'热米皮菜豆腐',
#      u'烽火镇',
#      u'焊接楼',
#      u'焦岱镇',
#      u'燕雀门',
#      u'爱华幼儿园',
#      u'爱因斯坦广场',
#      u'爱学路',
#      u'爱宁路',
#      u'爱民路',
#      u'爱西华庭',
#      u'牛角巷',
#      u'牡丹园',
#      u'牧护关镇',
#      u'物美西大街店',
#      u'狄寨路',
#      u'狄寨镇',
#      u'独李村站',
#      u'独李镇',
#      u'玄奘塔',
#      u'玄武东路',
#      u'玄武路',
#      u'玄武门大街',
#      u'玄风桥',
#      u'玄风桥北巷',
#      u'玉山',
#      u'玉山镇',
#      u'玉成路',
#      u'玉林汽车市场',
#      u'玉泉东路',
#      u'玉泉西路',
#      u'玉泉院',
#      u'玉祥门',
#      u'玉祥门站',
#      u'王二羊肉面馆',
#      u'王仓巷',
#      u'王守村',
#      u'王家咀',
#      u'王家山',
#      u'王家巷',
#      u'王家饺子馆',
#      u'王寺街办',
#      u'王曲街办',
#      u'王村镇',
#      u'王桥镇',
#      u'王莽街办',
#      u'玫瑰大楼',
#      u'环一路',
#      u'环二路',
#      u'环五路',
#      u'环六路',
#      u'环四路',
#      u'环城东路',
#      u'环城东路（南段）',
#      u'环城公园',
#      u'环城北路',
#      u'环城南路',
#      u'环城南路东段',
#      u'环城南路市场',
#      u'环城南路西段',
#      u'环城西苑',
#      u'环城西路',
#      u'环境工程大楼',
#      u'环山路',
#      u'环岛路',
#      u'环校路',
#      u'环湖东路',
#      u'环湖北路',
#      u'环湖南路',
#      u'环湖西路',
#      u'环高速公路',
#      u'珠泉路',
#      u'球类运动场',
#      u'理学院 数学与统计学院',
#      u'理工大曲江校区',
#      u'琉璃街',
#      u'瑞丽整形医院',
#      u'瓜坡镇',
#      u'甑糕',
#      u'甘家寨',
#      u'甘峪水库',
#      u'甘水坊村',
#      u'甘河镇',
#      u'甘湫池滑雪场',
#      u'甚学路',
#      u'甜水井',
#      u'生科院温室实验室',
#      u'田家小馆',
#      u'田家湾',
#      u'田家炳教育书院',
#      u'田峪河',
#      u'田市镇',
#      u'田洪正街',
#      u'田王站',
#      u'田阜乡',
#      u'田马路',
#      u'申通快递',
#      u'电力中心',
#      u'电力中心 校卫队',
#      u'电厂东路',
#      u'电厂西路',
#      u'电厂路',
#      u'电子一路',
#      u'电子三路 / Dianzi San Lu',
#      u'电子与信息工程学院',
#      u'电子东街',
#      u'电子二路 / Dianzi Er Lu',
#      u'电子二路西口',
#      u'电子五路',
#      u'电子信息路',
#      u'电子商城',
#      u'电子四路',
#      u'电子城',
#      u'电子正街',
#      u'电子西街',
#      u'电气绝缘楼',
#      u'电瓶车路',
#      u'电视塔',
#      u'电视塔路',
#      u'男澡堂',
#      u'男生宿舍',
#      u'画展路',
#      u'畅志园',
#      u'留南村',
#      u'留印路',
#      u'留学生楼',
#      u'留清路',
#      u'留渭路',
#      u'白云路',
#      u'白庙路',
#      u'白沙路 / Baisha Lu',
#      u'白鹭湾',
#      u'白鹿原',
#      u'百姓厨房',
#      u'百盛',
#      u'百盛购物中心',
#      u'皂河',
#      u'皂河站',
#      u'皂河路',
#      u'皇城东路',
#      u'皇城西路',
#      u'皇子坡村',
#      u'皇子路',
#      u'皇峪寺村',
#      u'皮影艺术博物馆',
#      u'益民坊',
#      u'盐店巷',
#      u'盐店街',
#      u'监军镇',
#      u'盛世长安',
#      u'盛志望麻酱凉皮铺',
#      u'盛志望麻酱酿皮铺',
#      u'盛景园',
#      u'相桥镇',
#      u'省射击场',
#      u'省煤炭厅家属院',
#      u'眉县 (Mei)',
#      u'真东村',
#      u'真南村',
#      u'真理村',
#      u'真西村',
#      u'眼光菩萨',
#      u'瞪羚一路',
#      u'瞪羚二路',
#      u'瞪羚路',
#      u'短途巴士中转站',
#      u'石井镇',
#      u'石化大道',
#      u'石家街站',
#      u'石川河',
#      u'石川河流域',
#      u'石桥立交',
#      u'石泉路',
#      u'石牛乡',
#      u'石牛山',
#      u'石砭峪水库',
#      u'石门镇',
#      u'矿山路',
#      u'研究生东馆',
#      u'研究生公寓',
#      u'研究生宿舍',
#      u'研究生西馆',
#      u'研飞巷',
#      u'砖房路',
#      u'砚川站',
#      u'硕士路',
#      u'碑林区',
#      u'碑林区 (Beilin)',
#      u'碧山湖',
#      u'礼仪广场',
#      u'礼堂',
#      u'礼泉',
#      u'礼泉县',
#      u'礼泉县 (Liquan)',
#      u'礼泉站',
#      u'社会北路',
#      u'社会实践部、社团文艺部',
#      u'社会路',
#      u'祁北村',
#      u'祁南村',
# ...
#      u'西5舍',
#      u'西6舍',
#      u'西7 8 9 10舍',
#      u'西一巷',
#      u'西一村',
#      u'西一街',
#      u'西一路',
#      u'西七路',
#      u'西七道',
#      u'西七道巷',
#      u'西万公路',
#      u'西万路加油站',
#      u'西万路口',
#      u'西三巷',
#      u'西三环',
#      u'西三环快速路',
#      u'西三环辅道',
#      u'西三路',
#      u'西三道巷',
#      u'西临公路',
#      u'西举院巷',
#      u'西九道',
#      u'西二巷',
#      u'西二楼',
#      u'西二环路',
#      u'西二街',
#      u'西二路',
#      u'西二道巷',
#      u'西五桥新村',
#      u'西五桥村',
#      u'西五路',
#      u'西五道',
#      u'西五道巷',
#      u'西京医院',
#      u'西京学院',
#      u'西京路',
#      u'西仓南巷',
#      u'西仓巷',
#      u'西仪坊',
#      u'西侯王村',
#      u'西保安滩村',
#      u'西八路',
#      u'西八道',
#      u'西八道巷',
#      u'西八里村巷',
#      u'西六路',
#      u'西六道',
#      u'西六道巷',
#      u'西兰路',
#      u'西关',
#      u'西关正街',
#      u'西关路',
#      u'西兴街',
#      u'西北一路',
#      u'西北东路',
#      u'西北二路',
#      u'西北农林科技大学',
#      u'西北农林科技大学附属中学',
#      u'西北国棉一厂',
#      u'西北大学',
#      u'西北大学南校区',
#      u'西北大学桃园校区',
#      u'西北大学长安校区',
#      u'西北工业大学 友谊校区',
#      u'西北工业大学 图书馆',
#      u'西北工业大学友谊校区东门',
#      u'西北工业大学友谊校区南门',
#      u'西北工业大学友谊校区西门',
#      u'西北工业大学图书馆',
#      u'西北工业大学幼儿园',
#      u'西北工业大学档案馆',
#      u'西北工业大学理学院',
#      u'西北工业大学田径场',
#      u'西北工业大学电子信息学院',
#      u'西北工业大学老图书馆',
#      u'西北工业大学自动化学院',
#      u'西北工业大学长安校区',
#      u'西北工业大学长安校区东门（北）',
#      u'西北工业大学长安校区东门（南）',
#      u'西北工业大学长安校区北门',
#      u'西北工业大学长安校区校车候车点',
#      u'西北工业大学附属中学',
#      u'西北工业大学附属中学(高中部)',
#      u'西北工业大学附属中学(高中部)东门',
#      u'西北工业大学附属中学中门',
#      u'西北工业大学附属中学北门',
#      u'西北工业大学附属中学南门',
#      u'西北工业大学附属中学操场',
#      u'西北工业大学附属中学（高中部）北门',
#      u'西北工业大学附属小学',
#      u'西北政法大学',
#      u'西北政法大学长安校区',
#      u'西北旅馆',
#      u'西区水房',
#      u'西区食堂',
#      u'西华路',
#      u'西华门大街',
#      u'西南城角',
#      u'西南巷',
#      u'西号巷',
#      u'西司马村',
#      u'西吴镇',
#      u'西咸北环线',
#      u'西咸北环线高速',
#      u'西咸大道',
#      u'西四巷',
#      u'西四府村',
#      u'西四路',
#      u'西四道巷',
#      u'西围三巷',
#      u'西围二巷',
#      u'西围墙',
#      u'西堡村',
#      u'西外东道',
#      u'西外宾馆',
#      u'西外广场',
#      u'西外西道',
#      u'西大新区',
#      u'西大楼',
#      u'西大街',
#      u'西太路',
#      u'西太路公交枢纽站',
#      u'西宁街',
#      u"西安世博公园（Xi'an EXPO)",
#      u'西安东站',
#      u'西安中学',
#      u'西安事变旧址',
#      u'西安交大城市学院',
#      u'西安交通大学',
#      u'西安交通大学北门',
#      u'西安交通大学医院',
#      u'西安交通大学口腔医学院',
#      u'西安交通大学幼儿园',
#      u'西安交通大学招生办公室',
#      u'西安交通大学曲江校区',
#      u'西安交通大学第一附属医院',
#      u'西安交通大学附属中学高中部',
#      u'西安交通大学附属第二中学',
#      u'西安交通大学雁塔校区',
#      u'西安交通大学雁塔校区生活区',
#      u'西安交通工程学院',
#      u'西安体育学院',
#      u'西安儿童公园',
#      u'西安元智',
#      u'西安光机所',
#      u'西安光电园',
#      u'西安创业水务公司',
#      u'西安创业水务公司二期',
#      u'西安化工厂',
#      u'西安北',
#      u'西安北站',
#      u'西安医专附属医院',
#      u'西安医学院未央校区',
#      u'西安医学高等专科学校',
#      u'西安华城国际',
#      u'西安华天通信有限公司',
#      u'西安南站',
#      u'西安博物院',
#      u'西安印钞厂',
#      u'西安变压器厂',
#      u'西安咸阳国际机场',
#      u'西安国际贸易中心',
#      u'西安国际高尔夫俱乐部',
#      u'西安地铁一号线',
#      u'西安地铁三号线',
#      u'西安地铁二号线',
#      u'西安城南客运站',
#      u'西安城墙',
#      u'西安城墙(含光门)',
#      u'西安城墙(和平门)',
#      u'西安城墙(建国门)',
#      u'西安城墙(文昌门)',
#      u'西安城墙(朱雀门)',
#      u'西安城墙(永宁门)',
#      u'西安城市运动公园',
#      u'西安城建技术学院',
#      u'西安培华学院长安校区',
#      u'西安培苑高考补习学校',
#      u'西安外事学院',
#      u'西安外事学院北教学区',
#      u'西安外国语大学长安校区',
#      u'西安外国语大学长安校区图书馆',
#      u'西安外国语大学（雁塔校区）',
#      u'西安大雁塔假日酒店',
#      u'西安奥林匹克花园',
#      u'西安宇航中心',
#      u'西安宇航小学',
#      u'西安宇航幼儿园',
#      u'西安宏桥中学',
#      u'西安工业大学未央校区',
#      u'西安工业学院',
#      u'西安工程大学',
#      u'西安工程大学图书馆',
#      u'西安工程大学田径操场',
#      u'西安工程技术学院',
#      u'西安市',
#      u"西安市 / Xi'an",
#      u'西安市中心医院',
#      u'西安市人民体育场',
#      u'西安市儿童医院',
#      u'西安市公安局出入境管理中心',
#      u'西安市旅游咨询服务中心',
#      u'西安市曲江第一中学',
#      u'西安市民政曲江小区',
#      u'西安市汽车站',
#      u'西安市现代化综合苗圃',
#      u'西安市第一中学',
#      u'西安市第九医院',
#      u'西安市第八医院',
#      u'西安市第八十九中学',
#      u'西安市第四医院',
#      u'西安市第四污水处理厂',
#      u'西安市结核病医院',
#      u'西安市肿瘤医院',
#      u'西安市长延堡派出所',
#      u'西安市高新一中',
#      u'西安市高新第二小学',
#      u'西安建筑科技大学',
#      u'西安建筑科技大学草堂校区',
#      u'西安惠安中学',
#      u'西安惠安中学北门',
#      u'西安惠安中学南门',
#      u'西安惠安小学',
#      u'西安政治学院',
#      u'西安文理学院',
#      u'西安新纪元高尔夫俱乐部',
#      u'西安明德中学',
#      u'西安植物园',
#      u'西安植物园家属院',
#      u'西安欧亚学院',
#      u'西安比亚迪汽车公司二厂（草堂厂区）',
#      u'西安活跃网络有限公司',
#      u'西安济仁医院',
#      u'西安烈士陵园',
#      u'西安烤鸭店总店',
#      u'西安理工大学',
#      u'西安理工大学田径操场',
#      u'西安理工大学篮球场',
#      u'西安理工大学羽毛球与乒乓球场',
#      u'西安理工大学高等技术学院',
#      u"西安瑞斯丽大酒店 / Xi'an Swizz Touches Hotel",
#      u'西安电子科技大学',
#      u'西安电子科技大学新校区',
#      u'西安电子科技大学新校区北门',
#      u'西安电子科技大学长安校区',
#      u'西安电子科技大学长安校区图书馆',
#      u'西安电子科技职业学院',
#      u'西安电瓷厂',
#      u'西安电缆厂',
#      u'西安电视台',
#      u'西安石油大学',
#      u'西安石油大学南区',
#      u'西安石油大学户县校区',
#      u'西安石油大学生活区',
#      u'西安碑林',
#      u'西安秋林(吉祥店)',
#      u'西安科技大学',
#      u'西安科技大学北校区',
#      u'西安秦岭野生动物园',
#      u'西安站',
#      u'西安绕城高速',
#      u'西安绕城高速G3001',
#      u'西安绝缘材料厂',
#      u'西安美术学院',
#      u'西安美术学院美术馆',
#      u'西安美术馆',
#      u'西安翻译学院',
#      u'西安职业中等专业学校',
#      u'西安职业技术学院',
#      u'西安航空学院',
#      u'西安西站',
#      u'西安财经学院',
#      u'西安财经学院长安校区',
#      u'西安车辆厂',
#      u'西安软件园 零壹广场',
#      u'西安软件园: 218, 253, 260, 262',
#      u'西安软件园: 260, 262',
#      u'西安软件园唐乐阁',
#      u'西安软件园汉韵阁',
#      u'西安软件园秦风阁',
#      u'西安软件园零壹广场',
#      u'西安软件服务外包学院',
#      u'西安软家园秦风阁综合大楼',
#      u'西安邮区中心局',
#      u'西安邮区中心局草滩邮件处理中心',
#      u'西安邮电大学图书馆',
#      u'西安邮电大学长安校区',
#      u'西安邮电学院南校区',
#      u'西安铁路工程职工大学',
#      u'西安银行',
#      u'西安阎良机场',
#      u'西安陇华 hotel',
#      u'西安院子',
#      u'西安雁塔神龙中医医院',
#      u'西安音乐厅',
#      u'西安音乐学院',
#      u'西安飞机工业',
#      u'西安高压开关厂',
#      u'西安高新区环普产业园',
#      u'西安高架快速干道',
#      u'西安高科度假大酒店',
#      u'西安高科度假大酒店 正门',
#      u'西安鼓楼博物馆',
#      u'西宝疏导线',
#      u'西宝高速',
#      u'西宝高铁',
#      u'西寨菜市场',
#      u'西寨： 905，917，923，4-19',
#      u'西寨：215，229，324，918',
#      u'西寨：215，229，324，918，4-18',
#      u'西寨：323，500，4-04，4-09，4-10，4-13',
#      u'西寨：323，500，4-04，4-09，4-10，4-13，4-18',
#      u'西寨：905，917，923，4-19',
#      u'西尧上村',
#      u'西岳路',
#      u'西工大',
#      u'西工大医院',
#      u'西工大商场',
#      u'西工大旺园学生公寓',
#      u'西工大路',
#      u'西工大车队',
#      u'西工大车队正门',
#      u'西工大长安校区',
#      u'西工大附中校内天桥',
#      u'西工大附中钟楼',
#      u'西平铁路',
#      u'西康铁路',
#      u'西延路',
#      u'西延铁路',
#      u'西延高速',
#      u'西建新村',
#      u'西开公司',
#      u'西开医院',
#      u'西张堡',
#      u'西张堡镇',
#      u'西影路',
#      u'西成客专',
#      u'西成客运专线',
#      u'西成高铁',
#      u'西户公路',
#      u'西户路',
#      u'西户铁路',
#      u'西操场',
#      u'西斜七路',
#      u'西新街',
#      u'西曹村',
#      u'西杨万村',
#      u'西汉高速',
#      u'西江坡村',
#      u'西沃南路',
#      u'西沣路建材市场',
#      u'西泉镇',
#      u'西湖1#楼',
#      u'西湖2#楼',
#      u'西滩村',
#      u'西潼高速',
#      u'西潼高速G20',
#      u'西潼高速G30',
#      u'西环城路',
#      u'西环路',
#      u'西甜水井巷',
#      u'西电中学',
#      u'西电实验小学',
#      u'西电宾馆',
#      u'西电技师学院',
#      u'西电集团医院',
#      u'西禹高速',
#      u'西稍门',
#      u'西窑头',
#      u'西站路',
#      u'西篮球场',
#      u'西羊市',
#      u'西羊村',
#      u'西航花园',
#      u'西花园',
#      u'西苑北路',
#      u'西苑南路',
#      u'西蓝高速',
#      u'西街',
#      u'西足球场',
#      u'西车张',
#      u'西迁纪念馆',
#      u'西道巷',
#      u'西部之光-陕西电视塔',
#      u'西部国际车城',
#      u'西部大道',
#      u'西部欣桥农产品物流中心',
#      u'西里路',
#      u'西铁分局',
#      u'西铁双维超市',
#      u'西铜高速',
#      u'西门',
#      u'西闸口',
#      u'西阳镇',
#      u'西阶',
#      u'西韦巷',
#      u'西韩村',
#      u'西韩街',
#      u'西飞大道',
#      u'西食堂',
#      u'西高新',
#      u'西黄高速',
#      u'西龙窝村',
#      u'观音山',
#      u'观音禅院',
#      u'规划局家属院',
#      u'规划路',
#      u'角楼',
#      u'解放军三二三医院',
#      u'解放南路',
#      u'解放市场',
#      u'解放路',
#      u'解放门',
#      u'计算机中心',
#      u'许士庙街',
#      u'许滨北路',
#      u'试飞路',
#      u'试飞院路',
#      u'试验田',
#      u'诚信路',
#      u'诚字楼',
#      u'调剂餐厅',
#      u'谢王桥',
#      u'谭家',
#      u'谭家滩村',
#      u'谷家巷',
#      u'豁口',
#      u'豪邦时尚购物广场',
#      u'贞元镇',
#      u'贞观路',
#      u'贡院门',
#      u'财东路',
#      u'货车安全检查站',
#      u'贾三灌汤包子馆',
#      u'贾家滩村',
#      u'贾家馄饨馆',
#      u'赛格电脑城',
#      u'赛格购物中心',
#      u'赤栏桥村',
#      u'赤水河',
#      u'赤水站',
#      u'赤水镇',
#      u'赵佳宝甜食',
#      u'赵公明财神庙',
#      u'赵围东路',
#      u'赵家堡村',
#      u'赵村镇',
#      u'赵王巷',
#      u'赵王村',
#      u'赵镇',
#      u'足球场',
#      u'跳楼塔',
#      u'车棚',
#      u'车站东路',
#      u'车站北路',
#      u'车站南路',
#      u'软件学院',
#      u'辋川',
#      u'辛家寨镇',
#      u'辛家庙',
#      u'辛家庙立交',
#      u'辛家庙站',
#      u'辛王路',
#      u'边东巷',
#      u'边东街',
#      u'边西街',
#      u'边防学院',
#      u'迎宾大道',
#      u'迎宾路',
#      u'迎春巷',
#      u'运动公园站',
#      u'运动场',
#      u'运渠店村',
#      u'连丰北巷',
#      u'连丰南巷',
#      u'连心路',
#      u'连霍高速',
#      u'连霍高速 - Lianhuo Expressway',
#      u'通化门站',
#      u'通塬路',
#      u'通济坊',
#      u'通远镇',
#      u'造字台路',
#      u'逸夫图书馆',
#      u'逸夫工程馆',
#      u'逸夫楼',
#      u'逸夫科学馆',
#      u'逸夫科技信息楼',
#      u'逸翠园第一期',
#      u'道北中学',
#      u'避难线',
#      u'那曲路',
#      u'邮政储蓄银行',
#      u'邮电北巷',
#      u'邮电南巷',
#      u'邰城路',
#      u'郑国路',
#      u'郑西客运专线',
#      u'郝家巷',
#      u'郝家滩村',
#      u'郝村',
#      u'郝村滩北庄',
#      u'郦苑大酒店',
#      u'郭北村',
#      u'郭家巷',
#      u'郭杜东街',
#      u'郭杜南街',
#      u'郭杜街办',
#      u'郭杜西街',
#      u'都城隍庙',
#      u'都市与建筑设计研究中心（7F）',
#      u'都市水乡',
#      u'鄠邑区',
#      u'鄠邑区人民政府',
#      u'酒店',
#      u'酒店预留土地',
#      u'里花北路',
#      u'里贤庄村',
#      u'重光路',
#      u'重玄路',
#      u'重阳宫',
#      u'金光门桥',
#      u'金华路',
#      u'金吾丈东路',
#      u'金吾丈西路',
#      u'金地湖城大境',
#      u'金城路',
#      u'金域牟嘉',
#      u'金堆城小区',
#      u'金堆城：162',
#      u'金堆镇',
#      u'金宇蓝苑',
#      u'金山镇',
#      u'金康路',
#      u'金旭路',
#      u'金曹路',
#      u'金桥路',
#      u'金水路',
#      u'金汉斯',
#      u'金沣路',
#      u'金源•御景华府',
#      u'金石路',
#      u'金融路',
#      u'金鹰',
#      u'鑫泰熙乐',
#      u'钓鱼台',
#      u'钓鱼台路',
#      u'钟元小区',
#      u'钟公园小径',
#      u'钟楼',
#      u'钟楼书店',
#      u'钟楼地下通道',
#      u'钟楼站',
#      u'钟楼青年旅馆',
#      u'钟楼饭店',
#      u'钟鼓楼广场',
#      u'钱学森图书馆',
#      u'铁一中',
#      u'铁一中3公寓',
#      u'铁一中4公寓',
#      u'铁一中东校区',
#      u'铁一操场',
#      u'铁器厂',
#      u'铁塔寺北街',
#      u'铁塔寺西街',
#      u'铁塔寺路',
#      u'铁安一街',
#      u'铁安二街',
#      u'铁志坚腊牛羊肉店',
#      u'铁永坊',
#      u'铁炉乡',
#      u'铁设院',
#      u'铝业路',
#      u'铭城国际学校',
#      u'铭城国际幼儿园',
#      u'铭城国际社区',
#      u'银杏大道',
#      u'银桥大道',
#      u'银河科技公寓 / Yinhe Keji Gongyu',
#      u'银河路',
#      u'银泰城',
#      u'银百高速',
#      u'锅炉房',
#      u'锦业三路',
#      u'锦业二路',
#      u'锦业四路',
#      u'锦业新居',
#      u'锦业路 JinYe road',
#      u'锦园小区',
#      u'锦园路',
#      u'锦盛邸',
#      u'长丰园',
#      u'长乐东路',
#      u'长乐中路',
#      u'长乐公园',
#      u'长乐坊',
#      u'长乐坡站',
#      u'长乐巷',
#      u'长乐第二小学',
#      u'长乐街',
#      u'长乐西苑',
#      u'长乐西路',
#      u'长乐门（东门）',
#      u'长兴北路',
#      u'长兴南路',
#      u'长兴路',
#      u'长大南路',
#      u'长宁镇',
#      u'长安一中',
#      u'长安一中初中部',
#      u'长安三中',
#      u'长安三幼',
#      u'长安东大',
#      u'长安九中',
#      u'长安二中',
#      u'长安二中：162',
#      u'长安党校',
#      u'长安党校：215，229，324，918',
#      u'长安分局出入境管理中心',
#      u'长安北路',
#      u'长安区',
#      u"长安区 (Chang'an)",
#      u'长安区政府',
#      u'长安十一中',
#      u'长安南路',
#      u'长安南路 Cháng‘ān nán lù',
#      u'长安塔',
#      u'长安大学',
#      u'长安大学本部体育场',
#      u'长安大学校本部东院',
#      u'长安大学校本部办公楼',
#      u'长安大学汽车试验场',
#      u'长安大学渭水校区',
#      u'长安大学渭水校区医院',
#      u'长安大学渭水校区实验楼',
#      u'长安大学附属中学',
#      u'长安大学雁塔校区',
#      u'长安大道',
#      u'长安妇幼保健医院',
#      u'长安客运公司',
#      u'长安广场',
#      u'长安民政局',
#      u'长安汽车站',
#      u'长安消防队',
#      u'长安立交',
#      u'长安西路',
#      u'长安计划生育服务中心',
#      u'长安路',
#      u'长庆东路',
#      u'长庆西路',
#      u'长庆路',
#      u'长延堡',
#      u'长延堡购物中心',
#      u'长延居·会展明珠',
#      u'长征365',
#      u'长征国际酒店',
#      u'长江丰泽园',
#      u'长江流域',
#      u'长百商厦',
#      u'长缨北路',
#      u'长缨西路',
#      u'长缨路',
#      u'长翠路',
#      u'长胜街',
#      u'长虹广场',
#      u'长途巴士中转站',
#      u'长里村',
#      u'长陵站',
#      u'长陵路',
#      u'长鸣公路',
#      u'长鸣路',
#      u'门球场',
#      u'问远路',
#      u'阎南路',
#      u'阎村镇',
#      u'阎油路',
#      u'阎良',
#      u'阎良区',
#      u'阎良区 (Yanliang)',
#      u'阎良站',
#      u'阜寨乡',
#      u'阡东镇',
#      u'防护林',
#      u'阳光东路',
#      u'阳光北路',
#      u'阳光华庭',
#      u'阳光天地',
#      u'阳光小区',
#      u'阳光苑',
#      u'阳光苑广场',
#      u'阳光路',
#      u'阳峪站',
#      u'阳洪镇',
#      u'阳郭镇',
#      u'阳阳国际',
#      u'阶梯教室',
#      u'阿姆瑞特家居',
#      u'阿房一路',
#      u'阿房三路',
#      u'阿房二路',
#      u'阿房四路',
#      u'阿房宫',
#      u'阿房宫遗址',
#      u'阿房宫遗址公园',
#      u'阿里路',
#      u'陂头村',
#      u'陂西镇',
#      u'陇海线',
#      u'陈伍路',
#      u'陈南路',
#      u'陈天人校长纪念碑',
#      u'陈沟村路',
#      u'陈河镇',
#      u'陈西路',
#      u'陈阳寨',
#      u'陈阳寨街办',
#      u'陕公路',
#      u'陕师大羽毛球场',
#      u'陕师大长安校区',
#      u'陕报社',
#      u'陕柴儿童游泳池',
#      u'陕柴小学',
#      u'陕柴小学主教学楼',
#      u'陕柴小学体育场',
#      u'陕柴小学宿舍',
#      u'陕柴小学洗手间',
#      u'陕柴小学辅教学楼',
#      u'陕柴广场',
#      u'陕柴游泳池',
#      u'陕柴社区足球场',
#      u'陕煤集团(西安重装)小区',
#      u'陕西中医大学',
#      u'陕西信合',
#      u'陕西医科学校',
#      u'陕西历史博物馆',
#      u'陕西国防工业技师学院',
#      u'陕西国防工业职业技术学院',
#      u'陕西国防工业职业技术学院南校区',
#      u'陕西基础地理信息中心',
#      u'陕西大会堂',
#      u'陕西学前师范学院',
#      u'陕西实验中学',
#      u'陕西宾馆',
#      u'陕西局青年公寓',
#      u'陕西师范大学',
#      u'陕西师范大学 （长安校区）',
#      u'陕西师范大学田径场',
#      u'陕西师范大学长安校区',
#      u'陕西师范大学附属中学',
#      u'陕西师范大学附属小学幼儿园',
#      u'陕西广播电视大学',
#      u'陕西戏曲大观园',
#      u'陕西日报社',
#      u'陕西测绘地理信息局',
#      u'陕西测绘局家属楼',
#      u'陕西电视塔 Shaanxi Television Tower',
#      u'陕西省',
#      u'陕西省中医医院',
#      u'陕西省交通医院',
#      u'陕西省人民医院',
#      u'陕西省动物研究所实验基地',
#      u'陕西省图书馆',
#      u'陕西省政府',
#      u'陕西省教育局',
#      u'陕西省第二人民医院',
#      u'陕西省结核病防治研究所',
#      u'陕西省计算机专业技术资格水平考试办公室',
#      u'陕西省跳水游泳馆',
#      u'陕西省银行学校',
#      u'陕西社会主义学院',
#      u'陕西科技大学西安校区',
#      u'陕西科技馆',
#      u'陕西第一碗',
#      u'陕西职业技师学校',
#      u'陕西自然博物馆',
#      u'陕重汽大道',
#      u'陕鼓大街',
#      u'陕鼓西仪',
#      u'陕鼓集团',
#      u'院门巷',
#      u'陶院巷',
#      u'雁南一路',
#      u'雁南三路',
#      u'雁南三路 Yàn nán sān lù',
#      u'雁南二路',
#      u'雁南二路 Yàn nán èr lù',
#      u'雁南五路',
#      u'雁南四路 Yàn nán sì lù',
#      u'雁塔区',
#      u'雁塔区 (Yanta)',
#      u'雁塔区美术馆',
#      u'雁塔南路',
#      u'雁塔立交',
#      u'雁塔西路',
#      u'雁塔西路（东段）',
#      u'雁塔西路（西段）',
#      u'雁塔路',
#      u'雁引路',
#      u'雁环路',
#      u'雁翔桥',
#      u'雁翔路',
#      u'雅居乐勃朗峯',
#      u'雅居乐花园',
#      u'雅荷一路',
#      u'雅风路',
#      u'集贤巷',
#      u'集贤路',
#      u'集贤镇',
#      u'雨金镇',
#      u'零二商店',
#      u'零口',
#      u'零口镇',
#      u'零河',
#      u'零河水库',
#      u'雷沣路',
#      u'雾庄桥',
#      u'露天停车场',
#      u'霸陵乡',
#      u'青化镇',
#      u'青城：162',
#      u'青少年活动中心',
#      u'青岔村',
#      u'青岔站',
#      u'青年一巷',
#      u'青年之家',
#      u'青年二巷',
#      u'青年北街',
#      u'青年南街',
#      u'青年南街：215，229，324，918',
#      u'青年教师公寓1#',
#      u'青年教师公寓2#',
#      u'青年教师公寓3#',
#      u'青年街',
#      u'青年路',
#      u'青年路三巷',
#      u'青松路',
#      u'青门南巷',
#      u'青门巷',
#      u'青龙寺',
#      u'青龙寺站',
#      u'青龙路',
#      u'革命公园',
#      u'韦大路',
#      u'韦曲',
#      u'韦曲北街',
#      u'韦曲南',
#      u'韦曲南 A 入口',
#      u'韦曲南 B 入口',
#      u'韦曲南 C 入口',
#      u'韦曲南 D 入口',
#      u'韦曲南街社区医院 (申店医院)',
#      u'韦曲老街',
#      u'韦曲街办',
#      u'韦罗高速公路',
#      u'韦郭路',
#      u'韩家湾街道',
#      u'韩峪乡',
#      u'韩森寨',
#      u'韩森路',
#      u'韩非路',
#      u'音乐广场',
#      u'韵达快递',
#      u'顺兴路',
#      u'顺城北路',
#      u'顺城南路',
#      u'频谱研究所',
#      u'颜家堡路',
#      u'风华路',
#      u'风韵蓝湾',
#      u'飞天路',
#      u'飞炫',
#      u'食品学院中试车间',
#      u'食堂',
#      u'餐厅',
#      u'餐饮中心',
#      u'饕餮食街',
#      u'饮食中心面屋',
#      u'饮马池',
#      u'首创国际城',
#      u'首阳山',
#      u'香柏路',
#      u'香格里拉大酒店',
#      u'香王',
#      u'香积大道',
#      u'香积寺',
#      u'香积寺村',
#      u'香米园',
#      u'香米园西巷',
#      u'香蜜园',
#      u'马厂子',
#      u'马召镇',
#      u'马坊村',
#      u'马坊滩村',
#      u'马坊路',
#      u'马家堡',
#      u'马家堡村',
#      u'马家湾乡',
#      u'马家院巷',
#      u'马嵬坡站',
#      u'马嵬镇',
#      u'马庄',
#      u'马庄镇',
#      u'马德全特色烤鸡',
#      u'马泉镇',
#      u'马王站',
#      u'马王街办',
#      u'马腾空',
#      u'马腾空桥',
#      u'马营村',
#      u'马连镇',
#      u'马额镇',
#      u'驾校训练场',
#      u'骆驼巷',
#      u'骊山',
#      u'骏马乡',
#      u'骡马市',
#      u'高三路',
#      u'高交路',
#      u'高冠峪',
#      u'高塘镇',
#      u'高家堡',
#      u'高家寨村',
#      u'高岳菘宅 UNESCO',
#      u'高庄路',
#      u'高庄镇',
#      u'高教楼',
#      u'高新一中国际部',
#      u'高新一路',
#      u'高新一路 / Gaoxin Yi Lu',
#      u'高新三中',
#      u'高新三路 / Gaoxin San Lu',
#      u'高新二路',
#      u'高新二路 / Gaoxin Er Lu',
#      u'高新五小',
#      u'高新六路 / Gaoxin Liu Lu',
#      u'高新医院',
#      u'高新唐南中学',
#      u'高新四小',
#      u'高新国际学校',
#      u'高新路',
#      u'高新路 / Gaoxin Lu',
#      u'高新逸品',
#      u'高新逸品1号楼',
#      u'高新逸品2号楼',
#      u'高新逸品3号楼',
#      u'高新逸翠园学校',
#      u'高桥街办',
#      u'高泾路',
#      u'高渠乡',
#      u'高科尚都',
#      u'高薪一中高中部 / Gaoxin Yizhong Gaozhong Bu',
#      u'高薪四路 / Gaoxin Si Lu',
#      u'高薪第一小学 / Gaoxin Diyi Xiaoxue',
#      u'高薪路 / Gaoxin Lu',
#      u'高阳一路',
#      u'高阳二路',
#      u'高阳四路',
#      u'高阳里',
#      u'高陵',
#      u'高陵区',
#      u'高陵县 (Gaoling)',
#      u'魏家凉皮',
#      u'魏家凉皮 @ 南门店',
#      u'魏寨街办',
#      u'鱼化寨',
#      u'鱼化寨站',
#      u'鱼化寨街',
#      u'鱼化桥',
#      u'鱼斗路',
#      u'鱼藻路',
#      u'鲁家寨村',
#      u'鲁家村',
#      u'鸣犊街办',
#      u'鸿翔路',
#      u'鹿塬街',
#      u'鹿塬街西段',
#      u'鹿翔路',
#      u'鹿苑大道',
#      u'麟游县 (Linyou)',
#      u'麦当劳',
#      u'麦德龙 METRO',
#      u'麻坪镇',
#      u'麻街镇',
#      u'黄埔村',
#      u'黄家寨',
#      u'黄家庄村',
#      u'黄良街办',
#      u'黄金嘉园 西门',
#      u'黄金嘉园一号楼',
#      u'黄金嘉园三号楼',
#      u'黄金嘉园二号楼',
#      u'黎明一巷',
#      u'黑河',
#      u'黑河金盆水库',
#      u'黑龙口镇',
#      u'鼓楼',
#      u'龙新村',
#      u'龙渠堡',
#      u'龙渠湾',
#      u'龙窝村',
#      u'龙腾路',
#      u'龙西村',
#      u'龙钢集团',
#      u'龙首东路',
#      u'龙首中路',
#      u'龙首北路',
#      u'龙首南路',
#      u'龙首原',
#      u'龙首商业街',
#      u'센양 국제공항',
#      u'한성호공원'])

# %% [markdown]
# Bingo! Pretty easily, we can see the problems, because some of the name tags contain only English words (when they shouldn't) or contain duplicated Chinese and English names:
#
# - ('Gaoling Xian', '244080278')
# - (u'索菲特国际会展中心 Sofitel on Renmin Square', '850352828')

# %% [markdown]
# ## Auditing Name Tags
#
# Using another helper function **find_and_print()** defined and put at the beginning, let's look at the whole elements in which the above two potential problematic name tags live:

# %%
find_and_print('244080278')
find_and_print('850352828')
# Out:
# node id: 244080278
# {'created_by': 'dkt_GNS-import-1',
#  'gns:ADM1': '26',
#  'gns:DSG': 'ADM3',
#  'gns:UFI': '-1906363',
#  'gns:UNI': '6816820',
#  'name': 'Gaoling Xian',
#  'name:vi': u'Cao Lăng',
#  'name:zh': u'高陵县',
#  'name:zh_pinyin': 'Gaoling Xian',
#  'place': 'county'}
#
# node id: 850352828
# {'addr:housenumber': '319',
#  'addr:street': 'Dongxin',
#  'name': u'索菲特国际会展中心 Sofitel on Renmin Square',
#  'name:en': 'Sofitel on Renmin Square',
#  'name:zh': u'索菲特国际会展中心',
#  'tourism': 'hotel'}

# %% [markdown]
# Ha, the OSM elements do have the correct Chinese names, although buried in the 'name:zh' tags ('高陵县' and '索菲特国际会展中心'). Fixing them once we have found them should be easy (copy 'name:zh' tags to 'name' tags). However, determining how to pinpoint these kind of problematic name tags could be challenging.
#
# First, let's ascertain whether we can safely use the 'name:zh' tags as the gold standard to fix our name tags by searching the counterexamples:

# %%
ALL_CN = re.compile(u'^[\u4e00-\u9fa5\s]+$')

# search 'name:zh' tags containing non-Chinese characters

for elem, key, val in all_tags(OSM_FILE):
    if key == 'name:zh' and not ALL_CN.match(val):
        tags = { tag.attrib['k']: tag.attrib['v'] 
                     for tag in elem.iter('tag') }
        name = tags.get('name', '')
        
        print('id     ', elem.attrib['id'])
        print('name   ', name)
        print('name:zh', val, '\n')
# Out:
# id      310515765
# name    兵马俑 terracotta army
# name:zh Exército de Terracota
#
# id      1761733711
# name    长乐门（东门）
# name:zh 长乐门（东门）
#
# id      2535980901
# name    都城隍庙
# name:zh Duchenghuang Temple of Xi'an
#
# id      4308320198
# name    센양 국제공항
# name:zh Aeroporto Internacional de Xi'an Xianyang
#
# id      4317716489
# name    陕西省计算机专业技术资格水平考试办公室
# name:zh 地   址：西安市高新区丈八五路10号 陕西省科技资源统筹中心D座217室
#
# id      4376910800
# name    Yong Ning International Art museum
# name:zh Yong Ning International Art museum
#
# id      4377098289
# name    greenants outdoor
# name:zh greenants outdoor
#
# id      4379974989
# name    K2 summit
# name:zh K2 summit
#
# id      4381895289
# name    Yuan village food tourist park
# name:zh Yuan village food tourist park
#
# id      4388892491
# name    Three Sisters Dumplings
# name:zh Three Sisters Dumplings
#
# id      4394361889
# name    pagoda
# name:zh pagoda
#
# id      4397221090
# name    PSB office for visa extensions
# name:zh PSB office for visa extensions
#
# id      4405705298
# name    Yaijie Guesthouse
# name:zh Yaijie Guesthouse
#
# id      4409659533
# name    First Noodle under the sun
# name:zh 天下第一面 First Noodle under the sun
#
# id      4412751093
# name    décathlon store
# name:zh décathlon store
#
# id      4448973294
# name    parada 702
# name:zh parada 702
#
# id      4449004389
# name    bus 702
# name:zh bus 702
#
# id      4449051494
# name    Empark Grand Hotel
# name:zh Empark Grand Hotel
#
# id      4516274493
# name    Wal-Mart
# name:zh Wal-Mart
#
# id      4516285094
# name    天下第一面 @ 吉祥村店
# name:zh 天下第一面 @ 吉祥村店
#
# id      4516332396
# name    高岳菘宅 UNESCO
# name:zh 高岳菘宅 UNESCO
#
# id      4516332397
# name    三姐妹饺子 @ 东木头市店
# name:zh 三姐妹饺子 @ 东木头市店
#
# id      4516348789
# name    红红酸菜炒米
# name:zh 红红 skewers
#
# id      4516348790
# name    魏家凉皮 @ 南门店
# name:zh 魏家凉皮 @ 南门店
#
# id      4516349190
# name    Bang Bang 面
# name:zh Bang Bang 面
#
# id      254488433
# name    西安博物院
# name:zh Xi'an museum
#
# id      266254855
# name    西安咸阳国际机场
# name:zh 西安咸阳国际机场(XIY)
#
# id      176920
# name    312国道
# name:zh 312国道
#
# id      5869568
# name    亞洲公路34號線
# name:zh 亞洲公路34號線

# %% [markdown]
# Unfortunately, counterexamples do exist. However, it does not prevent us from using the 'name:zh' tags as the gold standard, but it does mean we have to use them with care: checking before using.
#
# So we can split up the problematic name tags into two groups depending on whether the 'name:zh' tags can be used as the gold standard:

# %%
ALL_EN = re.compile(u'^[a-zA-Z0-9\s]+$')
CN_EN  = re.compile(u'^[\u4e00-\u9fa5\s]+[^\u4e00-\u9fa5]+$')

names_zh_good = []
names_zh_bad  = []

for elem, key, val in all_tags(OSM_FILE):
    if key == 'name':
        tags = { tag.attrib['k']: tag.attrib['v'] 
                     for tag in elem.iter('tag') }
        zh = tags.get('name:zh', '')
    
        if ALL_EN.match(val) and ALL_CN.match(zh):
            names_zh_good.append([elem.attrib['id'], val, zh])
            
        elif CN_EN.match(val):
            if ALL_CN.match(zh):
                names_zh_good.append([elem.attrib['id'], val, zh])  
            else:
                names_zh_bad.append([elem.attrib['id'], val])
                
print("Tags of 'name:zh' in Chinese:\n")
for id, name, zh in names_zh_good:
    print('id     ', id)
    print('name   ', name)
    print('name:zh', zh, '\n')
# Out:
# Tags of 'name:zh' in Chinese:
#
# id      244080278
# name    Gaoling Xian
# name:zh 高陵县
#
# id      310740922
# name    Watsons
# name:zh 屈臣氏
#
# id      850352828
# name    索菲特国际会展中心 Sofitel on Renmin Square
# name:zh 索菲特国际会展中心
#
# id      1511453998
# name    KFC
# name:zh 肯德基
#
# id      2254514432
# name    KFC
# name:zh 肯德基
#
# id      2260053296
# name    华山南峰 Hua Shan South Peak
# name:zh 华山南峰
#
# id      2379990928
# name    Vanguard
# name:zh 华润万家
#
# id      2634971740
# name    KFC
# name:zh 肯德基
#
# id      2945306642
# name    KFC
# name:zh 肯德基
#
# id      3995724828
# name    翠华山 Cuihua Mountain
# name:zh 翠华山
#
# id      4086083089
# name    KFC
# name:zh 肯德基
#
# id      4119774589
# name    KFC
# name:zh 肯德基
#
# id      4198263692
# name    KFC
# name:zh 肯德基
#
# id      28258008
# name    Tangyan Lu
# name:zh 唐延路
#
# id      28258930
# name    长安南路 Cháng‘ān nán lù
# name:zh 长安南路
#
# id      28258946
# name    桃园南路 / Taoyuan Nan Lu
# name:zh 桃园南路
#
# id      28339844
# name    高新六路 / Gaoxin Liu Lu
# name:zh 高新六路
#
# id      28343179
# name    2nd Ring Road
# name:zh 二环路
#
# id      39825419
# name    Longhai Line
# name:zh 陇海线
#
# id      39825420
# name    Longhai Line
# name:zh 陇海线
#
# id      39825421
# name    Longhai Line
# name:zh 陇海线
#
# id      39825422
# name    Longhai Line
# name:zh 陇海线
#
# id      39825432
# name    Longhai Line
# name:zh 陇海线
#
# id      39825434
# name    Longhai Line
# name:zh 陇海线
#
# id      123290405
# name    Longhai Line
# name:zh 陇海线
#
# id      123290414
# name    Longhai Line
# name:zh 陇海线
#
# id      139828159
# name    Longhai Line
# name:zh 陇海线
#
# id      139828163
# name    Longhai Line
# name:zh 陇海线
#
# id      142323459
# name    曲江池东路 Qū jiāng chí East Rd
# name:zh 曲江池东路
#
# id      142323461
# name    三兆路 Sānzhào Rd
# name:zh 三兆路
#
# id      142323463
# name    雁南四路 Yàn nán sì lù
# name:zh 雁南四路
#
# id      142323469
# name    芙蓉西路 Fúróng West Rd
# name:zh 芙蓉西路
#
# id      142323474
# name    曲江池西路 Qū jiāng chí West Rd
# name:zh 曲江池西路
#
# id      142323478
# name    新开门南路 New Open Door South Rd
# name:zh 新开门南路
#
# id      142323481
# name    庙坡头路 Miào pōtóu lù
# name:zh 庙坡头路
#
# id      152429475
# name    2nd Ring Road
# name:zh 二环路
#
# id      181341777
# name    Longhai Line
# name:zh 陇海线
#
# id      181341781
# name    Longhai Line
# name:zh 陇海线
#
# id      220732076
# name    Longhai Line
# name:zh 陇海线
#
# id      220732077
# name    Longhai Line
# name:zh 陇海线
#
# id      220793568
# name    Longhai Line
# name:zh 陇海线
#
# id      220793569
# name    Longhai Line
# name:zh 陇海线
#
# id      220793572
# name    Longhai Line
# name:zh 陇海线
#
# id      220793574
# name    Longhai Line
# name:zh 陇海线
#
# id      239284682
# name    曲江池东路 Qū jiāng chí East Rd
# name:zh 曲江池东路
#
# id      249318217
# name    雁南二路 Yàn nán èr lù
# name:zh 雁南二路
#
# id      250709118
# name    长安南路 Cháng‘ān nán lù
# name:zh 长安南路
#
# id      250709121
# name    长安南路 Cháng‘ān nán lù
# name:zh 长安南路
#
# id      250709124
# name    长安南路 Cháng‘ān nán lù
# name:zh 长安南路
#
# id      251744557
# name    雁南三路 Yàn nán sān lù
# name:zh 雁南三路
#
# id      251744559
# name    雁南三路 Yàn nán sān lù
# name:zh 雁南三路
#
# id      251746753
# name    长安南路 Cháng‘ān nán lù
# name:zh 长安南路
#
# id      263572157
# name    三兆路 Sānzhào Rd
# name:zh 三兆路
#
# id      263572159
# name    三兆路 Sānzhào Rd
# name:zh 三兆路
#
# id      264116882
# name    Longhai Line
# name:zh 陇海线
#
# id      264116896
# name    2nd Ring Road
# name:zh 二环路
#
# id      264116897
# name    2nd Ring Road
# name:zh 二环路
#
# id      266795200
# name    雁南三路 Yàn nán sān lù
# name:zh 雁南三路
#
# id      266957158
# name    莲湖路 Liánhú Rd
# name:zh 莲湖路
#
# id      266957159
# name    莲湖路 Liánhú Rd
# name:zh 莲湖路
#
# id      267024767
# name    2nd Ring Road
# name:zh 二环路
#
# id      277695702
# name    2nd Ring Road
# name:zh 二环路
#
# id      277695706
# name    2nd Ring Road
# name:zh 二环路
#
# id      288902525
# name    Longhai Line
# name:zh 陇海线
#
# id      288902526
# name    Longhai Line
# name:zh 陇海线
#
# id      288902529
# name    Longhai Line
# name:zh 陇海线
#
# id      288902530
# name    Longhai Line
# name:zh 陇海线
#
# id      290670759
# name    Longhai Line
# name:zh 陇海线
#
# id      290670760
# name    Longhai Line
# name:zh 陇海线
#
# id      292586123
# name    Longhai Line
# name:zh 陇海线
#
# id      292586124
# name    Longhai Line
# name:zh 陇海线
#
# id      292818834
# name    天池 Sky Pool
# name:zh 天池
#
# id      310009689
# name    新开门南路 New Open Door South Rd
# name:zh 新开门南路
#
# id      310009690
# name    曲江池东路 Qū jiāng chí East Rd
# name:zh 曲江池东路
#
# id      334971107
# name    长安南路 Cháng‘ān nán lù
# name:zh 长安南路
#
# id      335527399
# name    高新六路 / Gaoxin Liu Lu
# name:zh 高新六路
#
# id      335527401
# name    高新六路 / Gaoxin Liu Lu
# name:zh 高新六路
#
# id      335531764
# name    Tangyan Lu
# name:zh 唐延路
#
# id      335531767
# name    桃园南路 / Taoyuan Nan Lu
# name:zh 桃园南路
#
# id      335531769
# name    2nd Ring Road
# name:zh 二环路
#
# id      335531771
# name    2nd Ring Road
# name:zh 二环路
#
# id      335531773
# name    2nd Ring Road
# name:zh 二环路
#
# id      335539578
# name    新开门南路 New Open Door South Rd
# name:zh 新开门南路
#
# id      335700122
# name    芙蓉西路 Fúróng West Rd
# name:zh 芙蓉西路
#
# id      335700133
# name    高新六路 / Gaoxin Liu Lu
# name:zh 高新六路
#
# id      352716537
# name    Longhai Line
# name:zh 陇海线
#
# id      352716539
# name    Longhai Line
# name:zh 陇海线
#
# id      352716540
# name    Longhai Line
# name:zh 陇海线
#
# id      352716542
# name    Longhai Line
# name:zh 陇海线
#
# id      408666158
# name    十八盘 Eighteen Coils
# name:zh 十八盘
#
# id      410078319
# name    曲江池东路 Qū jiāng chí East Rd
# name:zh 曲江池东路
#
# id      446780963
# name    Howard Johnson Ginwa Plaza
# name:zh 西安金花豪生国际大酒店
#
# id      446874243
# name    高新六路 / Gaoxin Liu Lu
# name:zh 高新六路
#
# id      446874264
# name    高新六路 / Gaoxin Liu Lu
# name:zh 高新六路
#
# id      170266
# name    连霍高速 - Lianhuo Expressway
# name:zh 连霍高速
#
# id      2971123
# name    洛南县 (Luonan)
# name:zh 洛南县
#
# id      2971125
# name    商州区 (Shangzhou)
# name:zh 商州区
#
# id      2971127
# name    柞水县 (Zhashui)
# name:zh 柞水县
#
# id      2971129
# name    商洛市 / Shangluo
# name:zh 商洛市
#
# id      3028612
# name    大荔县 (Dali)
# name:zh 大荔县
#
# id      3028613
# name    富平县 (Fuping)
# name:zh 富平县
#
# id      3028616
# name    华县 (Hua)
# name:zh 华县
#
# id      3028617
# name    华阴市 (Huayin)
# name:zh 华阴市
#
# id      3028618
# name    临渭区 (Linwei)
# name:zh 临渭区
#
# id      3028620
# name    潼关县 (Tongguan)
# name:zh 潼关县
#
# id      3028621
# name    渭南市 (Yan'an)
# name:zh 渭南市
#
# id      3048442
# name    宝鸡市 / Baoji
# name:zh 宝鸡市
#
# id      3048835
# name    眉县 (Mei)
# name:zh 眉县
#
# id      3048911
# name    扶风县 (Fufeng)
# name:zh 扶风县
#
# id      3048913
# name    麟游县 (Linyou)
# name:zh 麟游县
#
# id      3221008
# name    淳化县 (Chunhua)
# name:zh 淳化县
#
# id      3221009
# name    泾阳县 (Jingyang)
# name:zh 泾阳县
#
# id      3221010
# name    礼泉县 (Liquan)
# name:zh 礼泉县
#
# id      3221011
# name    乾县 (Qian)
# name:zh 乾县
#
# id      3221012
# name    秦都区 (Qindu)
# name:zh 秦都区
#
# id      3221013
# name    三原县 (Sanyuan)
# name:zh 三原县
#
# id      3221014
# name    渭城区 (Weicheng)
# name:zh 渭城区
#
# id      3221015
# name    武功县 (Wugong)
# name:zh 武功县
#
# id      3221016
# name    兴平市 (Xingping)
# name:zh 兴平市
#
# id      3221018
# name    杨陵区 (Yangling)
# name:zh 杨陵区
#
# id      3221019
# name    永寿县 (Yongshou)
# name:zh 永寿县
#
# id      3221020
# name    咸阳市 / Xianyang
# name:zh 咸阳市
#
# id      3226004
# name    西安市 / Xi'an
# name:zh 西安市
#
# id      3226087
# name    灞桥区 (Baqiao)
# name:zh 灞桥区
#
# id      3226088
# name    碑林区 (Beilin)
# name:zh 碑林区
#
# id      3226089
# name    长安区 (Chang'an)
# name:zh 长安区
#
# id      3226090
# name    高陵县 (Gaoling)
# name:zh 高陵县
#
# id      3226091
# name    户县 (Hu)
# name:zh 户县
#
# id      3226092
# name    蓝田县 (Lantian)
# name:zh 蓝田县
#
# id      3226093
# name    莲湖区 (Lianhu)
# name:zh 莲湖区
#
# id      3226094
# name    临潼区 (Chang'an)
# name:zh 临潼区
#
# id      3226095
# name    未央区 (Weiyang)
# name:zh 未央区
#
# id      3226096
# name    新城区 (Xincheng)
# name:zh 新城区
#
# id      3226097
# name    阎良区 (Yanliang)
# name:zh 阎良区
#
# id      3226098
# name    雁塔区 (Yanta)
# name:zh 雁塔区
#
# id      3226099
# name    周至县 (Zhouzhi)
# name:zh 周至县
#
# id      3366810
# name    曲江池 Qū jiāng chí
# name:zh 曲江池

# %% [markdown]
# Among the name tags with no golden-standard 'name:zh' tags shown below, only some of them can be easily fixed, namely those with a space separating the Chinese and English parts, such as:
#
# '兵马俑 terracotta army',
#
# '高薪四路 / Gaoxin Si Lu' and
#
# '高薪第一小学 / Gaoxin Diyi Xiaoxue'.
#
# And we have incidentally noticed that the wrong Chinese characters '高薪' here should be '高新' instead.

# %%
print("No 'name:zh' tag or 'name:zh' tag not in Chinese:\n")
pprint(names_zh_bad)
# Out:
# No 'name:zh' tag or 'name:zh' tag not in Chinese:
#
# [['310515765', u'兵马俑 terracotta army'],
#  ['312727586', u'西安软件园: 260, 262'],
#  ['315470145', u'丁家桥: 107, 218, 251, 908'],
#  ['1558667396', u'陕西电视塔 Shaanxi Television Tower'],
#  ['1655332222', u'交通银行ATM'],
#  ['1828308887', u'招行ATM'],
#  ['2615853708', u'农行ATM'],
#  ['2615853709', u'建行ATM'],
#  ['2615870236', u'丁家桥: 218, 251'],
#  ['2615873516', u'西安软件园: 218, 253, 260, 262'],
#  ['2616229440', u'西寨： 905，917，923，4-19'],
#  ['2616238121', u'西寨：905，917，923，4-19'],
#  ['2616238122', u'西寨：323，500，4-04，4-09，4-10，4-13'],
#  ['2616238123', u'西寨：323，500，4-04，4-09，4-10，4-13，4-18'],
#  ['2616238124', u'西寨：215，229，324，918，4-18'],
#  ['2616238125', u'西寨：215，229，324，918'],
#  ['2616238126', u'青年南街：215，229，324，918'],
#  ['2616238127', u'青年南街：215，229，324，918'],
#  ['2616238128', u'长安党校：215，229，324，918'],
#  ['2616238130', u'太阳水岸新城：162'],
#  ['2616238131', u'候家湾村：324'],
#  ['2616238132', u'绿园度假村：324，923'],
#  ['2921585612', u'太阳水岸新城：162'],
#  ['2921585613', u'长安二中：162'],
#  ['2921585614', u'毓秀园：162'],
#  ['2921585615', u'金堆城：162'],
#  ['2921585616', u'圣和家园：162'],
#  ['2921585617', u'青城：162'],
#  ['2921585618', u'清凉寺：162'],
#  ['2921585619', u'欧亚学院：162'],
#  ['2921585620', u'姜溪花都社区：162'],
#  ['3013596183', u'都市与建筑设计研究中心（7F）'],
#  ['3017385348', u'周宋小学ZhouSong Primary School'],
#  ['3017385349', u'周宋幼儿园ZhouSong kindergarten'],
#  ['3283285289', u'绿地世纪城 Igress Park'],
#  ['3686351885', u'中国工商银行ATM'],
#  ['3686357125', u'中国建设银行ATM'],
#  ['4110728490', u'西安陇华 hotel'],
#  ['4516332396', u'高岳菘宅 UNESCO'],
#  ['26327101', u'太白南路 / Taibai Nan Lu'],
#  ['28257571', u'沣惠南路 / Fenghui Nan Lu'],
#  ['28257572', u'科技七路 / Keji Qi Lu'],
#  ['28258958', u'高薪四路 / Gaoxin Si Lu'],
#  ['28258961', u'丈八北路 / Zhangba Bei Lu'],
#  ['28294894', u'锦业路 JinYe road'],
#  ['28322137', u'高新三路 / Gaoxin San Lu'],
#  ['28465736', u'新纪元公园 / Xinji Yuan Huayuan'],
#  ['28482923', u'高新二路 / Gaoxin Er Lu'],
#  ['28506885', u'安吉巷 / Anji Xiang'],
#  ['28655769', u'丈八北路 / Zhangba Bei Lu'],
#  ['28696871', u'科技六路 / Keji Liu Lu'],
#  ['28718661', u'枫林路 / Fenglin Road'],
#  ['28718662', u'枫叶北路 / Fengye Bei Lu'],
#  ['28718663', u'枫叶南路 / Fengye Nan Lu'],
#  ['28718664', u'科技六路 / Keji Liu Lu'],
#  ['28718679', u'科技四路 / Keji Si Lu'],
#  ['28738544', u'高新一路 / Gaoxin Yi Lu'],
#  ['28738545', u'高新一路 / Gaoxin Yi Lu'],
#  ['55696761', u'白沙路 / Baisha Lu'],
#  ['148975613', u'电子二路 / Dianzi Er Lu'],
#  ['162542043', u'太白南路 / Taibai Nan Lu'],
#  ['162658753', u'高薪路 / Gaoxin Lu'],
#  ['170359515', u'西安绕城高速G3001'],
#  ['183399832', u'博文路 / Bowen Lu'],
#  ['205768672', u'西潼高速G30'],
#  ['212724368', u'电子三路 / Dianzi San Lu'],
#  ['229924127', u'西潼高速G30'],
#  ['229924131', u'西潼高速G20'],
#  ['235002635', u'科技一路 / Keji Yi Lu'],
#  ['236672209', u'西安绕城高速G3001'],
#  ['237065467', u'西安绕城高速G3001'],
#  ['237110064', u'锦业路 JinYe road'],
#  ['237110687', u'锦业路 JinYe road'],
#  ['237110689', u'锦业路 JinYe road'],
#  ['252885702', u"西安世博公园（Xi'an EXPO)"],
#  ['253971563', u'曲江六号Ⅲ'],
#  ['253972079', u'曲江池北路Qū jiāng chí North Rd'],
#  ['254470938', u'麦德龙 METRO'],
#  ['264106098', u'青年教师公寓1#'],
#  ['264106099', u'青年教师公寓2#'],
#  ['264107442', u'教工楼1#'],
#  ['264109803', u'青年教师公寓3#'],
#  ['264421116', u'教二100'],
#  ['264421117', u'中三1300'],
#  ['264421118', u'中二1200'],
#  ['266773678', u'白沙路 / Baisha Lu'],
#  ['266848694', u'西安绕城高速G3001'],
#  ['266848695', u'西安绕城高速G3001'],
#  ['266848696', u'西安绕城高速G3001'],
#  ['266848697', u'西安绕城高速G3001'],
#  ['266848698', u'西安绕城高速G3001'],
#  ['266848699', u'西安绕城高速G3001'],
#  ['266848700', u'西安绕城高速G3001'],
#  ['266848701', u'西安绕城高速G3001'],
#  ['288925370', u'西潼高速G30'],
#  ['289882305', u'西安绕城高速G3001'],
#  ['290517491', u'西潼高速G30'],
#  ['290517492', u'西潼高速G30'],
#  ['290517497', u'西潼高速G30'],
#  ['290517498', u'西潼高速G30'],
#  ['290518364', u'西潼高速G20'],
#  ['290518365', u'西潼高速G20'],
#  ['290518366', u'西潼高速G30'],
#  ['290518367', u'西潼高速G30'],
#  ['290519233', u'西潼高速G20'],
#  ['290519234', u'西潼高速G20'],
#  ['290519235', u'西潼高速G30'],
#  ['290519236', u'西潼高速G30'],
#  ['290519237', u'西潼高速G30'],
#  ['290519238', u'西潼高速G30'],
#  ['290519239', u'西潼高速G20'],
#  ['290519240', u'西潼高速G20'],
#  ['295181368', u'长征365'],
#  ['297832885', u'周鱼路ZhouYu Lu'],
#  ['301483274', u'西潼高速G20'],
#  ['301483275', u'西潼高速G20'],
#  ['301483276', u'西潼高速G30'],
#  ['301483277', u'西潼高速G30'],
#  ['313207520', u'银河科技公寓 / Yinhe Keji Gongyu'],
#  ['313208278', u'高薪第一小学 / Gaoxin Diyi Xiaoxue'],
#  ['313208848', u'枫叶新新花园 / Fengye Xinxin Huayuan'],
#  ['313209011', u'高薪一中高中部 / Gaoxin Yizhong Gaozhong Bu'],
#  ['313209994', u"西安瑞斯丽大酒店 / Xi'an Swizz Touches Hotel"],
#  ['315561296', u'高新一路 / Gaoxin Yi Lu'],
#  ['333194387', u'太白南路 / Taibai Nan Lu'],
#  ['333194390', u'太白南路 / Taibai Nan Lu'],
#  ['334281025', u'高薪四路 / Gaoxin Si Lu'],
#  ['334281026', u'科技路 / Keji Lu'],
#  ['334648176', u'太白南路 / Taibai Nan Lu'],
#  ['335513936', u'太白南路 / Taibai Nan Lu'],
#  ['335518216', u'高薪路 / Gaoxin Lu'],
#  ['335518217', u'高新二路 / Gaoxin Er Lu'],
#  ['335518218', u'高新路 / Gaoxin Lu'],
#  ['335522611', u'丈八北路 / Zhangba Bei Lu'],
#  ['335522612', u'丈八北路 / Zhangba Bei Lu'],
#  ['335527388', u'科技路 / Keji Lu'],
#  ['335527391', u'高新二路 / Gaoxin Er Lu'],
#  ['335527392', u'科技路 / Keji Lu'],
#  ['335527393', u'高新路 / Gaoxin Lu'],
#  ['335527395', u'科技路 / Keji Lu'],
#  ['335527402', u'丈八北路 / Zhangba Bei Lu'],
#  ['335527404', u'丈八北路 / Zhangba Bei Lu'],
#  ['335527411', u'锦业路 JinYe road'],
#  ['335527413', u'锦业路 JinYe road'],
#  ['335527415', u'锦业路 JinYe road'],
#  ['335560623', u'太白南路 / Taibai Nan Lu'],
#  ['335700126', u'高新三路 / Gaoxin San Lu'],
#  ['335700129', u'科技路 / Keji Lu'],
#  ['348652556', u'西安绕城高速G3001'],
#  ['348652561', u'西安绕城高速G3001'],
#  ['348652571', u'西安绕城高速G3001'],
#  ['361357669', u'西潼高速G20'],
#  ['361357670', u'西潼高速G30'],
#  ['361357671', u'西潼高速G30'],
#  ['361357672', u'西潼高速G20'],
#  ['361358094', u'西潼高速G20'],
#  ['361358095', u'西潼高速G30'],
#  ['361358096', u'西潼高速G20'],
#  ['361358097', u'西潼高速G30'],
#  ['361358100', u'西潼高速G20'],
#  ['361358101', u'西潼高速G20'],
#  ['361358102', u'西潼高速G30'],
#  ['361358103', u'西潼高速G30'],
#  ['361358104', u'西潼高速G20'],
#  ['361358105', u'西潼高速G20'],
#  ['361358106', u'西潼高速G30'],
#  ['361358107', u'西潼高速G30'],
#  ['361358109', u'西潼高速G20'],
#  ['361358110', u'西潼高速G20'],
#  ['361358111', u'西潼高速G30'],
#  ['361358112', u'西潼高速G30'],
#  ['361358115', u'西潼高速G20'],
#  ['361358116', u'西潼高速G20'],
#  ['361358117', u'西潼高速G30'],
#  ['361358118', u'西潼高速G30'],
#  ['361361259', u'西潼高速G20'],
#  ['361361260', u'西潼高速G20'],
#  ['361361261', u'西潼高速G30'],
#  ['361361262', u'西潼高速G30'],
#  ['381473318', u'太白南路 / Taibai Nan Lu'],
#  ['381473319', u'太白南路 / Taibai Nan Lu'],
#  ['403107243', u'西潼高速G30'],
#  ['403107250', u'西潼高速G30'],
#  ['412602202', u'号6'],
#  ['426731361', u'西安绕城高速G3001'],
#  ['426734680', u'西安绕城高速G3001'],
#  ['426734685', u'西安绕城高速G3001'],
#  ['426734689', u'西安绕城高速G3001'],
#  ['435442353', u'苏园丰景1#'],
#  ['435442355', u'苏园丰景2#'],
#  ['435442356', u'苏园丰景3#'],
#  ['435442357', u'苏园丰景4#'],
#  ['435442358', u'苏园丰景5#'],
#  ['452594089', u'满堂悦MOMA'],
#  ['457301963', u'科技一路 / Keji Yi Lu'],
#  ['457301964', u'科技一路 / Keji Yi Lu'],
#  ['457301965', u'白沙路 / Baisha Lu']]

# %% [markdown]
# Thus we update the regular expression to isolate those easily-fixable name tags, and show how to fix them:

# %%
CN_SPACE_EN  = re.compile(u'^[\u4e00-\u9fa5\s]+\s[^\u4e00-\u9fa5]+$')

for elem, key, val in all_tags(SAMPLE_FILE):
    if key == 'name' and CN_SPACE_EN.match(val):
        cn, _, _ = val.partition(' ')
        print('id:\t\t', elem.attrib['id'])
        print('name:\t', val)
        print('fixed:\t', cn, '\n')
# Out:
# id:		 310515765
# name:	 兵马俑 terracotta army
# fixed:	 兵马俑
#
# id:		 850352828
# name:	 索菲特国际会展中心 Sofitel on Renmin Square
# fixed:	 索菲特国际会展中心
#
# id:		 3283285289
# name:	 绿地世纪城 Igress Park
# fixed:	 绿地世纪城
#
# id:		 28258958
# name:	 高薪四路 / Gaoxin Si Lu
# fixed:	 高薪四路
#
# id:		 28294894
# name:	 锦业路 JinYe road
# fixed:	 锦业路
#
# id:		 28465736
# name:	 新纪元公园 / Xinji Yuan Huayuan
# fixed:	 新纪元公园
#
# id:		 55696761
# name:	 白沙路 / Baisha Lu
# fixed:	 白沙路
#
# id:		 142323478
# name:	 新开门南路 New Open Door South Rd
# fixed:	 新开门南路
#
# id:		 162658753
# name:	 高薪路 / Gaoxin Lu
# fixed:	 高薪路
#
# id:		 251744557
# name:	 雁南三路 Yàn nán sān lù
# fixed:	 雁南三路
#
# id:		 251746753
# name:	 长安南路 Cháng‘ān nán lù
# fixed:	 长安南路
#
# id:		 313208278
# name:	 高薪第一小学 / Gaoxin Diyi Xiaoxue
# fixed:	 高薪第一小学
#
# id:		 335518217
# name:	 高新二路 / Gaoxin Er Lu
# fixed:	 高新二路
#
# id:		 335522611
# name:	 丈八北路 / Zhangba Bei Lu
# fixed:	 丈八北路
#
# id:		 335527388
# name:	 科技路 / Keji Lu
# fixed:	 科技路
#
# id:		 335527413
# name:	 锦业路 JinYe road
# fixed:	 锦业路
#
# id:		 335531767
# name:	 桃园南路 / Taoyuan Nan Lu
# fixed:	 桃园南路
#
# id:		 446874243
# name:	 高新六路 / Gaoxin Liu Lu
# fixed:	 高新六路
#
# id:		 446874264
# name:	 高新六路 / Gaoxin Liu Lu
# fixed:	 高新六路
#
# id:		 2971129
# name:	 商洛市 / Shangluo
# fixed:	 商洛市
#
# id:		 3048442
# name:	 宝鸡市 / Baoji
# fixed:	 宝鸡市
#
# id:		 3221014
# name:	 渭城区 (Weicheng)
# fixed:	 渭城区
#
# id:		 3226090
# name:	 高陵县 (Gaoling)
# fixed:	 高陵县

# %% [markdown]
# # Auditing Name:en Tags

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

ENDING = re.compile(r'\b\S+\.?$', re.IGNORECASE)     
EXPECTED = ['City', 'District', 'Section', 'Temple', 'Park', 'Base', 'Line', 'Luanzhen', 'Area',
    'Hospital','Tunnel', 'Plaza', 'Railway', 'River', 'Expressway', 'Road', 'Square', 'Alley',
    'County', 'Street', 'Village', 'School', 'Avenue', 'Pavilion', 'Path', 'University', 
    'Airport', 'Cemetery', 'Factory', 'Sanyao', 'Baqiao', 'Yinzhen', 'Jingyang', 'Lantian',
    'Gujiling', 'Caotang', "Chang'an", 'Linwei', 'Station', 'Gate', 'Yangling', 'Restaurant',
    'Island', 'Tower', 'Mall', 'Exit', 'Stadium', 'Hotel', 'Store', 'station', 'Peak',
    'Market',
]
            
endings = defaultdict(set)     
for elem, key, val in all_tags(SAMPLE_FILE):
    if key == 'name:en':
        ending = ENDING.search(val).group()
        if ending not in EXPECTED:
            endings[ending].add(val)

pprint(endings.keys())
# Out:
# ['Doumen',
#  'Warriors',
#  'Qiaonan',
#  'Ginwa',
#  'Rd',
#  'cafe',
#  'Dayang',
#  'Gengzhen',
#  'Houjiacun',
#  'Zhongnan',
#  'Columbia',
#  'Caochangpo',
#  'Expy',
#  '2',
#  'Xizhakou',
#  'Jiaochangmen',
#  '0006',
#  'Dajing',
#  'Weinan',
#  'Fengqiyuan',
#  'Str',
#  'Beicaojia',
#  'Fanjia',
#  'Tongyuan',
#  'Thirteen']

# %%
ABBRES = {
    'Blvd': 'Boulevard',
    'Rd': 'Road',
    'Lu': 'Road',
    'Rd(E)': 'East Road',
    'Rd(W)': 'West Road',
    'Rd(N)': 'North Road',
    'Rd(S)': 'South Road',
    'Expy': 'Expressway',
    'Str': 'Street',
    'St': 'Street',
    'Jie': 'Street',
    u'Jie（S.）': 'Stret',
    'Qu': 'District',
}

# %%
for elem, key, val in all_tags(OSM_FILE):
    if key == 'name:en':
        for abbre, full in ABBRES.items():
            if val.endswith(abbre):
                print(abbre, ':', val, '=>', val.replace(abbre, full))
# Out:
# Qu : Lintong Qu => Lintong District
# Qu : Yanta Qu => Yanta District
# Rd : Xiwan Rd => Xiwan Road
# Rd : E. Zhangba Rd => E. Zhangba Road
# Rd : N. Changan Rd => N. Changan Road
# Rd : S. Changan Rd => S. Changan Road
# Rd : TV Tower Rd => TV Tower Road
# Rd : Changming Rd => Changming Road
# Rd : W. Xiaozhai Rd => W. Xiaozhai Road
# Rd : W. Huaqing Rd => W. Huaqing Road
# Rd : Huichang Rd => Huichang Road
# Jie（S.） : Zhuque Da Jie（S.） => Zhuque Da Stret
# Rd : Daqing Rd => Daqing Road
# Lu : Da Qing Lu => Da Qing Road
# Rd : Fengqing Rd => Fengqing Road
# Rd : Yanhuan Rd => Yanhuan Road
# Lu : Guang De Lu => Guang De Road
# Rd : W. Renming Rd => W. Renming Road
# Rd : Weiyang East Rd => Weiyang East Road
# Rd(E) : Youyi Rd(E) => Youyi East Road
# Rd : Cien Rd => Cien Road
# Rd : Yannan 1st Rd => Yannan 1st Road
# Rd : Chongye Rd => Chongye Road
# Rd : Yongsong Rd => Yongsong Road
# Lu : Jinye Er Lu => Jinye Er Road
# Rd : Weiyang West Rd => Weiyang West Road
# Rd : Jianshe Rd => Jianshe Road
# Rd : W. Cehui Rd => W. Cehui Road
# Rd : S. Wenyi Rd => S. Wenyi Road
# Rd : N. Sport Statium Rd => N. Sport Statium Road
# Rd : Yannan 3rd Rd => Yannan 3rd Road
# Rd : New Open Door South Rd => New Open Door South Road
# Rd : E. Furong Rd => E. Furong Road
# Rd : S. Yanta Rd => S. Yanta Road
# Rd : S. Yanta Rd => S. Yanta Road
# Rd : Yannan 2nd Rd => Yannan 2nd Road
# Str : Zhuque Str => Zhuque Street
# Rd(E) : Xianning Rd(E) => Xianning East Road
# Rd : Jinshui Rd => Jinshui Road
# St : Anxi St => Anxi Street
# St : Jiandong St => Jiandong Street
# St : Andong St => Andong Street
# Rd : Fenghe Rd => Fenghe Road
# Rd : Taihua Rd => Taihua Road
# Rd(S) : Gongyuan Rd(S) => Gongyuan South Road
# Str : Taian Str => Taian Street
# Rd : Jiangong Rd => Jiangong Road
# Rd : E. Tuanjie Rd => E. Tuanjie Road
# Rd : Wannian Rd => Wannian Road
# Rd : Tiyu Rd => Tiyu Road
# Rd : Taoyuan Rd => Taoyuan Road
# Rd : E. Wenhua Rd => E. Wenhua Road
# Rd : S. 2nd Ring Rd => S. 2nd Ring Road
# Rd : North Tabai Rd => North Tabai Road
# Rd : N. Taibai Rd => N. Taibai Road
# Expy : Ring Expy => Ring Expressway
# Rd : Sanhang Rd => Sanhang Road
# Jie : Zhuque Da Jie => Zhuque Da Street
# Rd : Bajia Rd => Bajia Road
# Rd : Xizhan Rd => Xizhan Road
# Rd : W. Laodong Rd => W. Laodong Road
# Rd : South Daxue Rd => South Daxue Road
# Str : Bianxi Str => Bianxi Street
# Rd : Lijiachun Rd => Lijiachun Road
# Rd : Yongning Rd => Yongning Road
# Rd : Yianta Rd => Yianta Road
# Rd : N. Kangfu Rd => N. Kangfu Road
# Rd : Xuehui Rd => Xuehui Road
# Rd : S. Xueyuan Rd => S. Xueyuan Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Rd : S. Furong Rd => S. Furong Road
# Rd : Tiantan Rd => Tiantan Road
# Rd : W. Tiantan Rd => W. Tiantan Road
# Rd : Qingsong Rd => Qingsong Road
# Rd : Jianfusi Rd => Jianfusi Road
# Rd : S. Hongzhuan Rd => S. Hongzhuan Road
# Str : Furong Str => Furong Street
# Rd : Jingye Rd => Jingye Road
# Rd : Chuangxin Rd => Chuangxin Road
# Rd : Duxue Rd => Duxue Road
# Rd : Tuanjie Rd => Tuanjie Road
# Str : Guangshunmen Str => Guangshunmen Street
# Rd : Jianhua Rd => Jianhua Road
# Rd : Yongsheng Rd => Yongsheng Road
# Rd : W. Wenyi Rd => W. Wenyi Road
# Lu : Tangyan Nan Lu => Tangyan Nan Road
# Rd : Cehui Rd => Cehui Road
# Rd : E. Cehui Rd => E. Cehui Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Rd : Biaofeng Rd => Biaofeng Road
# Rd : Zhuanfang Rd => Zhuanfang Road
# Rd : Anding Rd => Anding Road
# Str : Paofang Str => Paofang Street
# Rd : W. Changying Rd => W. Changying Road
# Rd : Renyi Rd => Renyi Road
# Str : Changsheng Str => Changsheng Street
# Rd : Wanda Square 1st Rd => Wanda Square 1st Road
# Str : Xifeng Str => Xifeng Street
# Rd : N. Pianjiachun Rd => N. Pianjiachun Road
# Rd : Tietasi Rd => Tietasi Road
# Rd : W. Tietasi Rd => W. Tietasi Road
# Rd : E. Yaoyuan Rd => E. Yaoyuan Road
# Rd : Xingyuan Rd => Xingyuan Road
# Rd(E) : Xianning Rd(E) => Xianning East Road
# Rd(E) : Xianning Rd(E) => Xianning East Road
# Str : S. Zhuque Str => S. Zhuque Street
# Rd : Shida Rd => Shida Road
# Rd : S. Yanta Rd => S. Yanta Road
# Rd : S. Yanta Rd => S. Yanta Road
# Rd : E. Cien Rd => E. Cien Road
# Rd : Shida Rd => Shida Road
# Rd : Renmin East Rd => Renmin East Road
# Rd : Dongren Rd => Dongren Road
# Rd : W. Kangfu Rd => W. Kangfu Road
# Rd : Qingling Rd => Qingling Road
# Rd : Maojia Rd => Maojia Road
# Rd : Xingzhe Rd => Xingzhe Road
# Rd : W. Wenhua Rd => W. Wenhua Road
# Rd : N. Renming Rd => N. Renming Road
# Rd : E. Renming Rd => E. Renming Road
# Rd : S. Kangfu Rd => S. Kangfu Road
# Rd : JIankang Rd => JIankang Road
# Rd : Jiankang Rd => Jiankang Road
# Rd : N. Jiankang Rd => N. Jiankang Road
# Rd : N. Jiangzhai Rd => N. Jiangzhai Road
# Rd : S. Jiangzhai Rd => S. Jiangzhai Road
# Rd : Tonghe Rd => Tonghe Road
# Str : Xisi Str => Xisi Street
# Rd : S. Renming Rd => S. Renming Road
# Rd : E. Huancheng Rd => E. Huancheng Road
# Rd : Chengxin Rd => Chengxin Road
# Rd : Taoyuan Rd => Taoyuan Road
# Rd : Taoyuan Rd => Taoyuan Road
# Rd : E. 2nd Ring Rd => E. 2nd Ring Road
# Rd : N. Qinling Rd => N. Qinling Road
# Rd : Chengouchun Rd => Chengouchun Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Rd : Taihua Rd => Taihua Road
# Rd : E. Xiaozhai Rd => E. Xiaozhai Road
# Rd : Cuihua Rd => Cuihua Road
# Rd : TV Tower Rd => TV Tower Road
# Rd : N. Fengdeng Rd => N. Fengdeng Road
# Rd : Jingjiu Rd => Jingjiu Road
# Rd : Xingqing Rd => Xingqing Road
# Rd : Jingyuan Rd => Jingyuan Road
# Rd : Jiangong Rd => Jiangong Road
# Rd : Xinghuo Rd => Xinghuo Road
# Rd : Xingqing Rd => Xingqing Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Rd(E) : Youyi Rd(E) => Youyi East Road
# Rd : W. Furong Rd => W. Furong Road
# Rd : Yannan 3rd Rd => Yannan 3rd Road
# Rd : Yannan 1st Rd => Yannan 1st Road
# Rd : Cuihua Rd => Cuihua Road
# Rd : Cuihua Rd => Cuihua Road
# Rd : Jiangong Rd => Jiangong Road
# Rd : Jiangong Rd => Jiangong Road
# Rd(S) : Gongyuan Rd(S) => Gongyuan South Road
# Expy : Ring Expy => Ring Expressway
# Expy : Ring Expy => Ring Expressway
# Expy : Ring Expy => Ring Expressway
# Expy : Ring Expy => Ring Expressway
# Rd : Yanhuan Rd => Yanhuan Road
# Rd : Yanhuan Rd => Yanhuan Road
# Rd : N. Qinling Rd => N. Qinling Road
# Blvd : Yinqiao Blvd => Yinqiao Boulevard
# Rd : W. Yaoyuan Rd => W. Yaoyuan Road
# Rd : N. Renming Rd => N. Renming Road
# Rd : N. Renming Rd => N. Renming Road
# Rd : N. Qinling Rd => N. Qinling Road
# Rd : N. Qinling Rd => N. Qinling Road
# Rd : N. Renming Rd => N. Renming Road
# Rd : N. Renming Rd => N. Renming Road
# Str : Guangshunmen Str => Guangshunmen Street
# Rd : N. Qinling Rd => N. Qinling Road
# Rd : N. Qinling Rd => N. Qinling Road
# Rd : Jingjiu Rd => Jingjiu Road
# Rd : New Open Door South Rd => New Open Door South Road
# Rd : Jingjiu Rd => Jingjiu Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Rd : E. Zhangba Rd => E. Zhangba Road
# Str : Dongguanzheng Str => Dongguanzheng Street
# Lu : Da Qing Lu => Da Qing Road
# Lu : Da Qing Lu => Da Qing Road
# Rd(E) : Youyi Rd(E) => Youyi East Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Rd : S. 2nd Ring Rd => S. 2nd Ring Road
# Rd : Yianta Rd => Yianta Road
# Rd : Yianta Rd => Yianta Road
# Rd(E) : Youyi Rd(E) => Youyi East Road
# Rd(E) : Xianning Rd(E) => Xianning East Road
# Rd(S) : Gongyuan Rd(S) => Gongyuan South Road
# Rd : West 8th Rd => West 8th Road
# Rd : East Ring Rd => East Ring Road
# Rd : Jiangong Rd => Jiangong Road
# Rd(S) : Gongyuan Rd(S) => Gongyuan South Road
# Rd(S) : Gongyuan Rd(S) => Gongyuan South Road
# Lu : Jinye Er Lu => Jinye Er Road
# Lu : Xiwan Gong Lu => Xiwan Gong Road
# Lu : Jinye Er Lu => Jinye Er Road
# Lu : Da Qing Lu => Da Qing Road
# Lu : Da Qing Lu => Da Qing Road
# Rd : New Open Door South Rd => New Open Door South Road
# Rd : Kechuang Rd => Kechuang Road
# Rd : Jingjiu Rd => Jingjiu Road
# Rd(E) : Xianning Rd(E) => Xianning East Road
# Rd : Jiangong Rd => Jiangong Road
# Rd : Jingjiu Rd => Jingjiu Road
# Rd : Maojia Rd => Maojia Road
# Expy : Ring Expy => Ring Expressway
# Rd : Xingzhe Rd => Xingzhe Road
# Rd : Sanhang Rd => Sanhang Road
# Rd : Zhuhong Rd => Zhuhong Road
# Rd : N. Tabai Rd => N. Tabai Road
# Rd : Renmin East Rd => Renmin East Road
# Str : Guangshunmen Str => Guangshunmen Street
# Expy : Ring Expy => Ring Expressway
# Expy : Ring Expy => Ring Expressway
# Expy : Ring Expy => Ring Expressway
# Expy : Ring Expy => Ring Expressway
# Lu : Da Qing Lu => Da Qing Road
# Str : Guangshunmen Str => Guangshunmen Street
# Str : Guangshunmen Str => Guangshunmen Street
# Rd : S. Yanta Rd => S. Yanta Road
# Rd : S. Yanta Rd => S. Yanta Road
# Rd : South Daxue Rd => South Daxue Road
# Rd : South Daxue Rd => South Daxue Road
# Rd : Qingsong Rd => Qingsong Road
# Rd : S. Furong Rd => S. Furong Road
# Rd : S. Furong Rd => S. Furong Road
# Rd : S. Yanta Rd => S. Yanta Road
# Rd : S. Yanta Rd => S. Yanta Road

# %% [markdown]
# # Final audit code

# %% [markdown]
# What we learnt so far can be written up as an **audit_tags** function to be used in the audit.py file (which will be imported and used in the to_csv.py file):
#
# ```
# def audit_tags(tags):
#     # Apply what we learnt in audit.ipynb:
#     for i, tag in enumerate(tags):
#         value = tag['value']
#
#         # Fix name tags
#         if tag['key'] == 'name' and (ALL_EN.match(value) or
#                                      CN_EN.match(value)):
#             zh_tag = get_zh_tag(tags)
#
#             # Use name:zh as the gold standard
#             if zh_tag and ALL_CN.match(zh_tag['value']):
#                 tags[i]['value'] = zh_tag['value']
#
#             # Fix tags with a space separating the Chinese
#             # and English parts, such as:
#             # '兵马俑 terracotta army'
#             # '高薪四路 / Gaoxin Si Lu'
#             elif CN_SPACE_EN.match(value):
#                 cn, _, _ = value.partition(' ')
#                 tags[i]['value'] = cn
#
#             # Fix typos
#             # '高薪' => '高新'
#             for wrong, right in TYPOS.items():
#                 if wrong in value:
#                     tags[i]['value'] = tags[i]['value'].replace(wrong, right)
#
#         # Fix abbrevations in name:en
#         if tag['key'] == 'en':
#             for abbre, full in ABBRES.items():
#                 if value.endswith(abbre):
#                     tags[i]['value'] = tags[i]['value'].replace(abbre, full)
#
#     return tags
# ```
